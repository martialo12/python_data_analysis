# %% [markdown]
# # Palindromes

# %%
import math
import collections
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

# %%
# code from prvious video

def signature(word):
    return ''.join(sorted(word))

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)
    
anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
# reverse word by slicing with negative step 
'michele'[::-1]
# Out:
# 'elehcim'

# %%
anagrams_by_sig.values()
# Out:
# dict_values([{'aal', 'ala'}, {'aam', 'ama'}, {'nicarao', 'aaronic', 'ocarina'}, {'aeration', 'aaronite'}, {'aura', 'aaru'}, {'ab', 'ba'}, {'aba', 'baa'}, {'caba', 'abac'}, {'acrobat', 'abactor'}, {'bafta', 'abaft'}, {'balonea', 'abalone'}, {'abandoner', 'reabandon'}, {'abanic', 'bianca'}, {'abaris', 'arabis'}, {'abas', 'saba'}, {'abrase', 'abaser'}, {'ateba', 'batea', 'beata', 'abate'}, {'trabea', 'abater', 'eartab', 'artabe'}, {'abb', 'bab'}, {'baba', 'abba'}, {'bebay', 'abbey'}, {'abby', 'baby'}, {'batad', 'abdat'}, {'baldie', 'abdiel'}, {'abdominovaginal', 'vaginoabdominal'}, {'abdominovesical', 'vesicoabdominal'}, {'abe', 'bea', 'bae'}, {'abed', 'bade', 'bead'}, {'beal', 'able', 'albe', 'bale', 'abel', 'bela', 'blae'}, {'abele', 'albee'}, {'abelian', 'nebalia'}, {'bicrenate', 'abenteric'}, {'baiera', 'aberia', 'baeria'}, {'abet', 'bate', 'beta', 'beat'}, {'abetment', 'batement'}, {'taboret', 'abettor'}, {'earthborn', 'abhorrent'}, {'abhorrer', 'harborer'}, {'bardie', 'abider'}, {'abies', 'beisa'}, {'labial', 'abilla'}, {'aboil', 'abilo'}, {'rabi', 'abir', 'bari'}, {'bastion', 'abiston'}, {'aubrite', 'biurate', 'rubiate', 'abiuret'}, {'abkar', 'arkab'}, {'abkhas', 'kasbah'}, {'ablactate', 'cabaletta'}, {'arbela', 'arable', 'ablare'}, {'masticable', 'ablastemic'}, {'ablation', 'obtainal'}, {'tabula', 'ablaut'}, {'ableness', 'blaeness', 'sensable'}, {'ablepsia', 'epibasal'}, {'belar', 'blear', 'blare', 'abler', 'baler'}, {'tables', 'ablest', 'stable'}, {'mabolo', 'abloom'}, {'ablow', 'bowla', 'balow'}, {'ablude', 'belaud'}, {'tunable', 'abluent'}, {'abutilon', 'ablution'}, {'yalb', 'ably', 'blay'}, {'abmho', 'abohm'}, {'arneb', 'reban', 'abner'}, {'abnet', 'beant'}, {'boa', 'abo'}, {'aborad', 'aboard', 'abroad'}, {'abode', 'adobe'}, {'abolisher', 'reabolish'}, {'abongo', 'gaboon'}, {'aboral', 'arbalo'}, {'board', 'dorab', 'broad', 'bardo', 'dobra', 'abord'}, {'abort', 'tabor'}, {'aborticide', 'bacterioid'}, {'abortient', 'torbanite'}, {'taborin', 'abortin'}, {'robotian', 'abortion'}, {'abortive', 'bravoite'}, {'abouts', 'basuto'}, {'abram', 'ambar'}, {'abramis', 'arabism'}, {'abrasax', 'abraxas'}, {'abrasion', 'sorabian'}, {'abrastol', 'albatros'}, {'abreact', 'cabaret', 'bractea'}, {'berat', 'abret', 'bater'}, {'abridge', 'brigade'}, {'birma', 'abrim'}, {'brian', 'abrin', 'bairn', 'rabin', 'brain'}, {'abristle', 'libertas'}, {'baritone', 'abrotine', 'reobtain', 'obtainer'}, {'bursa', 'subra', 'abrus'}, {'absalom', 'balsamo'}, {'scabies', 'abscise'}, {'basten', 'absent'}, {'reabsent', 'absenter'}, {'isba', 'bias', 'bais', 'absi'}, {'batis', 'absit'}, {'absmho', 'absohm'}, {'reabsorb', 'absorber'}, {'barpost', 'absorpt'}, {'abthain', 'habitan'}, {'baculi', 'abulic'}, {'tuba', 'tabu', 'abut'}, {'bauta', 'abuta'}, {'bay', 'aby'}, {'balsamy', 'abysmal'}, {'acetamide', 'academite'}, {'acedia', 'adicea', 'acadie'}, {'acephal', 'acaleph'}, {'acephala', 'acalepha'}, {'apalachee', 'acalephae'}, {'acalephan', 'acephalan'}, {'calyptratae', 'acalyptrate'}, {'maraca', 'acamar', 'camara'}, {'tanach', 'anchat', 'acanth'}, {'acanthia', 'achatina'}, {'calathian', 'acanthial'}, {'acanthin', 'chinanta'}, {'araca', 'acara'}, {'arcadia', 'acardia', 'acarida'}, {'acarina', 'acarian', 'acrania'}, {'carida', 'acarid', 'cardia'}, {'arecain', 'acarine', 'acraein'}, {'astacus', 'acastus'}, {'acatholic', 'chaotical'}, {'ecaudata', 'acaudate'}, {'caca', 'acca'}, {'accelerator', 'retrocaecal'}, {'acception', 'peccation'}, {'accessioner', 'reaccession'}, {'preascitic', 'accipitres'}, {'acetic', 'accite'}, {'acclinate', 'analectic'}, {'accoil', 'calico'}, {'accomplisher', 'reaccomplish'}, {'compact', 'accompt'}, {'accorder', 'reaccord'}, {'ccoya', 'accoy'}, {'neoarctic', 'anorectic', 'accretion'}, {'carucal', 'accrual'}, {'accurate', 'carucate'}, {'accurse', 'accuser'}, {'subcaecal', 'accusable'}, {'accused', 'succade'}, {'acedy', 'decay'}, {'nearctic', 'encratic', 'acentric'}, {'courtesan', 'nectarous', 'acentrous'}, {'phacelia', 'acephali'}, {'acephalina' ...

# %%
# loop over anagram sets, and over all possible pairs of words in each set:
# if the second word equals the reverse of the first, add pair to list

pairs = []

for wordset in anagrams_by_sig.values():
    for word1 in wordset:
        for word2 in wordset:  
            # consider only sorted pairs to avoid duplicate matches
            if word1 >= word2 and word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ala', 'ala'),
#  ('ama', 'ama'),
#  ('ba', 'ab'),
#  ('aba', 'aba'),
#  ('caba', 'abac'),
#  ('saba', 'abas'),
#  ('bab', 'bab'),
#  ('abba', 'abba'),
#  ('yalb', 'blay'),
#  ('isba', 'absi'),
#  ('tuba', 'abut'),
#  ('araca', 'acara'),
#  ('acca', 'acca'),
#  ('dirca', 'acrid'),
#  ('da', 'ad'),
#  ('dada', 'adad'),
#  ('adda', 'adda'),
#  ('rada', 'adar'),
#  ('dad', 'dad'),
#  ('duad', 'daud'),
#  ('teda', 'adet'),
#  ('naid', 'dian'),
#  ('namda', 'adman'),
#  ('oda', 'ado'),
#  ('yard', 'dray'),
#  ('yad', 'day'),
#  ('ea', 'ae'),
#  ('era', 'are'),
#  ('rea', 'aer'),
#  ('sea', 'aes'),
#  ('alga', 'agla'),
#  ('amaga', 'agama'),
#  ('raga', 'agar'),
#  ('regga', 'agger'),
#  ('biga', 'agib'),
#  ('morga', 'agrom'),
#  ('tsuga', 'agust'),
#  ('ha', 'ah'),
#  ('moha', 'ahom'),
#  ('tha', 'aht'),
#  ('redia', 'aider'),
#  ('elia', 'aile'),
#  ('ima', 'ami'),
#  ('ria', 'air'),
#  ('aria', 'aira'),
#  ('eria', 'aire'),
#  ('ita', 'ati'),
#  ('raja', 'ajar'),
#  ('ka', 'ak'),
#  ('akka', 'akka'),
#  ('oka', 'ako'),
#  ('kua', 'auk'),
#  ('la', 'al'),
#  ('lana', 'anal'),
#  ('lab', 'bal'),
#  ('nabal', 'laban'),
#  ('nabla', 'alban'),
#  ('mela', 'alem'),
#  ('nael', 'lean'),
#  ('lina', 'anil'),
#  ('yalla', 'allay'),
#  ('ella', 'alle'),
#  ('muilla', 'allium'),
#  ('amla', 'alma'),
#  ('lamina', 'animal'),
#  ('dola', 'alod'),
#  ('lowa', 'awol'),
#  ('pal', 'lap'),
#  ('tal', 'lat'),
#  ('ma', 'am'),
#  ('apama', 'amapa'),
#  ('rama', 'amar'),
#  ('diorama', 'amaroid'),
#  ('massa', 'assam'),
#  ('samas', 'samas'),
#  ('enema', 'amene'),
#  ('ulema', 'amelu'),
#  ('mane', 'enam'),
#  ('nema', 'amen'),
#  ('xema', 'amex'),
#  ('decima', 'amiced'),
#  ('lima', 'amil'),
#  ('naim', 'mian'),
#  ('rima', 'amir'),
#  ('amma', 'amma'),
#  ('maam', 'maam'),
#  ('soma', 'amos'),
#  ('tam', 'mat'),
#  ('manuma', 'amunam'),
#  ('yam', 'may'),
#  ('na', 'an'),
#  ('ana', 'ana'),
#  ('aracana', 'anacara'),
#  ('mana', 'anam'),
#  ('nana', 'anan'),
#  ('anna', 'anna'),
#  ('asana', 'anasa'),
#  ('tana', 'anat'),
#  ('yana', 'anay'),
#  ('edna', 'ande'),
#  ('rogan', 'nagor'),
#  ('sain', 'nias'),
#  ('sina', 'anis'),
#  ('nan', 'nan'),
#  ('manna', 'annam'),
#  ('nona', 'anon'),
#  ('tan', 'nat'),
#  ('taen', 'neat'),
#  ('etna', 'ante'),
#  ('tuan', 'naut'),
#  ('yan', 'nay'),
#  ('trapa', 'apart'),
#  ('dopa', 'apod'),
#  ('tap', 'pat'),
#  ('supa', 'apus'),
#  ('ra', 'ar'),
#  ('bara', 'arab'),
#  ('read', 'daer'),
#  ('sagra', 'argas'),
#  ('regal', 'lager'),
#  ('lira', 'aril'),
#  ('rail', 'liar'),
#  ('rial', 'lair'),
#  ('kra', 'ark'),
#  ('ram', 'mar'),
#  ('ran', 'nar'),
#  ('ora', 'aro'),
#  ('sarra', 'arras'),
#  ('tracer', 'recart'),
#  ('sirrah', 'harris'),
#  ('tra', 'art'),
#  ('tar', 'rat'),
#  ('sumatra', 'artamus'),
#  ('ura', 'aru'),
#  ('mura', 'arum'),
#  ('yar', 'ray'),
#  ('rayan', 'nayar'),
#  ('lyra', 'aryl'),
#  ('sa', 'as'),
#  ('asa', 'asa'),
#  ('kasa', 'asak'),
#  ('mesa', 'asem'),
#  ('sark', 'kras'),
#  ('rosa', 'asor'),
#  ('ta', 'at'),
#  ('ata', 'ata'),
#  ('pata', 'atap'),
#  ('tae', 'eat'),
#  ('eta', 'ate'),
#  ('seta', 'ates'),
#  ('pita', 'atip'),
#  ('sita', 'atis'),
#  ('salta', 'atlas'),
#  ('teal', 'laet'),
#  ('tael', 'leat'),
#  ('lakota', 'atokal'),
#  ('laud', 'dual'),
#  ('ulua', 'aulu'),
#  ('etua', 'aute'),
#  ('lava', 'aval'),
#  ('eva', 'ave'),
#  ('diva', 'avid'),
#  ('siva', 'avis'),
#  ('ova', 'avo'),
#  ('wa', 'aw'),
#  ('tawa', 'awat'),
#  ('wad', 'daw'),
#  ('wan', 'naw'),
#  ('noxa', 'axon'),
#  ('ya', 'ay'),
#  ('haya', 'ayah'),
#  ('cab', 'bac'),
#  ('dab', 'bad'),
#  ('gab', 'bag'),
#  ('mab', 'bam'),
#  ('nab', 'ban'),
#  ('knab', 'bank'),
#  ('rab', 'bar'),
#  ('brab', 'barb'),
#  ('drab', 'bard'),
#  ('sab', 'bas'),
#  ('stab', 'bats'),
#  ('tab', 'bat'),
#  ('kitab', 'batik'),
#  ('wab', 'baw'),
#  ('deb', 'bed'),
#  ('dieb', 'beid'),
#  ('treble', 'elbert'),
#  ('neb', 'ben'),
#  ('reb', 'ber'),
#  ('dib', 'bid'),
#  ('gib', 'big'),
#  ('mib', 'bim'),
#  ('nib', 'bin'),
#  ('drib', 'bird'),
#  ('sib', 'bis'),
#  ('tib', 'bit'),
#  ('bulb', 'blub'),
#  ('cabob', 'bobac'),
#  ('boob', 'boob'),
#  ('dob', 'bod'),
#  ('doob', 'bood'),
#  ('gob', 'bog'),
#  ('rohob', 'bohor'),
#  ('obol', 'lobo'),
#  ('mob', 'bom'),
#  ('nob', 'bon'),
#  ('knob', 'bonk'),
#  ('pob', 'bop'),
#  ('rob', 'bor'),
#  ('rerob', 'borer'),
#  ('gorb', 'brog'),
#  ('sob', 'bos'),
#  ('wob', 'bow'),
#  ('garb', 'brag'),
#  ('yarb', 'bray'),
#  ('yerb', 'brey'),
#  ('trub', 'burt'),
#  ('turb', 'brut'),
#  ('tuber', 'rebut'),
#  ('dub', 'bud'),
#  ('nub', 'bun'),
#  ('knub', 'bunk'),
#  ('rub', 'bur'),
#  ('drub', 'burd'),
#  ('grub', 'burg'),
#  ('rubor', 'robur'),
#  ('suber', 'rebus'),
#  ('sub', 'bus'),
#  ('tub', 'but'),
#  ('ecad', 'dace'),
#  ('lac', 'cal'),
#  ('mac', 'cam'),
#  ('sumac', 'camus'),
#  ('pac', 'cap'),
#  ('paced', 'decap'),
#  ('recap', 'pacer'),
#  ('wac', 'caw'),
#  ('spec', 'ceps'),
#  ('tic', 'cit'),
#  ('talc', 'clat'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('orc', 'cro'),
#  ('roc', 'cor'),
#  ('soc', 'cos'),
#  ('marc', 'cram'),
#  ('eruc', 'cure'),
#  ('gad', 'dag'),
#  ('sgad', 'dags'),
#  ('had', 'dah'),
#  ('laid', 'dial'),
#  ('radek', 'kedar'),
#  ('lad', 'dal'),
#  ('mad', 'dam'),
#  ('nomad', 'damon'),
#  ('nidal', 'ladin'),
#  ('pad', 'dap'),
#  ('rad', 'dar'),
#  ('farad', 'daraf'),
#  ('grad', 'darg'),
#  ('ranid', 'dinar'),
#  ('strad', 'darts'),
#  ('trader', 'redart'),
#  ('retrad', 'darter'),
#  ('sad', 'das'),
#  ('rated', 'detar'),
#  ('ed', 'de'),
#  ('meed', 'deem'),
#  ('peed', 'deep'),
#  ('reed', 'deer'),
#  ('ged', 'deg'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('timed', 'demit'),
#  ('ned', 'den'),
#  ('hoped', 'depoh'),
#  ('tressed', 'dessert'),
#  ('leud', 'duel'),
#  ('lived', 'devil'),
#  ('wed', 'dew'),
#  ('rewed', 'dewer'),
#  ('yed', 'dey'),
#  ('id', 'di'),
#  ('morbid', 'dibrom'),
#  ('reid', 'dier'),
#  ('tide', 'edit'),
#  ('gid', 'dig'),
#  ('olid', 'dilo'),
#  ('mid', 'dim'),
#  ('timid', 'dimit'),
#  ('nid', 'din'),
#  ('enid', 'dine'),
#  ('sid', 'dis'),
#  ('tid', 'dit'),
#  ('od', 'do'),
#  ('dod', 'dod'),
#  ('ode', 'edo'),
#  ('god', 'dog'),
#  ('lod', 'dol'),
#  ('elod', 'dole'),
#  ('mod', 'dom'),
#  ('nod', 'don'),
#  ('lood', 'dool'),
#  ('mood', 'doom'),
#  ('redoom', 'mooder'),
#  ('rood', 'door'),
#  ('pod', 'dop'),
#  ('rod', 'dor'),
#  ('prod', 'dorp'),
#  ('sod', 'dos'),
#  ('tod', 'dot'),
#  ('wod', 'dow'),
#  ('liard', 'drail'),
#  ('ward', 'draw'),
#  ('reward', 'drawer'),
#  ('warder', 'redraw'),
#  ('word', 'drow'),
#  ('gud', 'dug'),
#  ('mud', 'dum'),
#  ('pud', 'dup'),
#  ('nae', 'ean'),
#  ('notice', 'eciton'),
#  ('lee', 'eel'),
#  ('ree', 'eer'),
#  ('ere', 'ere'),
#  ('loge', 'egol'),
#  ('he', 'eh'),
#  ('eke', 'eke'),
#  ('spale', 'elaps'),
#  ('nifle', 'elfin'),
#  ('haole', 'eloah'),
#  ('lone', 'enol'),
#  ('noel', 'leon'),
#  ('spole', 'elops'),
#  ('seel', 'lees'),
#  ('revel', 'lever'),
#  ('me', 'em'),
#  ('lime', 'emil'),
#  ('mime', 'emim'),
#  ('remi', 'imer'),
#  ('rime', 'emir'),
#  ('time', 'emit'),
#  ('mem', 'mem'),
#  ('ume', 'emu'),
#  ('ne', 'en'),
#  ('romane', 'enamor'),
#  ('reman', 'namer'),
#  ('fine', 'enif'),
#  ('wone', 'enow'),
#  ('esne', 'ense'),
#  ('yoven', 'nevoy'),
#  ('sope', 'epos'),
#  ('re', 'er'),
#  ('reg', 'ger'),
#  ('reen', 'neer'),
#  ('sore', 'eros'),
#  ('retier', 'reiter'),
#  ('seer', 'rees'),
#  ('se', 'es'),
#  ('nave', 'evan'),
#  ('eve', 'eve'),
#  ('neve', 'even'),
#  ('reve', 'ever'),
#  ('live', 'evil'),
#  ('ewe', 'ewe'),
#  ('ye', 'ey'),
#  ('eye', 'eye'),
#  ('nye', 'eyn'),
#  ('raif', 'fiar'),
#  ('reef', 'feer'),
#  ('lief', 'feil'),
#  ('nef', 'fen'),
#  ('if', 'fi'),
#  ('gif', 'fig'),
#  ('welf', 'flew'),
#  ('golf', 'flog'),
#  ('wolf', 'flow'),
#  ('wolfer', 'reflow'),
#  ('of', 'fo'),
#  ('ofo', 'ofo'),
#  ('loof', 'fool'),
#  ('stoof', 'foots'),
#  ('orf', 'fro'),
#  ('refer', 'refer'),
#  ('jag', 'gaj'),
#  ('lag', 'gal'),
#  ('mag', 'gam'),
#  ('nag', 'gan'),
#  ('nagnag', 'gangan'),
#  ('tang', 'gnat'),
#  ('rag', 'gar'),
#  ('rang', 'gnar'),
#  ('sag', 'gas'),
#  ('tag', 'gat'),
#  ('retag', 'gater'),
#  ('wag', 'gaw'),
#  ('wang', 'gnaw'),
#  ('zag', 'gaz'),
#  ('leg', 'gel'),
#  ('redleg', 'gelder'),
#  ('meg', 'gem'),
#  ('seg', 'ges'),
#  ('teg', 'get'),
#  ('mig', 'gim'),
#  ('nig', 'gin'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('tig', 'git'),
#  ('og', 'go'),
#  ('log', 'gol'),
#  ('reflog', 'golfer'),
#  ('nog', 'gon'),
#  ('rog', 'gor'),
#  ('sog', 'gos'),
#  ('tog', 'got'),
#  ('upgo', 'ogpu'),
#  ('lug', 'gul'),
#  ('plug', 'gulp'),
#  ('mug', 'gum'),
#  ('pug', 'gup'),
#  ('rug', 'gur'),
#  ('trug', 'gurt'),
#  ('tug', 'gut'),
#  ('makah', 'hakam'),
#  ('nallah', 'hallan'),
#  ('mah', 'ham'),
#  ('pah', 'hap'),
#  ('trah', 'hart'),
#  ('wah', 'haw'),
#  ('yah', 'hay'),
#  ('reh', 'her'),
#  ('oh', 'ho'),
#  ('pooh', 'hoop'),
#  ('poh', 'hop'),
#  ('obi', 'ibo'),
#  ('immi', 'immi'),
#  ('ni', 'in'),
#  ('retin', 'niter'),
#  ('tennis', 'sinnet'),
#  ('nori', 'iron'),
#  ('kori', 'irok'),
#  ('si', 'is'),
#  ('sisi', 'isis'),
#  ('ti', 'it'),
#  ('neti', 'iten'),
#  ('tier', 'reit'),
#  ('timo', 'omit'),
#  ('raj', 'jar'),
#  ('taj', 'jat'),
#  ('nak', 'kan'),
#  ('panak', 'kanap'),
#  ('tanak', 'kanat'),
#  ('lark', 'kral'),
#  ('yak', 'kay'),
#  ('kayak', 'kayak'),
#  ('leek', 'keel'),
#  ('peek', 'keep'),
#  ('seek', 'kees'),
#  ('pik', 'kip'),
#  ('polk', 'klop'),
#  ('pank', 'knap'),
#  ('rank', 'knar'),
#  ('nark', 'kran'),
#  ('tink', 'knit'),
#  ('tonk', 'knot'),
#  ('tunk', 'knut'),
#  ('ok', 'ko'),
#  ('rok', 'kor'),
#  ('sok', 'kos'),
#  ('rauk', 'kuar'),
#  ('mal', 'lam'),
#  ('nopal', 'lapon'),
#  ('plap', 'palp'),
#  ('sural', 'larus'),
#  ('sal', 'las'),
#  ('sail', 'lias'),
#  ('ossal', 'lasso'),
#  ('peel', 'leep'),
#  ('reel', 'leer'),
#  ('teel', 'leet'),
#  ('repel', 'leper'),
#  ('relap', 'paler'),
#  ('rel', 'ler'),
#  ('relevel', 'leveler'),
#  ('rivel', 'levir'),
#  ('neil', 'lien'),
#  ('mil', 'lim'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('sunil', 'linus'),
#  ('sil', 'lis'),
#  ('til', 'lit'),
#  ('well', 'llew'),
#  ('olam', 'malo'),
#  ('siol', 'lois'),
#  ('mool', 'loom'),
#  ('pool', 'loop'),
#  ('tool', 'loot'),
#  ('retool', 'looter'),
#  ('pol', 'lop'),
#  ('tol', 'lot'),
#  ('owl', 'lwo'),
#  ('nam', 'man'),
#  ('senam', 'manes'),
#  ('oam', 'mao'),
#  ('pam', 'map'),
#  ('tram', 'mart'),
#  ('sam', 'mas'),
#  ('stam', 'mats'),
#  ('teem', 'meet'),
#  ('teemer', 'remeet'),
#  ('timer', 'remit'),
#  ('retem', 'meter'),
#  ('wem', 'mew'),
#  ('ohm', 'mho'),
#  ('saim', 'mias'),
#  ('nim', 'min'),
#  ('rim', 'mir'),
#  ('om', 'mo'),
#  ('sloom', 'mools'),
#  ('room', 'moor'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('tom', 'mot'),
#  ('yom', 'moy'),
#  ('um', 'mu'),
#  ('sum', 'mus'),
#  ('ym', 'my'),
#  ('rohan', 'nahor'),
#  ('zaman', 'namaz'),
#  ('pan', 'nap'),
#  ('susan', 'nasus'),
#  ('redden', 'nedder'),
#  ('peen', 'neep'),
#  ('teen', 'neet'),
#  ('pen', 'nep'),
#  ('repen', 'neper'),
#  ('ten', 'net'),
#  ('oven', 'nevo'),
#  ('wen', 'new'),
#  ('pin', 'nip'),
#  ('tin', 'nit'),
#  ('on', 'no'),
#  ('tenon', 'nonet'),
#  ('poon', 'noop'),
#  ('ron', 'nor'),
#  ('ton', 'not'),
#  ('won', 'now'),
#  ('yon', 'noy'),
#  ('un', 'nu'),
#  ('tun', 'nut'),
#  ('tao', 'oat'),
#  ('senones', 'senones'),
#  ('top', 'pot'),
#  ('ro', 'or'),
#  ('tor', 'rot'),
#  ('yor', 'roy'),
#  ('so', 'os'),
#  ('oto', 'oto'),
#  ('otto', 'otto'),
#  ('toot', 'toot'),
#  ('suto', 'otus'),
#  ('wo', 'ow'),
#  ('repaper', 'repaper'),
#  ('rap', 'par'),
#  ('trap', 'part'),
#  ('tarp', 'prat'),
#  ('taps', 'spat'),
#  ('wap', 'paw'),
#  ('yap', 'pay'),
#  ('rep', 'per'),
#  ('rip', 'pir'),
#  ('tip', 'pit'),
#  ('pulp', 'plup'),
#  ('toop', 'poot'),
#  ('troper', 'report'),
#  ('tops', 'spot'),
#  ('toper', 'repot'),
#  ('wop', 'pow'),
#  ('turp', 'prut'),
#  ('up', 'pu'),
#  ('sup', 'pus'),
#  ('tup', 'put'),
#  ('sar', 'ras'),
#  ('war', 'raw'),
#  ('rewarder', 'redrawer'),
#  ('teer', 'reet'),
#  ('sier', 'reis'),
#  ('tinker', 'reknit'),
#  ('tenner', 'rennet'),
#  ('terret', 'terret'),
#  ('retter', 'retter'),
#  ('rever', 'rever'),
#  ('tewer', 'rewet'),
#  ('venator', 'rotanev'),
#  ('sur', 'rus'),
#  ('tur', 'rut'),
#  ('was', 'saw'),
#  ('twas', 'sawt'),
#  ('taws', 'swat'),
#  ('yas', 'say'),
#  ('wes', 'sew'),
#  ('yes', 'sey'),
#  ('sis', 'sis'),
#  ('wels', 'slew'),
#  ('wots', 'stow'),
#  ('traps', 'spart'),
#  ('sus', 'sus'),
#  ('tuts', 'stut'),
#  ('yaws', 'sway'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('yat', 'tay'),
#  ('teet', 'teet'),
#  ('wet', 'tew'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('yot', 'toy'),
#  ('wort', 'trow'),
#  ('ut', 'tu'),
#  ('yaw', 'way'),
#  ('yew', 'wey'),
#  ('yow', 'woy')]

# %%
import itertools

# %%
# list all combinations of two different elements from the set {1,2,3} 
list(itertools.combinations({1,2,3}, 2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
# same as above, using itertools.combinations to generate unique pairs

pairs = []

for wordset in anagrams_by_sig.values():
    for word1, word2 in itertools.combinations(wordset, 2):
        if word1[::-1] == word2:
            pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ab', 'ba'),
#  ('caba', 'abac'),
#  ('abas', 'saba'),
#  ('yalb', 'blay'),
#  ('isba', 'absi'),
#  ('tuba', 'abut'),
#  ('araca', 'acara'),
#  ('dirca', 'acrid'),
#  ('da', 'ad'),
#  ('dada', 'adad'),
#  ('adar', 'rada'),
#  ('daud', 'duad'),
#  ('adet', 'teda'),
#  ('dian', 'naid'),
#  ('namda', 'adman'),
#  ('oda', 'ado'),
#  ('yard', 'dray'),
#  ('day', 'yad'),
#  ('ea', 'ae'),
#  ('aer', 'rea'),
#  ('era', 'are'),
#  ('aes', 'sea'),
#  ('alga', 'agla'),
#  ('agama', 'amaga'),
#  ('raga', 'agar'),
#  ('regga', 'agger'),
#  ('biga', 'agib'),
#  ('morga', 'agrom'),
#  ('tsuga', 'agust'),
#  ('ah', 'ha'),
#  ('moha', 'ahom'),
#  ('tha', 'aht'),
#  ('aider', 'redia'),
#  ('elia', 'aile'),
#  ('ami', 'ima'),
#  ('ria', 'air'),
#  ('aria', 'aira'),
#  ('aire', 'eria'),
#  ('ati', 'ita'),
#  ('ajar', 'raja'),
#  ('ak', 'ka'),
#  ('oka', 'ako'),
#  ('kua', 'auk'),
#  ('al', 'la'),
#  ('lana', 'anal'),
#  ('lab', 'bal'),
#  ('alban', 'nabla'),
#  ('nabal', 'laban'),
#  ('alem', 'mela'),
#  ('nael', 'lean'),
#  ('lina', 'anil'),
#  ('allay', 'yalla'),
#  ('ella', 'alle'),
#  ('allium', 'muilla'),
#  ('alma', 'amla'),
#  ('animal', 'lamina'),
#  ('alod', 'dola'),
#  ('awol', 'lowa'),
#  ('lap', 'pal'),
#  ('lat', 'tal'),
#  ('ma', 'am'),
#  ('amapa', 'apama'),
#  ('rama', 'amar'),
#  ('diorama', 'amaroid'),
#  ('massa', 'assam'),
#  ('enema', 'amene'),
#  ('amelu', 'ulema'),
#  ('enam', 'mane'),
#  ('amen', 'nema'),
#  ('xema', 'amex'),
#  ('decima', 'amiced'),
#  ('lima', 'amil'),
#  ('naim', 'mian'),
#  ('rima', 'amir'),
#  ('amos', 'soma'),
#  ('tam', 'mat'),
#  ('manuma', 'amunam'),
#  ('yam', 'may'),
#  ('na', 'an'),
#  ('anacara', 'aracana'),
#  ('anam', 'mana'),
#  ('nana', 'anan'),
#  ('asana', 'anasa'),
#  ('tana', 'anat'),
#  ('yana', 'anay'),
#  ('edna', 'ande'),
#  ('rogan', 'nagor'),
#  ('sain', 'nias'),
#  ('anis', 'sina'),
#  ('manna', 'annam'),
#  ('anon', 'nona'),
#  ('tan', 'nat'),
#  ('taen', 'neat'),
#  ('ante', 'etna'),
#  ('naut', 'tuan'),
#  ('yan', 'nay'),
#  ('trapa', 'apart'),
#  ('dopa', 'apod'),
#  ('pat', 'tap'),
#  ('apus', 'supa'),
#  ('ar', 'ra'),
#  ('arab', 'bara'),
#  ('read', 'daer'),
#  ('argas', 'sagra'),
#  ('regal', 'lager'),
#  ('lira', 'aril'),
#  ('liar', 'rail'),
#  ('rial', 'lair'),
#  ('kra', 'ark'),
#  ('ram', 'mar'),
#  ('ran', 'nar'),
#  ('aro', 'ora'),
#  ('sarra', 'arras'),
#  ('recart', 'tracer'),
#  ('harris', 'sirrah'),
#  ('art', 'tra'),
#  ('rat', 'tar'),
#  ('artamus', 'sumatra'),
#  ('ura', 'aru'),
#  ('arum', 'mura'),
#  ('ray', 'yar'),
#  ('rayan', 'nayar'),
#  ('lyra', 'aryl'),
#  ('as', 'sa'),
#  ('kasa', 'asak'),
#  ('mesa', 'asem'),
#  ('kras', 'sark'),
#  ('asor', 'rosa'),
#  ('ta', 'at'),
#  ('atap', 'pata'),
#  ('ate', 'eta'),
#  ('tae', 'eat'),
#  ('ates', 'seta'),
#  ('pita', 'atip'),
#  ('atis', 'sita'),
#  ('atlas', 'salta'),
#  ('leat', 'tael'),
#  ('teal', 'laet'),
#  ('lakota', 'atokal'),
#  ('laud', 'dual'),
#  ('aulu', 'ulua'),
#  ('etua', 'aute'),
#  ('lava', 'aval'),
#  ('eva', 'ave'),
#  ('avid', 'diva'),
#  ('avis', 'siva'),
#  ('avo', 'ova'),
#  ('wa', 'aw'),
#  ('tawa', 'awat'),
#  ('daw', 'wad'),
#  ('wan', 'naw'),
#  ('noxa', 'axon'),
#  ('ya', 'ay'),
#  ('ayah', 'haya'),
#  ('cab', 'bac'),
#  ('bad', 'dab'),
#  ('gab', 'bag'),
#  ('bam', 'mab'),
#  ('nab', 'ban'),
#  ('knab', 'bank'),
#  ('rab', 'bar'),
#  ('barb', 'brab'),
#  ('drab', 'bard'),
#  ('bas', 'sab'),
#  ('bats', 'stab'),
#  ('tab', 'bat'),
#  ('batik', 'kitab'),
#  ('baw', 'wab'),
#  ('bed', 'deb'),
#  ('beid', 'dieb'),
#  ('treble', 'elbert'),
#  ('ben', 'neb'),
#  ('reb', 'ber'),
#  ('bid', 'dib'),
#  ('big', 'gib'),
#  ('bim', 'mib'),
#  ('bin', 'nib'),
#  ('drib', 'bird'),
#  ('sib', 'bis'),
#  ('bit', 'tib'),
#  ('bulb', 'blub'),
#  ('cabob', 'bobac'),
#  ('dob', 'bod'),
#  ('bood', 'doob'),
#  ('bog', 'gob'),
#  ('bohor', 'rohob'),
#  ('lobo', 'obol'),
#  ('bom', 'mob'),
#  ('bon', 'nob'),
#  ('knob', 'bonk'),
#  ('pob', 'bop'),
#  ('rob', 'bor'),
#  ('rerob', 'borer'),
#  ('gorb', 'brog'),
#  ('sob', 'bos'),
#  ('bow', 'wob'),
#  ('garb', 'brag'),
#  ('yarb', 'bray'),
#  ('yerb', 'brey'),
#  ('trub', 'burt'),
#  ('brut', 'turb'),
#  ('tuber', 'rebut'),
#  ('dub', 'bud'),
#  ('bun', 'nub'),
#  ('bunk', 'knub'),
#  ('bur', 'rub'),
#  ('drub', 'burd'),
#  ('grub', 'burg'),
#  ('robur', 'rubor'),
#  ('rebus', 'suber'),
#  ('sub', 'bus'),
#  ('tub', 'but'),
#  ('ecad', 'dace'),
#  ('lac', 'cal'),
#  ('cam', 'mac'),
#  ('camus', 'sumac'),
#  ('pac', 'cap'),
#  ('paced', 'decap'),
#  ('pacer', 'recap'),
#  ('wac', 'caw'),
#  ('ceps', 'spec'),
#  ('tic', 'cit'),
#  ('talc', 'clat'),
#  ('laced', 'decal'),
#  ('doc', 'cod'),
#  ('orc', 'cro'),
#  ('cor', 'roc'),
#  ('soc', 'cos'),
#  ('marc', 'cram'),
#  ('eruc', 'cure'),
#  ('dag', 'gad'),
#  ('dags', 'sgad'),
#  ('dah', 'had'),
#  ('laid', 'dial'),
#  ('kedar', 'radek'),
#  ('lad', 'dal'),
#  ('dam', 'mad'),
#  ('damon', 'nomad'),
#  ('ladin', 'nidal'),
#  ('dap', 'pad'),
#  ('rad', 'dar'),
#  ('daraf', 'farad'),
#  ('darg', 'grad'),
#  ('ranid', 'dinar'),
#  ('strad', 'darts'),
#  ('trader', 'redart'),
#  ('retrad', 'darter'),
#  ('das', 'sad'),
#  ('detar', 'rated'),
#  ('de', 'ed'),
#  ('meed', 'deem'),
#  ('deep', 'peed'),
#  ('reed', 'deer'),
#  ('ged', 'deg'),
#  ('led', 'del'),
#  ('fled', 'delf'),
#  ('demit', 'timed'),
#  ('den', 'ned'),
#  ('hoped', 'depoh'),
#  ('tressed', 'dessert'),
#  ('duel', 'leud'),
#  ('lived', 'devil'),
#  ('wed', 'dew'),
#  ('rewed', 'dewer'),
#  ('yed', 'dey'),
#  ('di', 'id'),
#  ('dibrom', 'morbid'),
#  ('reid', 'dier'),
#  ('edit', 'tide'),
#  ('dig', 'gid'),
#  ('olid', 'dilo'),
#  ('mid', 'dim'),
#  ('timid', 'dimit'),
#  ('din', 'nid'),
#  ('enid', 'dine'),
#  ('dis', 'sid'),
#  ('tid', 'dit'),
#  ('do', 'od'),
#  ('ode', 'edo'),
#  ('dog', 'god'),
#  ('lod', 'dol'),
#  ('dole', 'elod'),
#  ('mod', 'dom'),
#  ('nod', 'don'),
#  ('dool', 'lood'),
#  ('doom', 'mood'),
#  ('mooder', 'redoom'),
#  ('rood', 'door'),
#  ('pod', 'dop'),
#  ('rod', 'dor'),
#  ('prod', 'dorp'),
#  ('sod', 'dos'),
#  ('dot', 'tod'),
#  ('dow', 'wod'),
#  ('drail', 'liard'),
#  ('ward', 'draw'),
#  ('redraw', 'warder'),
#  ('drawer', 'reward'),
#  ('word', 'drow'),
#  ('gud', 'dug'),
#  ('mud', 'dum'),
#  ('dup', 'pud'),
#  ('ean', 'nae'),
#  ('eciton', 'notice'),
#  ('eel', 'lee'),
#  ('eer', 'ree'),
#  ('loge', 'egol'),
#  ('eh', 'he'),
#  ('elaps', 'spale'),
#  ('nifle', 'elfin'),
#  ('haole', 'eloah'),
#  ('lone', 'enol'),
#  ('noel', 'leon'),
#  ('elops', 'spole'),
#  ('lees', 'seel'),
#  ('revel', 'lever'),
#  ('em', 'me'),
#  ('emil', 'lime'),
#  ('mime', 'emim'),
#  ('remi', 'imer'),
#  ('emir', 'rime'),
#  ('emit', 'time'),
#  ('ume', 'emu'),
#  ('en', 'ne'),
#  ('romane', 'enamor'),
#  ('reman', 'namer'),
#  ('enif', 'fine'),
#  ('wone', 'enow'),
#  ('ense', 'esne'),
#  ('nevoy', 'yoven'),
#  ('sope', 'epos'),
#  ('re', 'er'),
#  ('ger', 'reg'),
#  ('neer', 'reen'),
#  ('eros', 'sore'),
#  ('retier', 'reiter'),
#  ('rees', 'seer'),
#  ('se', 'es'),
#  ('evan', 'nave'),
#  ('neve', 'even'),
#  ('reve', 'ever'),
#  ('evil', 'live'),
#  ('ey', 'ye'),
#  ('eyn', 'nye'),
#  ('fiar', 'raif'),
#  ('feer', 'reef'),
#  ('lief', 'feil'),
#  ('fen', 'nef'),
#  ('if', 'fi'),
#  ('gif', 'fig'),
#  ('welf', 'flew'),
#  ('flog', 'golf'),
#  ('wolf', 'flow'),
#  ('reflow', 'wolfer'),
#  ('of', 'fo'),
#  ('loof', 'fool'),
#  ('stoof', 'foots'),
#  ('fro', 'orf'),
#  ('gaj', 'jag'),
#  ('lag', 'gal'),
#  ('gam', 'mag'),
#  ('gan', 'nag'),
#  ('nagnag', 'gangan'),
#  ('gnat', 'tang'),
#  ('rag', 'gar'),
#  ('gnar', 'rang'),
#  ('sag', 'gas'),
#  ('gat', 'tag'),
#  ('gater', 'retag'),
#  ('gaw', 'wag'),
#  ('gnaw', 'wang'),
#  ('gaz', 'zag'),
#  ('leg', 'gel'),
#  ('redleg', 'gelder'),
#  ('meg', 'gem'),
#  ('ges', 'seg'),
#  ('get', 'teg'),
#  ('mig', 'gim'),
#  ('nig', 'gin'),
#  ('pig', 'gip'),
#  ('trig', 'girt'),
#  ('git', 'tig'),
#  ('og', 'go'),
#  ('gol', 'log'),
#  ('golfer', 'reflog'),
#  ('gon', 'nog'),
#  ('rog', 'gor'),
#  ('gos', 'sog'),
#  ('tog', 'got'),
#  ('upgo', 'ogpu'),
#  ('gul', 'lug'),
#  ('plug', 'gulp'),
#  ('mug', 'gum'),
#  ('pug', 'gup'),
#  ('gur', 'rug'),
#  ('gurt', 'trug'),
#  ('tug', 'gut'),
#  ('hakam', 'makah'),
#  ('nallah', 'hallan'),
#  ('mah', 'ham'),
#  ('pah', 'hap'),
#  ('hart', 'trah'),
#  ('haw', 'wah'),
#  ('hay', 'yah'),
#  ('her', 'reh'),
#  ('oh', 'ho'),
#  ('pooh', 'hoop'),
#  ('hop', 'poh'),
#  ('ibo', 'obi'),
#  ('in', 'ni'),
#  ('retin', 'niter'),
#  ('sinnet', 'tennis'),
#  ('iron', 'nori'),
#  ('irok', 'kori'),
#  ('si', 'is'),
#  ('sisi', 'isis'),
#  ('it', 'ti'),
#  ('neti', 'iten'),
#  ('tier', 'reit'),
#  ('omit', 'timo'),
#  ('jar', 'raj'),
#  ('jat', 'taj'),
#  ('nak', 'kan'),
#  ('panak', 'kanap'),
#  ('kanat', 'tanak'),
#  ('kral', 'lark'),
#  ('kay', 'yak'),
#  ('keel', 'leek'),
#  ('keep', 'peek'),
#  ('seek', 'kees'),
#  ('kip', 'pik'),
#  ('polk', 'klop'),
#  ('pank', 'knap'),
#  ('knar', 'rank'),
#  ('kran', 'nark'),
#  ('tink', 'knit'),
#  ('tonk', 'knot'),
#  ('tunk', 'knut'),
#  ('ok', 'ko'),
#  ('kor', 'rok'),
#  ('kos', 'sok'),
#  ('rauk', 'kuar'),
#  ('mal', 'lam'),
#  ('lapon', 'nopal'),
#  ('palp', 'plap'),
#  ('larus', 'sural'),
#  ('las', 'sal'),
#  ('sail', 'lias'),
#  ('lasso', 'ossal'),
#  ('leep', 'peel'),
#  ('reel', 'leer'),
#  ('leet', 'teel'),
#  ('leper', 'repel'),
#  ('paler', 'relap'),
#  ('ler', 'rel'),
#  ('relevel', 'leveler'),
#  ('levir', 'rivel'),
#  ('neil', 'lien'),
#  ('lim', 'mil'),
#  ('nil', 'lin'),
#  ('noil', 'lion'),
#  ('linus', 'sunil'),
#  ('sil', 'lis'),
#  ('til', 'lit'),
#  ('llew', 'well'),
#  ('olam', 'malo'),
#  ('siol', 'lois'),
#  ('mool', 'loom'),
#  ('loop', 'pool'),
#  ('loot', 'tool'),
#  ('retool', 'looter'),
#  ('pol', 'lop'),
#  ('tol', 'lot'),
#  ('lwo', 'owl'),
#  ('man', 'nam'),
#  ('manes', 'senam'),
#  ('mao', 'oam'),
#  ('map', 'pam'),
#  ('mart', 'tram'),
#  ('mas', 'sam'),
#  ('stam', 'mats'),
#  ('meet', 'teem'),
#  ('teemer', 'remeet'),
#  ('remit', 'timer'),
#  ('retem', 'meter'),
#  ('wem', 'mew'),
#  ('ohm', 'mho'),
#  ('saim', 'mias'),
#  ('min', 'nim'),
#  ('mir', 'rim'),
#  ('om', 'mo'),
#  ('sloom', 'mools'),
#  ('room', 'moor'),
#  ('toom', 'moot'),
#  ('pom', 'mop'),
#  ('tom', 'mot'),
#  ('yom', 'moy'),
#  ('um', 'mu'),
#  ('sum', 'mus'),
#  ('my', 'ym'),
#  ('nahor', 'rohan'),
#  ('zaman', 'namaz'),
#  ('pan', 'nap'),
#  ('nasus', 'susan'),
#  ('nedder', 'redden'),
#  ('peen', 'neep'),
#  ('neet', 'teen'),
#  ('pen', 'nep'),
#  ('neper', 'repen'),
#  ('net', 'ten'),
#  ('nevo', 'oven'),
#  ('wen', 'new'),
#  ('nip', 'pin'),
#  ('tin', 'nit'),
#  ('no', 'on'),
#  ('tenon', 'nonet'),
#  ('noop', 'poon'),
#  ('nor', 'ron'),
#  ('ton', 'not'),
#  ('now', 'won'),
#  ('noy', 'yon'),
#  ('un', 'nu'),
#  ('nut', 'tun'),
#  ('oat', 'tao'),
#  ('top', 'pot'),
#  ('ro', 'or'),
#  ('rot', 'tor'),
#  ('roy', 'yor'),
#  ('os', 'so'),
#  ('otus', 'suto'),
#  ('wo', 'ow'),
#  ('rap', 'par'),
#  ('trap', 'part'),
#  ('prat', 'tarp'),
#  ('spat', 'taps'),
#  ('paw', 'wap'),
#  ('yap', 'pay'),
#  ('rep', 'per'),
#  ('rip', 'pir'),
#  ('tip', 'pit'),
#  ('pulp', 'plup'),
#  ('toop', 'poot'),
#  ('troper', 'report'),
#  ('spot', 'tops'),
#  ('repot', 'toper'),
#  ('wop', 'pow'),
#  ('prut', 'turp'),
#  ('pu', 'up'),
#  ('pus', 'sup'),
#  ('tup', 'put'),
#  ('sar', 'ras'),
#  ('war', 'raw'),
#  ('rewarder', 'redrawer'),
#  ('reet', 'teer'),
#  ('reis', 'sier'),
#  ('reknit', 'tinker'),
#  ('rennet', 'tenner'),
#  ('tewer', 'rewet'),
#  ('venator', 'rotanev'),
#  ('sur', 'rus'),
#  ('rut', 'tur'),
#  ('saw', 'was'),
#  ('swat', 'taws'),
#  ('sawt', 'twas'),
#  ('say', 'yas'),
#  ('wes', 'sew'),
#  ('sey', 'yes'),
#  ('wels', 'slew'),
#  ('stow', 'wots'),
#  ('traps', 'spart'),
#  ('tuts', 'stut'),
#  ('sway', 'yaws'),
#  ('vat', 'tav'),
#  ('wat', 'taw'),
#  ('yat', 'tay'),
#  ('tew', 'wet'),
#  ('trot', 'tort'),
#  ('wot', 'tow'),
#  ('toy', 'yot'),
#  ('trow', 'wort'),
#  ('ut', 'tu'),
#  ('way', 'yaw'),
#  ('wey', 'yew'),
#  ('yow', 'woy')]
