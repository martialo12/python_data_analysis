# %% [markdown]
# # Trouver des anagrammes d'un mot

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('francais.txt', 'r')})

# %%
sorted("armée")
# Out:
# ['a', 'e', 'm', 'r', 'é']

# %%
sorted("armée") == sorted("ramée")
# Out:
# True

# %%
sorted("armée") == sorted("maré")
# Out:
# False

# %%
'-'.join(sorted("armée"))
# Out:
# 'a-e-m-r-é'

# %%
''.join(sorted("armée"))
# Out:
# 'aemré'

# %%
# compute the signature string for a word

def signature(word):
    return ''.join(sorted(word))

# %%
# brute-force anagram search: compare myword's signature
# with the signatures of all words in the dictionary

def find_anagram(myword):
    mysig = signature(myword)
    
    for word in words:
        if mysig == signature(word):
            print(word)

# %%
find_anagram('armée')
# Out:
# armée
# marée
# ramée

# %%
# %time find_anagram('armée')
# Out:
# armée
# marée
# ramée
# Wall time: 241 ms

# %%
# make a dict that maps each signature to the set of words with that signature;
# each signature will map to at least one word

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)

# %%
words_by_sig
# Out:
# defaultdict(set,
#             {'': {''},
#              'a': {'a'},
#              'ab': {'ab'},
#              'aaabiss': {'abaissa'},
#              'aaabiiss': {'abaissai'},
#              'aaabeiinsst': {'abaissaient'},
#              'aaabiisss': {'abaissais'},
#              'aaabiisst': {'abaissait'},
#              'aaabinsst': {'abaissant'},
#              'aaabisss': {'abaissas'},
#              'aaabeissss': {'abaissasse'},
#              'aaabeinsssst': {'abaissassent'},
#              'aaabeisssss': {'abaissasses'},
#              'aaabeiissssz': {'abaissassiez'},
#              'aaabiinosssss': {'abaissassions'},
#              'aabeiss': {'abaisse'},
#              'aabeeimnsst': {'abaissement'},
#              'aabeeimnssst': {'abaissements'},
#              'aabeinsst': {'abaissent', 'absentais', 'abstenais'},
#              'aabeirss': {'abaisser',
#               'baiseras',
#               'baissera',
#               'baserais',
#               'rabaisse'},
#              'aaabeirss': {'abaissera'},
#              'aaabeiirss': {'abaisserai'},
#              'aaabeeiinrsst': {'abaisseraient'},
#              'aaabeiirsss': {'abaisserais'},
#              'aaabeiirsst': {'abaisserait'},
#              'aaabeirsss': {'abaisseras'},
#              'aabeeirssz': {'abaisserez'},
#              'aabeeiirssz': {'abaisseriez'},
#              'aabeiinorsss': {'abaisserions'},
#              'aabeinorsss': {'abaisserons'},
#              'aabeinorsst': {'abaisseront'},
#              'aabeisss': {'abaisses', 'baisasse'},
#              'aabeirssu': {'abaisseur', 'abuserais'},
#              'aabeirsssu': {'abaisseurs'},
#              'aabeissz': {'abaissez'},
#              'aabeiissz': {'abaissiez'},
#              'aabiinosss': {'abaissions'},
#              'aabinosss': {'abaissons'},
#              'aabeimsssâ': {'abaissâmes'},
#              'aabisstâ': {'abaissât'},
#              'aabeissstâ': {'abaissâtes'},
#              'aabeinrsstè': {'abaissèrent'},
#              'aabissé': {'abaissé'},
#              'aabeissé': {'abaissée'},
#              'aabeisssé': {'abaissées'},
#              'aabisssé': {'abaissés'},
#              'aabdnno': {'abandon'},
#              'aaabdnnno': {'abandonna'},
#              'aaabdinnno': {'abandonnai'},
#              'aaabdeinnnnot': {'abandonnaient'},
#              'aaabdinnnos': {'abandonnais'},
#              'aaabdinnnot': {'abandonnait'},
#              'aaabdnnnnot': {'abandonnant'},
#              'aaabdnnnos': {'abandonnas'},
#              'aaabdennnoss': {'abandonnasse'},
#              'aaabdennnnosst': {'abandonnassent'},
#              'aaabdennnosss': {'abandonnasses'},
#              'aaabdeinnnossz': {'abandonnassiez'},
#              'aaabdinnnnoosss': {'abandonnassions'},
#              'aabdennno': {'abandonne'},
#              'aabdennnnot': {'abandonnent'},
#              'aabdennnor': {'abandonner'},
#              'aaabdennnor': {'abandonnera'},
#              'aaabdeinnnor': {'abandonnerai'},
#              'aaabdeeinnnnort': {'abandonneraient'},
#              'aaabdeinnnors': {'abandonnerais'},
#              'aaabdeinnnort': {'abandonnerait'},
#              'aaabdennnors': {'abandonneras'},
#              'aabdeennnorz': {'abandonnerez'},
#              'aabdeeinnnorz': {'abandonneriez'},
#              'aabdeinnnnoors': {'abandonnerions'},
#              'aabdennnnoors': {'abandonnerons'},
#              'aabdennnnoort': {'abandonneront'},
#              'aabdennnos': {'abandonnes'},
#              'aabdennnoz': {'abandonnez'},
#              'aabdeinnnoz': {'abandonniez'},
#              'aabdinnnnoos': {'abandonnions'},
#              'aabdnnnnoos': {'abandonnons'},
#              'aabdemnnnosâ': {'abandonnâmes'},
#              'aabdnnnotâ': {'abandonnât'},
#              'aabdennnostâ': {'abandonnâtes'},
#              'aabdennnnortè': {'abandonnèrent'},
#              'aabdnnnoé': {'abandonné'},
#              'aabdennnoé': {'abandonnée'},
#              'aabdennnosé': {'abandonnées'},
#              'aabdnnnosé': {'abandonnés'},
#              'aabdnnos': {'abandons'},
#              'aabequ': {'abaque'},
#              'aabeqsu': {'abaques'},
#              'aabdiorsu': {'abasourdi', 'absoudrai', 'radoubais'},
#              'aabdeiorsu': {'abasourdie'},
#              'aabdeiorssu': {'abasourdies'},
#              'aabdiorrsu': {'abasourdir'},
#              'aaabdiorrsu': {'abasourdira'},
#              'aaabdiiorrsu': {'abasourdirai'},
#              'aaabdeiinorrstu': {'abasourdiraient'},
#              'aaabdiiorrssu': {'abasourdirais'},
#              'aaabdiiorrstu': {'abasourdirait'},
#              'aaabdiorrssu': {'abasourdiras'},
#              'aabdeinorrstu': {'abasourdirent', 'surabonderait'},
#              'aabdeiorrsuz': {'abasourdirez'},
#              'aabdeiiorrsuz': {'abasourdiriez'},
#              'aabdiinoorrssu': {'abasourdirions'},
#              'aabdinoorrssu': {'abasourdirons'},
#              'aabdinoorrstu': {'abasourdiront'},
#              'aabdiorssu': {'abasourdis', 'absoudrais'},
#              'aaabdeiinorssstu': {'abasourdissaient'},
#              'aaabdiiorssssu': {'abasourdissais'},
#              'aaabdiiorssstu': {'abasourdissait'},
#              'aaabdinorssstu': {'abasourdissant'},
#              'aaabdeinorssstu': {'abasourdissante'},
#              'aaabdeinorsssstu': {'abasourdissantes'},
#              'aaabdinorsssstu': {'abasourdissants'},
#              'aabdeiorsssu': {'abasourdisse'},
#              'aabdeeimnorssstu': {'abasourdissement'},
#              'aabdeeimnorsssstu': {'abasourdissements'},
#              'aabdeinorssstu': {'abasourdissent'},
#              'aabdeiorssssu': {'abasourdisses'},
#              'aabdeiorsssuz': {'abasourdissez'},
#              'aabdeiiorsssuz': {'abasourdissiez'},
#              'aabdiinoorssssu': {'abasourdissions'},
#              'aabdinoorssssu': {'abasourdissons'},
#              'aabdiorstu': {'abasourdit', 'absoudrait'},
#              'aabdemorssuî': {'abasourdîmes'},
#              'aabdorstuî': {'abasourdît'},
#              'aabdeorsstuî': {'abasourdîtes'},
#              'aabt': {'abat'},
#              'aabst': {'abats'},
#              'aaabegtt': {'abattage'},
#              'aaabegstt': {'abattages'},
#              'aaabeinttt': {'abattaient'},
#              'aaabistt': {'abattais'},
#              'aaabittt': {'abattait'},
#              'aaabnttt': {'abattant'},
#              'aaabnsttt': {'abattants'},
#              'aabeemnttt': {'abattement'},
#              'aabeemnsttt': {'abattements'},
#              'aabettz': {'abattez'},
#              'aabeittz': {'abattiez'},
#              'aabinostt': {'abattions'},
#              'aabeinrttt': {'abattirent', 'battraient'},
#              'aabistt': {'abattis', 'battais'},
#              'aabeisstt': {'abattisse'},
#              'aabeinssttt': {'abattissent'},
#              'aabeissstt': {'abattisses'},
#              'aabeiissttz': {'abattissiez'},
#              'aabiinossstt': {'abattissions'},
#              'aabittt': {'abattit', 'battait'},
#              'aabiortt': {'abattoir', 'rabotait'},
#              'aabiorstt': {'abattoirs'},
#              'aaabrtt': {'abattra', 'baratta'},
#              'aaabirtt': {'abattrai', 'barattai'},
#              'aaabeinrttt': {'abattraient', 'barattaient', 'rabattaient'},
#              'aaabirstt': {'abattrais', 'barattais', 'rabattais'},
#              'aaabirttt': {'abattrait', 'barattait', 'rabattait'},
#              'aaabrstt': {'abattras', 'barattas'},
#              'aabertt': {'abattre', 'baratte', 'rabatte'},
#              'aaberttz': {'abattrez', 'barattez', 'rabattez'},
#              'aabeirttz': {'abattriez', 'barattiez', 'rabattiez'},
#              'aabinorstt': {'abattrions', 'barattions', 'rabattions'},
#              'aabnorstt': {'abattrons', 'barattons', 'rabattons'},
#              'aabnorttt': {'abattront'},
#              'aabttu': {'abattu'},
#              'aabettu': {'abattue'},
#              'aabesttu': {'abattues'},
#              'aabersttu': {'abattures', 'rabattues', 'tarabuste'},
#              'aabsttu': {'abattus'},
#              'aabemsttî': {'abattîmes'},
#              'aabtttî': {'abattît'},
#              'aabestttî': {'abattîtes'},
#              'aaabbilt': {'abbatial'},
#              'aaabbeilt': {'abbatiale'},
#              'aaabbeilst': {'abbatiales'},
#              'aaabbitux': {'abbatiaux'},
#              'aabbey': {'abbaye'},
#              'aabbesy': {'abbayes'},
#              'abbeess': {'abbesse'},
#              'abbeesss': {'abbesses'},
#              'abbé': {'abbé'},
#              'abbsé': {'abbés'},
#              'abcsè': {'abcès'},
#              'aabcdiinot': {'abdication'},
#              'aabcdiinost': {'abdications'},
#              'aabdiqu': {'abdiqua'},
#              'aabdiiqu': {'abdiquai'},
#              'aabdeiinqtu': {'abdiquaient'},
#              'aabdiiqsu': {'abdiquais'},
#              'aabdiiqtu': {'abdiquait'},
#              'aabdinqtu': {'abdiquant'},
#              'aabdiqsu': {'abdiquas'},
#              'aabdeiqssu': {'abdiquasse'},
#              'aabdeinqsstu': {'abdiquassent'},
#              'aabdeiqsssu': {'abdiquasses'},
#              'aabdeiiqssuz': {'abdiquassiez'},
#              'aabdiinoqsssu': {'abdiquassions'},
#              'abdeiqu': {'abdique'},
#              'abdeinqtu': {'abdiquent'},
#              'abdeiqru': {'abdiquer'},
#              'aabdeiqru': {'abdiquera'},
#              'aabdeiiqru': {'abdiquerai'},
#              'aabdeeiinqrtu': {'abdiqueraient'},
#              'aabdeiiqrsu': {'abdiquerais'},
#              'aabdeiiqrtu': {'abdiquerait'},
#              'aabdeiqrsu': {'abdiqueras'},
#              'abdeeiqruz': {'abdiquerez'},
#              'abdeeiiqruz': {'abdiqueriez'},
#              'abdeiinoqrsu': {'abdiquerions'},
#              'abdeinoqrsu': {'abdiquerons'},
#              'abdeinoqrtu': {'abdiqueront'},
#              'abdeiqsu': {'abdiques'},
#              'abdeiquz': {'abdiquez'},
#              'abdeiiquz': {'abdiquiez'},
#              'abdiinoqsu': {'abdiquions'},
#              'abdinoqsu': {'abdiquons'},
#              'abdeimqsuâ': {'abdiquâmes'},
#              'abdiqtuâ': {'abdiquât'},
#              'abdeiqstuâ': {'abdiquâtes'},
#              'abdeinqrtuè': {'abdiquèrent'},
#              'abdiqué': {'abdiqué'},
#              'abdeiqué': {'abdiquée'},
#              'abdeiqsué': {'abdiquées'},
#              'abdiqsué': {'abdiqués'},
#              'abdemno': {'abdomen'},
#              'abdemnos': {'abdomens'},
#              'aabdilmno': {'abdominal'},
#              'aabdeilmno': {'abdominale'},
#              'aabdeilmnos': {'abdominales'},
#              'aabdimnoux': {'abdominaux'},
#              'abcdertuu': {'abducteur'},
#              'abcderstuu': {'abducteurs'},
#              'abcdinotu': {'abduction'},
#              'abcdinostu': {'abductions'},
#              'abeeill': {'abeille'},
#              'abeeills': {'abeilles', 'isabelle'},
#              'aabenrrt': {'aberrant'},
#              'aabeenrrt': {'aberrante'},
#              'aabeenrrst': {'aberrantes'},
#              'aabenrrst': {'aberrants'},
#              'aabeinorrt': {'aberration', 'arboraient'},
#              'aabeinorrst': {'aberrations'},
#              'aabhorr': {'abhorra'},
#              'aabhiorr': {'abhorrai'},
#              'aabehinorrt': {'abhorraient'},
#              'aabhiorrs': {'abhorrais'},
#              'aabhiorrt': {'abhorrait'},
#              'aabhnorrt': {'abhorrant'},
#              'aabhorrs': {'abhorras'},
#              'aabehorrss': {'abhorrasse'},
#              'aabehnorrsst': {'abhorrassent'},
#              'aabehorrsss': {'abhorrasses'},
#              'aabehiorrssz': {'abhorrassiez'},
#              'aabhinoorrsss': {'abhorrassions'},
#              'abehorr': {'abhorre'},
#              'abehnorrt': {'abhorrent'},
#              'abehorrr': {'abhorrer'},
#              'aabehorrr': {'abhorrera'},
#              'aabehiorrr': {'abhorrerai'},
#              'aabeehinorrrt': {'abhorreraient'},
#              'aabehiorrrs': {'abhorrerais'},
#              'aabehiorrrt': {'abhorrerait'},
#              'aabehorrrs': {'abhorreras'},
#              'abeehorrrz': {'abhorrerez'},
#              'abeehiorrrz': {'abhorreriez'},
#              'abehinoorrrs': {'abhorrerions'},
#              'abehnoorrrs': {'abhorrerons'},
#              'abehnoorrrt': {'abhorreront'},
#              'abehorrs': {'abhorres'},
#              'abehorrz': {'abhorrez'},
#              'abehiorrz': {'abhorriez'},
#              'abhinoorrs': {'abhorrions'},
#              'abhnoorrs': {'abhorrons'},
#              'abehmorrsâ': {'abhorrâmes'},
#              'abhorrtâ': {'abhorrât'},
#              'abehorrstâ': {'abhorrâtes'},
#              'abehnorrrtè': {'abhorrèrent'},
#              'abhorré': {'abhorré'},
#              'abehorré': {'abhorrée'},
#              'abehorrsé': {'abhorrées'},
#              'abhorrsé': {'abhorrés'},
#              'abcejt': {'abject'},
#              'abceejt': {'abjecte'},
#              'abceejst': {'abjectes'},
#              'abceijnot': {'abjection'},
#              'abceijnost': {'abjections'},
#              'abcejst': {'abjects'},
#              'aabjru': {'abjura'},
#              'aabijru': {'abjurai'},
#              'aabeijnrtu': {'abjuraient'},
#              'aabijrsu': {'abjurais'},
#              'aabijrtu': {'abjurait'},
#              'aabjnrtu': {'abjurant'},
#              'aabjrsu': {'abjuras'},
#              'aabejrssu': {'abjurasse'},
#              'aabejnrsstu': {'abjurassent'},
#              'aabejrsssu': {'abjurasses'},
#              'aabeijrssuz': {'abjurassiez'},
#              'aabijnorsssu': {'abjurassions'},
#              'aabijnortu': {'abjuration'},
#              'aabijnorstu': {'abjurations'},
#              'abejru': {'abjure'},
#              'abejnrtu': {'abjurent'},
#              'abejrru': {'abjurer'},
#              'aabejrru': {'abjurera'},
#              'aabeijrru': {'abjurerai'},
#              'aabeeijnrrtu': {'abjureraient'},
#              'aabeijrrsu': {'abjurerais'},
#              'aabeijrrtu': {'abjurerait'},
#              'aabejrrsu': {'abjureras'},
#              'abeejrruz': {'abjurerez'},
#              'abeeijrruz': {'abjureriez'},
#              'abeijnorrsu': {'abjurerions'},
#              'abejnorrsu': {'abjurerons'},
#              'abejnorrtu': {'abjureront'},
#              'abejrsu': {'abjures'},
#              'abejruz': {'abjurez'},
#              'abeijruz': {'abjuriez'},
#              'abijnorsu': {'abjurions'},
#              'abjnorsu': {'abjurons'},
#              'abejmrsuâ': {'abjurâmes'},
#              'abjrtuâ': {'abjurât'},
#              'abejrstuâ': {'abjurâtes'},
#              'abejnrrtuè': {'abjurèrent'},
#              'abjrué': {'abjuré'},
#              'abejrué': {'abjurée'},
#              'abejrsué': {'abjurées'},
#              'abjrsué': {'abjurés'},
#              'aabfilt': {'ablatif'},
#              'aabilnot': {'ablation'},
#              'aabilnost': {'ablations'},
#              'abeeltt': {'ablette'},
#              'abeelstt': {'ablettes'},
#              'abilnotu': {'ablution', 'oubliant'},
#              'abilnostu': {'ablutions'},
#              'aabginnoté': {'abnégation'},
#              'aabginnosté': {'abnégations'},
#              'abio': {'aboi'},
#              'abeio': {'aboie'},
#              'abeeimnot': {'aboiement'},
#              'abeeimnost': {'aboiements'},
#              'abeinot': {'aboient'},
#              'aabeior': {'aboiera'},
#              'aabeiior': {'aboierai'},
#              'aabeeiinort': {'aboieraient'},
#              'aabeeiiorz': {'aboieraiez'},
#              'aabeiinoors': {'aboieraions'},
#              'aabeiiors': {'aboierais'},
#              'aabeiiort': {'aboierait'},
#              'aabeiors': {'aboieras'},
#              'abeeiorz': {'aboierez'},
#              'abeinoors': {'aboierons'},
#              'abeinoort': {'aboieront'},
#              'abeios': {'aboies'},
#              'abios': {'abois', 'boisa'},
#              'abilo': {'aboli'},
#              'abeilo': {'abolie'},
#              'abeilos': {'abolies'},
#              'abilor': {'abolir'},
#              'aabilor': {'abolira', 'bariola'},
#              'aabiilor': {'abolirai', 'bariolai'},
#              'aabeiilnort': {'aboliraient', 'bariolaient'},
#              'aabiilors': {'abolirais', 'bariolais'},
#              'aabiilort': {'abolirait', 'bariolait'},
#              'aabilors': {'aboliras', 'bariolas'},
#              'abeilnort': {'abolirent', 'bariolent'},
#              'abeilorz': {'abolirez', 'bariolez'},
#              'abeiilorz': {'aboliriez', 'barioliez'},
#              'abiilnoors': {'abolirions', 'bariolions'},
#              'abilnoors': {'abolirons', 'bariolons'},
#              'abilnoort': {'aboliront'},
#              'abilos': {'abolis'},
#              'aabeiilnosst': {'abolissaient'},
#              'aabiilosss': {'abolissais'},
#              'aabiilosst': {'abolissait'},
#              'aabilnosst': {'abolissant'},
#              'abeiloss': {'abolisse', 'bosselai'},
#              'abeilnosst': {'abolissent'},
#              'abeilosss': {'abolisses', 'bosselais'},
#              'abeilossz': {'abolissez'},
#              'abeiilossz': {'abolissiez'},
#              'abiilnoosss': {'abolissions'},
#              'abilnoosss': {'abolissons'},
#              'abilot': {'abolit'},
#              'abiilnoot': {'abolition'},
#              'abeiiilmnnoost': {'abolitionnisme'},
#              'abeiiilnnoostt': {'abolitionniste'},
#              'abeiiilnnoosstt': {'abolitionnistes'},
#              'abiilnoost': {'abolitions'},
#              'abelmosî': {'abolîmes'},
#              'ablotî': {'abolît'},
#              'abelostî': {'abolîtes'},
#              'aabimno': {'abomina'},
#              'aabbeilmno': {'abominable'},
#              'aabbeeilmmnnot': {'abominablement'},
#              'aabbeilmnos': {'abominables'},
#              'aabiimno': {'abominai'},
#              'aabeiimnnot': {'abominaient'},
#              'aabiimnos': {'abominais'},
#              'aabiimnot': {'abominait'},
#              'aabimnnot': {'abominant'},
#              'aabimnos': {'abominas'},
#              'aabeimnoss': {'abominasse'},
#              'aabeimnnosst': {'abominassent'},
#              'aabeimnosss': {'abominasses'},
#              'aabeiimnossz': {'abominassiez'},
#              'aabiimnnoosss': {'abominassions'},
#              'aabiimnnoot': {'abomination'},
#              'aabiimnnoost': {'abominations'},
#              'abeimno': {'abomine'},
#              'abeimnnot': {'abominent'},
#              'abeimnor': {'abominer'},
#              'aabeimnor': {'abominera'},
#              'aabeiimnor': {'abominerai'},
#              'aabeeiimnnort': {'abomineraient'},
#              'aabeiimnors': {'abominerais'},
#              'aabeiimnort': {'abominerait'},
#              'aabeimnors': {'abomineras'},
#              'abeeimnorz': {'abominerez'},
#              'abeeiimnorz': {'abomineriez'},
#              'abeiimnnoors': {'abominerions'},
#              'abeimnnoors': {'abominerons'},
#              'abeimnnoort': {'abomineront'},
#              'abeimnos': {'abomines'},
#              'abeimnoz': {'abominez'},
#              'abeiimnoz': {'abominiez'},
#              'abiimnnoos': {'abominions'},
#              'abimnnoos': {'abominons'},
#              'abeimmnosâ': {'abominâmes'},
#              'abimnotâ': {'abominât'},
#              'abeimnostâ': {'abominâtes'},
#              'abeimnnortè': {'abominèrent'},
#              'abimnoé': {'abominé'},
#              'abeimnoé': {'abominée'},
#              'abeimnosé': {'abominées'},
#              'abimnosé': {'abominés'},
#              'aabdno': {'abonda'},
#              'aabdino': {'abondai'},
#              'aabdeinnot': {'abondaient'},
#              'aabdinos': {'abondais'},
#              'aabdinot': {'abondait'},
#              'aabdemmnnot': {'abondamment'},
#              'aabcdenno': {'abondance'},
#              'aabcdennos': {'abondances'},
#              'aabdnnot': {'abondant'},
#              'aabdennot': {'abondante'},
#              'aabdennost': {'abondantes', 'bastonnade'},
#              'aabdnnost': {'abondants'},
#              'aabdnos': {'abondas'},
#              'aabdenoss': {'abondasse'},
#              'aabdennosst': {'abondassent', 'bastonnades'},
#              'aabdenosss': {'abondasses'},
#              'aabdeinossz': {'abondassiez'},
#              'aabdinnoosss': {'abondassions'},
#              'abdeno': {'abonde'},
#              'abdennot': {'abondent'},
#              'abdenor': {'abonder'},
#              'aabdenor': {'abondera'},
#              'aabdeinor': {'abonderai'},
#              'aabdeeinnort': {'abonderaient'},
#              'aabdeinors': {'abonderais'},
#              'aabdeinort': {'abonderait', 'abordaient'},
#              'aabdenors': {'abonderas'},
#              'abdeenorz': {'abonderez'},
#              'abdeeinorz': {'abonderiez'},
#              'abdeinnoors': {'abonderions'},
#              'abdennoors': {'abonderons'},
#              'abdennoort': {'abonderont'},
#              'abdenos': {'abondes'},
#              'abdenoz': {'abondez'},
#              'abdeinoz': {'abondiez'},
#              'abdinnoos': {'abondions'},
#              'abdnnoos': {'abondons'},
#              'abdemnosâ': {'abondâmes'},
#              'abdnotâ': {'abondât'},
#              'abdenostâ': {'abondâtes'},
#              'abdennortè': {'abondèrent'},
#              'abdnoé': {'abondé'},
#              'abdenoé': {'abondée'},
#              'abdenosé': {'abondées'},
#              'abdnosé': {'abondés'},
#              'aabnno': {'abonna'},
#              'aabinno': {'abonnai'},
#              'aabeinnnot': {'abonnaient'},
#              'aabinnos': {'abonnais'},
#              'aabinnot': {'abonnait'},
#              'aabnnnot': {'abonnant'},
#              'aabnnos': {'abonnas'},
#              'aabennoss': {'abonnasse'},
#              'aabennnosst': {'abonnassent'},
#              'aabennosss': {'abonnasses'},
#              'aabeinnossz': {'abonnassiez'},
#              'aabinnnoosss': {'abonnassions'},
#              'abenno': {'abonne'},
#              'abeemnnnot': {'abonnement'},
#              'abeemnnnost': {'abonnements'},
#              'abennnot': {'abonnent'},
#              'abennor': {'abonner', 'baronne'},
#              'aabennor': {'abonnera'},
#              'aabeinnor': {'abonnerai'},
#              'aabeeinnnort': {'abonneraient'},
#              'aabeinnors': {'abonnerais'},
#              'aabeinnort': {'abonnerait'},
#              'aabennors': {'abonneras'},
#              'abeennorz': {'abonnerez'},
#              'abeeinnorz': {'abonneriez'},
#              'abeinnnoors': {'abonnerions'},
#              'abennnoors': {'abonnerons'},
#              'abennnoort': {'abonneront'},
#              'abennos': {'abonnes'},
#              'abennoz': {'abonnez'},
#              'abinno': {'abonni'},
#              'abeinno': {'abonnie'},
#              'abeinnos': {'abonnies'},
#              'abeinnoz': {'abonniez'},
#              'abinnnoos': {'abonnions'},
#              'abinnor': {'abonnir'},
#              'aabinnor': {'abonnira'},
#              'aabiinnor': {'abonnirai'},
#              'aabeiinnnort': {'abonniraient'},
#              'aabiinnors': {'abonnirais'},
#              'aabiinnort': {'abonnirait'},
#              'aabinnors': {'abonniras'},
#              'abeinnnort': {'abonnirent'},
#              'abeinnorz': {'abonnirez'},
#              'abeiinnorz': {'abonniriez'},
#              'abiinnnoors': {'abonnirions'},
#              'abinnnoors': {'abonnirons'},
#              'abinnnoort': {'abonniront'},
#              'abinnos': {'abonnis'},
#              'aabeiinnnosst': {'abonnissaient'},
#              'aabiinnosss': {'abonnissais'},
#              'aabiinnosst': {'abonnissait'},
#              'aabinnnosst': {'abonnissant'},
#              'abeinnoss': {'abonnisse'},
#              'abeinnnosst': {'abonnissent'},
#              'abeinnosss': {'abonnisses'},
#              'abeinnossz': {'abonnissez'},
#              'abeiinnossz': {'abonnissiez'},
#              'abiinnnoosss': {'abonnissions'},
#              'abinnnoosss': {'abonnissons'},
#              'abinnot': {'abonnit'},
#              'abnnnoo': {'abonnon'},
#              'abnnnoos': {'abonnons'},
#              'abemnnosâ': {'abonnâmes'},
#              'abnnotâ': {'abonnât', 'bâtonna'},
#              'abennostâ': {'abonnâtes'},
#              'abennnortè': {'abonnèrent'},
#              'abnnoé': {'abonné'},
#              'abennoé': {'abonnée'},
#              'abennosé': {'abonnées'},
#              'abnnosé': {'abonnés'},
#              'abemnnosî': {'abonnîmes'},
#              'abnnotî': {'abonnît'},
#              'abennostî': {'abonnîtes'},
#              'abdor': {'abord', 'borda', 'broda'},
#              'aabdor': {'aborda'},
#              'aabbdelor': {'abordable'},
#              'aabbdelors': {'abordables'},
#              'aabdegor': {'abordage'},
#              'aabdegors': {'abordages', 'sabordage'},
#              'aabdior': {'abordai'},
#              'aabdiors': {'abordais', 'adsorbai', 'sabordai'},
#              'aabdiort': {'abordait'},
#              'aabdnort': {'abordant'},
#              'aabdors': {'abordas', 'adsorba', 'saborda'},
#              'aabdeorss': {'abordasse'},
#              'aabdenorsst': {'abordassent'},
#              'aabdeorsss': {'abordasses', 'adsorbasse', 'sabordasse'},
#              'aabdeiorssz': {'abordassiez'},
#              'aabdinoorsss': {'abordassions'},
#              'abdeor': {'aborde'},
#              'abdenort': {'abordent', 'bordante'},
#              'abdeorr': {'aborder', 'bordera', 'brodera'},
#              'aabdeorr': {'abordera'},
#              'aabdeiorr': {'aborderai'},
#              'aabdeeinorrt': {'aborderaient'},
#              'aabdeiorrs': {'aborderais', 'adsorberai', 'saborderai'},
#              'aabdeiorrt': {'aborderait'},
#              'aabdeorrs': {'aborderas', 'adsorbera', 'sabordera'},
#              'abdeeorrz': {'aborderez'},
#              'abdeeiorrz': {'aborderiez'},
#              'abdeinoorrs': {'aborderions'},
#              'abdenoorrs': {'aborderons'},
#              'abdenoorrt': {'aborderont'},
#              'abdeors': {'abordes', 'adsorbe', 'saborde'},
#              'abdeorz': {'abordez'},
#              'abdeiorz': {'abordiez'},
#              'abdinoors': {'abordions'},
#              'abdnoors': {'abordons'},
#              'abdors': {'abords', 'bordas', 'brodas', 'sabord'},
#              'abdemorsâ': {'abordâmes'},
#              'abdortâ': {'abordât'},
#              'abdeorstâ': {'abordâtes'},
#              'abdenorrtè': {'abordèrent'},
#              'abdoré': {'abordé', 'déroba'},
#              'abdeoré': {'abordée'},
#              'abdeorsé': {'abordées', 'adsorbée', 'obsédera', 'sabordée'},
#              'abdorsé': {'abordés', 'adsorbé', 'dérobas', 'sabordé'},
#              'abeginorè': {'aborigène'},
#              'abeginorsè': {'aborigènes'},
#              'abfiort': {'abortif'},
#              'abfiorst': {'abortifs'},
#              'abeiortv': {'abortive'},
#              'abeiorstv': {'abortives', 'observait'},
#              'aabchou': {'aboucha'},
#              'aabchiou': {'abouchai'},
#              'aabcehinotu': {'abouchaient'},
#              'aabchiosu': {'abouchais'},
#              'aabchiotu': {'abouchait'},
#              'aabchnotu': {'abouchant'},
#              'aabchosu': {'abouchas'},
#              'aabcehossu': {'abouchasse'},
#              'aabcehnosstu': {'abouchassent'},
#              'aabcehosssu': {'abouchasses'},
#              'aabcehiossuz': {'abouchassiez'},
#              'aabchinoosssu': {'abouchassions'},
#              'abcehou': {'abouche'},
#              'abcehnotu': {'abouchent'},
#              'abcehoru': {'aboucher', 'bouchera', 'reboucha'},
#              'aabcehoru': {'abouchera'},
#              'aabcehioru': {'aboucherai'},
#              'aabceehinortu': {'aboucheraient'},
#              'aabcehiorsu': {'aboucherais'},
#              'aabcehiortu': {'aboucherait'},
#              'aabcehorsu': {'aboucheras'},
#              'abceehoruz': {'aboucherez'},
#              'abceehioruz': {'aboucheriez'},
#              'abcehinoorsu': {'aboucherions'},
#              'abcehnoorsu': {'aboucherons'},
#              'abcehnoortu': {'aboucheront'},
#              'abcehosu': {'abouches'},
#              'abcehouz': {'abouchez'},
#              'abcehiouz': {'abouchiez'},
#              'abchinoosu': {'abouchions'},
#              'abchnoosu': {'abouchons'},
#              'abcehmosuâ': {'abouchâmes'},
#              'abchotuâ': {'abouchât'},
#              'abcehostuâ': {'abouchâtes'},
#              'abcehnortuè': {'abouchèrent'},
#              'abchoué': {'abouché'},
#              'abcehoué': {'abouchée'},
#              'abcehosué': {'abouchées'},
#              'abchosué': {'abouchés'},
#              'abeilou': {'aboulie'},
#              'abeilosu': {'aboulies'},
#              'abeiloquu': {'aboulique'},
#              'abeiloqsuu': {'abouliques'},
#              'abiotu': {'abouti'},
#              'abeiotu': {'aboutie'},
#              'abeiostu': {'abouties'},
#              'abiortu': {'aboutir', 'broutai', 'obturai', 'rabouti'},
#              'aabiortu': {'aboutira', 'raboutai'},
#              'aabeiinorttu': {'aboutiraient'},
#              'aabiiorstu': {'aboutirais'},
#              'aabiiorttu': {'aboutirait'},
#              'aabiorstu': {'aboutiras', 'raboutais'},
#              'abeinorttu': {'aboutirent', 'broutaient', 'obturaient'},
#              'abeiortuz': {'aboutirez', 'raboutiez'},
#              'abeiiortuz': {'aboutiriez'},
#              'abiinoorstu': {'aboutirions'},
#              'abinoorstu': {'aboutirons', 'raboutions'},
#              'abinoorttu': {'aboutiront', 'obturation'},
#              'abiostu': {'aboutis'},
#              'aabeiinossttu': {'aboutissaient'},
#              'aabiiossstu': {'aboutissais'},
#              'aabiiossttu': {'aboutissait'},
#              'aabinossttu': {'aboutissant'},
#              'aabinosssttu': {'aboutissants'},
#              'abeiosstu': {'aboutisse'},
#              'abeeimnossttu': {'aboutissement'},
#              'abeeimnosssttu': {'aboutissements'},
#              'abeinossttu': {'aboutissent'},
#              'abeiossstu': {'aboutisses'},
#              'abeiosstuz': {'aboutissez'},
#              'abeiiosstuz': {'aboutissiez'},
#              'abiinoossstu': {'aboutissions'},
#              'abinoossstu': {'aboutissons'},
#              'abiottu': {'aboutit', 'boutait'},
#              'abemostuî': {'aboutîmes'},
#              'abottuî': {'aboutît'},
#              'abeosttuî': {'aboutîtes'},
#              'aaboy': {'aboya'},
#              'aabioy': {'aboyai'},
#              'aabeinoty': {'aboyaient'},
#              'aabiosy': {'aboyais'},
#              'aabioty': {'aboyait'},
#              'aabnoty': {'aboyant'},
#              'aabeossy': {'aboyasse'},
#              'aabenossty': {'aboyassent'},
#              'aabeosssy': {'aboyasses'},
#              'aabeiossyz': {'aboyassiez'},
#              'aabinoosssy': {'aboyassions'},
#              'abeory': {'aboyer'},
#              'abeoruy': {'aboyeur'},
#              'abeorsuy': {'aboyeurs'},
#              'abeeosuy': {'aboyeuse'},
#              'abeeossuy': {'aboyeuses'},
#              'abeoyz': {'aboyez'},
#              'abeioyz': {'aboyiez'},
#              'abinoosy': {'aboyions'},
#              'abnoosy': {'aboyons'},
#              'abemosyâ': {'aboyâmes'},
#              'abotyâ': {'aboyât'},
#              'abeostyâ': {'aboyâtes'},
#              'abenortyè': {'aboyèrent'},
#              'aboyé': {'aboyé'},
#              'abeoyé': {'aboyée'},
#              'abeosyé': {'aboyées'},
#              'abosyé': {'aboyés'},
#              'aaaaabbcdnrrt': {'abracadabrant'},
#              'aaaaabbcdenrrt': {'abracadabrante'},
#              'aaaaabbcdenrrst': {'abracadabrantes'},
#              'aaaaabbcdnrrst': {'abracadabrants'},
#              'aabfirs': {'abrasif'},
#              'aabfirss': {'abrasifs'},
#              'aabinors': {'abrasion'},
#              'aabinorss': {'abrasions'},
#              'aabeirsv': {'abrasive', 'baverais'},
#              'aabeirssv': {'abrasives'},
#              'aaberuv': {'abreuva'},
#              'aabeiruv': {'abreuvai'},
#              'aabeeinrtuv': {'abreuvaient'},
#              'aabeirsuv': {'abreuvais'},
#              'aabeirtuv': {'abreuvait'},
#              'aabenrtuv': {'abreuvant'},
#              'aabersuv': {'abreuvas'},
#              'aabeerssuv': {'abreuvasse'},
#              'aabeenrsstuv': {'abreuvassent'},
#              'aabeersssuv': {'abreuvasses'},
#              'aabeeirssuvz': {'abreuvassiez'},
#              'aabeinorsssuv': {'abreuvassions'},
#              'abeeruv': {'abreuve'},
#              'abeenrtuv': {'abreuvent'},
#              'abeerruv': {'abreuver'},
#              'aabeerruv': {'abreuvera'},
#              'aabeeirruv': {'abreuverai'},
#              'aabeeeinrrtuv': {'abreuveraient'},
#              'aabeeirrsuv': {'abreuverais'},
#              'aabeeirrtuv': {'abreuverait'},
#              'aabeerrsuv': {'abreuveras'},
#              'abeeerruvz': {'abreuverez'},
#              'abeeeirruvz': {'abreuveriez'},
#              'abeeinorrsuv': {'abreuverions'},
#              'abeenorrsuv': {'abreuverons'},
#              'abeenorrtuv': {'abreuveront'},
#              'abeersuv': {'abreuves'},
#              'abeeruvz': {'abreuvez'},
#              'abeeiruvz': {'abreuviez'},
#              'abeinorsuv': {'abreuvions'},
#              'abeiorruv': {'abreuvoir'},
#              'abeiorrsuv': {'abreuvoirs'},
#              'abenorsuv': {'abreuvons'},
#              'abeemrsuvâ': {'abreuvâmes'},
#              'abertuvâ': {'abreuvât'},
#              'abeerstuvâ': {'abreuvâtes'},
#              'abeenrrtuvè': {'abreuvèrent'},
#              'aberuvé': {'abreuvé', 'ébavure'},
#              'abeeruvé': {'abreuvée'},
#              'abeersuvé': {'abreuvées'},
#              'abersuvé': {'abreuvés', 'ébavures'},
#              'abir': {'abri', 'brai'},
#              'abciort': {'abricot'},
#              'abceiiorrt': {'abricotier'},
#              'abceiiorrst': {'abricotiers'},
#              'abciorst': {'abricots'},
#              'abirs': {'abris', 'brisa', 'sabir'},
#              'aabirt': {'abrita'},
#              'aabiirt': {'abritai'},
#              'aabeiinrtt': {'abritaient'},
#              'aabiirst': {'abritais', 'braisait'},
#              'aabiirtt': {'abritait'},
#              'aabinrtt': {'abritant'},
#              'aabirst': {'abritas', 'brasait', 'sabrait'},
#              'aabeirsst': {'abritasse', 'abstraies'},
#              'aabeinrsstt': {'abritassent'},
#              'aabeirssst': {'abritasses'},
#              'aabeiirsstz': {'abritassiez'},
#              'aabiinorssst': {'abritassions'},
#              'abeirt': {'abrite', 'braite'},
#              'abeinrtt': {'abritent'},
#              'abeirrt': {'abriter', 'arbitre'},
#              'aabeirrt': {'abritera'},
#              'aabeiirrt': {'abriterai'},
#              'aabeeiinrrtt': {'abriteraient'},
#              'aabeiirrst': {'abriterais', 'braiserait'},
#              'aabeiirrtt': {'abriterait'},
#              'aabeirrst': {'abriteras', 'abstraire', 'braserait', 'sabrerait'},
#              'abeeirrtz': {'abriterez'},
#              'abeeiirrtz': {'abriteriez'},
#              'abeiinorrst': {'abriterions'},
#              'abeinorrst': {'abriterons', 'braiseront'},
#              'abeinorrtt': {'abriteront'},
#              'abeirst': {'abrites', 'braites'},
#              'abeirtz': {'abritez'},
#              'abeiirtz': {'abritiez'},
#              'abiinorst': {'abritions'},
#              'abinorst': {'abritons'},
#              'abeimrstâ': {'abritâmes'},
#              'abirttâ': {'abritât'},
#              'abeirsttâ': {'abritâtes'},
#              'abeinrrttè': {'abritèrent'},
#              'abirté': {'abrité'},
#              'abeirté': {'abritée'},
#              'abeirsté': {'abritées'},
#              'abirsté': {'abrités'},
#              'aabginoort': {'abrogation'},
#              'aabginoorst': {'abrogations'},
#              'abegor': {'abroge', 'gobera'},
#              'aabegor': {'abrogea'},
#              'aabegior': {'abrogeai'},
#              'aabeeginort': {'abrogeaient'},
#              'aabegiors': {'abrogeais'},
#              'aabegiort': {'abrogeait'},
#              'aabegnort': {'abrogeant'},
#              'aabegors': {'abrogeas'},
#              'aabeegorss': {'abrogeasse'},
#              'aabeegnorsst': {'abrogeassent'},
#              'aabeegorsss': {'abrogeasses'},
#              'aabeegiorssz': {'abrogeassiez'},
#              'aabeginoorsss': {'abrogeassions'},
#              'abegnort': {'abrogent'},
#              'abegnoors': {'abrogeons'},
#              'abegorr': {'abroger'},
#              'aabegorr': {'abrogera'},
#              'aabegiorr': {'abrogerai'},
#              'aabeeginorrt': {'abrogeraient'},
#              'aabegiorrs': {'abrogerais'},
#              'aabegiorrt': {'abrogerait'},
#              'aabegorrs': {'abrogeras'},
#              'abeegorrz': {'abrogerez'},
#              'abeegiorrz': {'abrogeriez'},
#              'abeginoorrs': {'abrogerions'},
#              'abegnoorrs': {'abrogerons'},
#              'abegnoorrt': {'abrogeront'},
#              'abegors': {'abroges', 'goberas'},
#              'abegorz': {'abrogez'},
#              'abeegmorsâ': {'abrogeâmes'},
#              'abegortâ': {'abrogeât'},
#              'abeegorstâ': {'abrogeâtes'},
#              'abegiorz': {'abrogiez'},
#              'abginoors': {'abrogions'},
#              'abegnorrtè': {'abrogèrent'},
#              'abgoré': {'abrogé'},
#              'abegoré': {'abrogée'},
#              'abegorsé': {'abrogées'},
#              'abgorsé': {'abrogés'},
#              'abprtu': {'abrupt'},
#              'abeprtu': {'abrupte'},
#              'abeprstu': {'abruptes'},
#              'abprstu': {'abrupts'},
#              'abirtu': {'abruti', 'bruita'},
#              'abeirtu': {'abrutie', 'buterai', 'rebutai', 'tuberai'},
#              'abeirstu': {'abruties', 'buterais', 'rebutais', 'tuberais'},
#              'abirrtu': {'abrutir'},
#              'aabirrtu': {'abrutira'},
#              'aabiirrtu': {'abrutirai'},
#              'aabeiinrrttu': {'abrutiraient'},
#              'aabiirrstu': {'abrutirais'},
#              'aabiirrttu': {'abrutirait'},
#              'aabirrstu': {'abrutiras'},
#              'abeinrrttu': {'abrutirent'},
#              'abeirrtuz': {'abrutirez'},
#              'abeiirrtuz': {'abrutiriez'},
#              'abiinorrstu': {'abrutirions'},
#              'abinorrstu': {'abrutirons'},
#              'abinorrttu': {'abrutiront', 'turbotrain'},
#              'abirstu': {'abrutis', 'bruitas'},
#              'aabeiinrssttu': {'abrutissaient'},
#              'aabiirssstu': {'abrutissais'},
#              'aabiirssttu': {'abrutissait'},
#              'aabinrssttu': {'abrutissant'},
#              'aabeinrssttu': {'abrutissante'},
#              'aabeinrsssttu': {'abrutissantes'},
#              'aabinrsssttu': {'abrutissants'},
#              'abeirsstu': {'abrutisse', 'bruitasse'},
#              'abeeimnrssttu': {'abrutissement'},
#              'abeeimnrsssttu': {'abrutissements'},
#              'abeinrssttu': {'abrutissent', 'bruitassent'},
#              'abeirssstu': {'abrutisses', 'bruitasses', 'subsistera'},
#              'abeirsstuz': {'abrutissez'},
#              'abeiirsstuz': {'abrutissiez', 'bruitassiez'},
#              'abiinorssstu': {'abrutissions', 'bruitassions'},
#              'abinorssstu': {'abrutissons'},
#              'abirttu': {'abrutit'},
#              'abemrstuî': {'abrutîmes'},
#              'abrttuî': {'abrutît'},
#              'abersttuî': {'abrutîtes'},
#              'abeegmnrtè': {'abrègement'},
#              'abeegmnrstè': {'abrègements'},
#              'abegré': {'abrége'},
#              'aabegré': {'abrégea'},
#              'aabegiré': {'abrégeai', 'bégaiera'},
#              'aabeeginrté': {'abrégeaient'},
#              'aabegirsé': {'abrégeais', 'bégaieras'},
#              'aabegirté': {'abrégeait'},
#              'aabegnrté': {'abrégeant'},
#              'aabegrsé': {'abrégeas'},
#              'aabeegrssé': {'abrégeasse'},
#              'aabeegnrssté': {'abrégeassent'},
#              'aabeegrsssé': {'abrégeasses'},
#              'aabeegirsszé': {'abrégeassiez'},
#              'aabeginorsssé': {'abrégeassions'},
#              'abegnrté': {'abrégent'},
#              'abegnorsé': {'abrégeons'},
#              'abegrré': {'abréger'},
#              'aabegrré': {'abrégera', 'bagarrée'},
#              'aabegirré': {'abrégerai'},
#              'aabeeginrrté': {'abrégeraient'},
#              'aabegirrsé': {'abrégerais'},
#              'aabegirrté': {'abrégerait'},
#              'aabegrrsé': {'abrégeras', 'bagarrées'},
#              'abeegrrzé': {'abrégerez'},
#              'abeegirrzé': {'abrégeriez'},
#              'abeginorrsé': {'abrégerions', 'éborgnerais'},
#              'abegnorrsé': {'abrégerons', 'éborgneras'},
#              'abegnorrté': {'abrégeront'},
#              'abegrsé': {'abréges'},
#              'abegrzé': {'abrégez'},
#              'abeegmrsâé': {'abrégeâmes'},
#              'abegrtâé': {'abrégeât'},
#              'abeegrstâé': {'abrégeâtes'},
#              'abegirzé': {'abrégiez'},
#              'abginorsé': {'abrégions', 'éborgnais'},
#              'abegnrrtèé': {'abrégèrent'},
#              'abgréé': {'abrégé'},
#              'abegréé': {'abrégée'},
#              'abegrséé': {'abrégées'},
#              'abgrséé': {'abrégés'},
#              'aabfiirtvé': {'abréviatif'},
#              'aabfiirstvé': {'abréviatifs'},
#              'aabiinortvé': {'abréviation'},
#              'aabiinorstvé': {'abréviations'},
#              'aabeiirtvvé': {'abréviative'},
#              'aabeiirstvvé': {'abréviatives'},
#              'abceisss': {'abscisse'},
#              'abceissss': {'abscisses'},
#              'abceens': {'absence'},
#              'abceenss': {'absences'},
#              'abenst': {'absent', 'basent'},
#              'aabenst': {'absenta'},
#              'aabeinst': {'absentai', 'basaient'},
#              'aabeeinnstt': {'absentaient', 'abstenaient'},
#              'aabeinstt': {'absentait', 'abstenait'},
#              'aabennstt': {'absentant', 'abstenant'},
#              'aabensst': {'absentas'},
#              'aabeenssst': {'absentasse'},
#              'aabeennssstt': {'absentassent'},
#              'aabeensssst': {'absentasses'},
#              'aabeeinssstz': {'absentassiez'},
#              'aabeinnosssst': {'absentassions'},
#              'abeenst': {'absente'},
#              'abeennstt': {'absentent'},
#              'abeenrst': {'absenter'},
#              'aabeenrst': {'absentera'},
#              'aabeeinrst': {'absenterai', 'baseraient'},
#              'aabeeeinnrstt': {'absenteraient'},
#              'aabeeinrsst': {'absenterais'},
#              'aabeeinrstt': {'absenterait'},
#              'aabeenrsst': {'absenteras'},
#              'abeeenrstz': {'absenterez'},
#              'abeeeinrstz': {'absenteriez'},
#              'abeeinnorsst': {'absenterions'},
#              'abeennorsst': {'absenterons', 'enrobassent'},
#              'abeennorstt': {'absenteront'},
#              'abeensst': {'absentes'},
#              'abeenstz': {'absentez', 'abstenez'},
#              'abeeinstz': {'absentiez', 'absteniez'},
#              'abeinnosst': {'absentions', 'abstenions'},
#              'abennosst': {'absentons', 'abstenons'},
#              'abensst': {'absents'},
#              'abeemnsstâ': {'absentâmes'},
#              'abensttâ': {'absentât'},
#              'abeenssttâ': {'absentâtes'},
#              'abeennrsttè': {'absentèrent'},
#              'abensté': {'absenté', 'béantes'},
#              'abeensté': {'absentée'},
#              'abeenssté': {'absentées'},
#              'abeeimnssté': {'absentéisme'},
#              'abenssté': {'absentés'},
#              'abdeis': {'abside'},
#              'abdeiss': {'absides'},
#              'abehinst': {'absinthe'},
#              'ablosu': {'absolu', 'blousa', 'boulas'},
#              'abelosu': {'absolue'},
#              'abelossu': {'absolues', 'boulasse'},
#              'abelmnostu': {'absolument'},
#              'ablossu': {'absolus', 'blousas'},
#              'abilnoostu': {'absolution'},
#              'abilnoosstu': {'absolutions'},
#              'abeilmosstu': {'absolutisme'},
#              'abeilossttu': {'absolutiste'},
#              'abeilosssttu': {'absolutistes'},
#              'aabeilnostv': {'absolvaient'},
#              'aabilossv': {'absolvais'},
#              'aabilostv': {'absolvait'},
#              'aablnostv': {'absolvant'},
#              'abelosv': {'absolve'},
#              'abelnostv': {'absolvent'},
#              'abelossv': {'absolves'},
#              'abelosvz': {'absolvez'},
#              'abeilosvz': {'absolviez'},
#              ...})

# %%
# keep only the key/value pairs where the set has more than one element;
# this is now a regular dict

anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
anagrams_by_sig
# Out:
# {'aabeinsst': {'abaissent', 'absentais', 'abstenais'},
#  'aabeirss': {'abaisser', 'baiseras', 'baissera', 'baserais', 'rabaisse'},
#  'aabeisss': {'abaisses', 'baisasse'},
#  'aabeirssu': {'abaisseur', 'abuserais'},
#  'aabdiorsu': {'abasourdi', 'absoudrai', 'radoubais'},
#  'aabdeinorrstu': {'abasourdirent', 'surabonderait'},
#  'aabdiorssu': {'abasourdis', 'absoudrais'},
#  'aabdiorstu': {'abasourdit', 'absoudrait'},
#  'aabeinrttt': {'abattirent', 'battraient'},
#  'aabistt': {'abattis', 'battais'},
#  'aabittt': {'abattit', 'battait'},
#  'aabiortt': {'abattoir', 'rabotait'},
#  'aaabrtt': {'abattra', 'baratta'},
#  'aaabirtt': {'abattrai', 'barattai'},
#  'aaabeinrttt': {'abattraient', 'barattaient', 'rabattaient'},
#  'aaabirstt': {'abattrais', 'barattais', 'rabattais'},
#  'aaabirttt': {'abattrait', 'barattait', 'rabattait'},
#  'aaabrstt': {'abattras', 'barattas'},
#  'aabertt': {'abattre', 'baratte', 'rabatte'},
#  'aaberttz': {'abattrez', 'barattez', 'rabattez'},
#  'aabeirttz': {'abattriez', 'barattiez', 'rabattiez'},
#  'aabinorstt': {'abattrions', 'barattions', 'rabattions'},
#  'aabnorstt': {'abattrons', 'barattons', 'rabattons'},
#  'aabersttu': {'abattures', 'rabattues', 'tarabuste'},
#  'abeeills': {'abeilles', 'isabelle'},
#  'aabeinorrt': {'aberration', 'arboraient'},
#  'abilnotu': {'ablution', 'oubliant'},
#  'abios': {'abois', 'boisa'},
#  'aabilor': {'abolira', 'bariola'},
#  'aabiilor': {'abolirai', 'bariolai'},
#  'aabeiilnort': {'aboliraient', 'bariolaient'},
#  'aabiilors': {'abolirais', 'bariolais'},
#  'aabiilort': {'abolirait', 'bariolait'},
#  'aabilors': {'aboliras', 'bariolas'},
#  'abeilnort': {'abolirent', 'bariolent'},
#  'abeilorz': {'abolirez', 'bariolez'},
#  'abeiilorz': {'aboliriez', 'barioliez'},
#  'abiilnoors': {'abolirions', 'bariolions'},
#  'abilnoors': {'abolirons', 'bariolons'},
#  'abeiloss': {'abolisse', 'bosselai'},
#  'abeilosss': {'abolisses', 'bosselais'},
#  'aabdennost': {'abondantes', 'bastonnade'},
#  'aabdennosst': {'abondassent', 'bastonnades'},
#  'aabdeinort': {'abonderait', 'abordaient'},
#  'abennor': {'abonner', 'baronne'},
#  'abnnotâ': {'abonnât', 'bâtonna'},
#  'abdor': {'abord', 'borda', 'broda'},
#  'aabdegors': {'abordages', 'sabordage'},
#  'aabdiors': {'abordais', 'adsorbai', 'sabordai'},
#  'aabdors': {'abordas', 'adsorba', 'saborda'},
#  'aabdeorsss': {'abordasses', 'adsorbasse', 'sabordasse'},
#  'abdenort': {'abordent', 'bordante'},
#  'abdeorr': {'aborder', 'bordera', 'brodera'},
#  'aabdeiorrs': {'aborderais', 'adsorberai', 'saborderai'},
#  'aabdeorrs': {'aborderas', 'adsorbera', 'sabordera'},
#  'abdeors': {'abordes', 'adsorbe', 'saborde'},
#  'abdors': {'abords', 'bordas', 'brodas', 'sabord'},
#  'abdoré': {'abordé', 'déroba'},
#  'abdeorsé': {'abordées', 'adsorbée', 'obsédera', 'sabordée'},
#  'abdorsé': {'abordés', 'adsorbé', 'dérobas', 'sabordé'},
#  'abeiorstv': {'abortives', 'observait'},
#  'abcehoru': {'aboucher', 'bouchera', 'reboucha'},
#  'abiortu': {'aboutir', 'broutai', 'obturai', 'rabouti'},
#  'aabiortu': {'aboutira', 'raboutai'},
#  'aabiorstu': {'aboutiras', 'raboutais'},
#  'abeinorttu': {'aboutirent', 'broutaient', 'obturaient'},
#  'abeiortuz': {'aboutirez', 'raboutiez'},
#  'abinoorstu': {'aboutirons', 'raboutions'},
#  'abinoorttu': {'aboutiront', 'obturation'},
#  'abiottu': {'aboutit', 'boutait'},
#  'aabeirsv': {'abrasive', 'baverais'},
#  'aberuvé': {'abreuvé', 'ébavure'},
#  'abersuvé': {'abreuvés', 'ébavures'},
#  'abir': {'abri', 'brai'},
#  'abirs': {'abris', 'brisa', 'sabir'},
#  'aabiirst': {'abritais', 'braisait'},
#  'aabirst': {'abritas', 'brasait', 'sabrait'},
#  'aabeirsst': {'abritasse', 'abstraies'},
#  'abeirt': {'abrite', 'braite'},
#  'abeirrt': {'abriter', 'arbitre'},
#  'aabeiirrst': {'abriterais', 'braiserait'},
#  'aabeirrst': {'abriteras', 'abstraire', 'braserait', 'sabrerait'},
#  'abeinorrst': {'abriterons', 'braiseront'},
#  'abeirst': {'abrites', 'braites'},
#  'abegor': {'abroge', 'gobera'},
#  'abegors': {'abroges', 'goberas'},
#  'abirtu': {'abruti', 'bruita'},
#  'abeirtu': {'abrutie', 'buterai', 'rebutai', 'tuberai'},
#  'abeirstu': {'abruties', 'buterais', 'rebutais', 'tuberais'},
#  'abinorrttu': {'abrutiront', 'turbotrain'},
#  'abirstu': {'abrutis', 'bruitas'},
#  'abeirsstu': {'abrutisse', 'bruitasse'},
#  'abeinrssttu': {'abrutissent', 'bruitassent'},
#  'abeirssstu': {'abrutisses', 'bruitasses', 'subsistera'},
#  'abeiirsstuz': {'abrutissiez', 'bruitassiez'},
#  'abiinorssstu': {'abrutissions', 'bruitassions'},
#  'aabegiré': {'abrégeai', 'bégaiera'},
#  'aabegirsé': {'abrégeais', 'bégaieras'},
#  'aabegrré': {'abrégera', 'bagarrée'},
#  'aabegrrsé': {'abrégeras', 'bagarrées'},
#  'abeginorrsé': {'abrégerions', 'éborgnerais'},
#  'abegnorrsé': {'abrégerons', 'éborgneras'},
#  'abginorsé': {'abrégions', 'éborgnais'},
#  'abenst': {'absent', 'basent'},
#  'aabeinst': {'absentai', 'basaient'},
#  'aabeeinnstt': {'absentaient', 'abstenaient'},
#  'aabeinstt': {'absentait', 'abstenait'},
#  'aabennstt': {'absentant', 'abstenant'},
#  'aabeeinrst': {'absenterai', 'baseraient'},
#  'abeennorsst': {'absenterons', 'enrobassent'},
#  'abeenstz': {'absentez', 'abstenez'},
#  'abeeinstz': {'absentiez', 'absteniez'},
#  'abeinnosst': {'absentions', 'abstenions'},
#  'abennosst': {'absentons', 'abstenons'},
#  'abensté': {'absenté', 'béantes'},
#  'ablosu': {'absolu', 'blousa', 'boulas'},
#  'abelossu': {'absolues', 'boulasse'},
#  'ablossu': {'absolus', 'blousas'},
#  'aabbiorst': {'absorbait', 'barbotais'},
#  'aabbeiorrst': {'absorberait', 'barboterais'},
#  'abbenoorrst': {'absorberont', 'barboterons'},
#  'aabdorsu': {'absoudra', 'radoubas'},
#  'abdeorsu': {'absoudre', 'bouderas', 'radoubes'},
#  'abdnoorstu': {'absoudront', 'subodorant'},
#  'abostu': {'absout', 'tabous'},
#  'abeostu': {'absoute', 'taboues'},
#  'abeosstu': {'absoutes', 'boutasse'},
#  'abeinrst': {'abstenir', 'braisent'},
#  'abenstu': {'abstenu', 'abusent'},
#  'abdeinnorsst': {'abstiendrons', 'rebondissant'},
#  'abeinsst': {'abstiens', 'baissent', 'bassinet'},
#  'abinsst': {'abstins', 'bissant'},
#  'abeinssst': {'abstinsse', 'bassinets'},
#  'abeinsssst': {'abstinsses', 'bissassent'},
#  'aabeirst': {'abstraie', 'baserait'},
#  'aabinorrstt': {'abstrairont', 'rabattrions'},
#  'aabirsst': {'abstrais', 'brassait'},
#  'aabirstt': {'abstrait', 'battrais', 'rabattis'},
#  'aabeirstt': {'abstraite', 'rebattais'},
#  'aabeirsstt': {'abstraites', 'rabattisse'},
#  'abesu': {'abuse', 'aubes'},
#  'aacehnt': {'acanthe', 'entacha'},
#  'aacehnst': {'acanthes', 'entachas'},
#  'aaaccepr': {'accapare', 'carapace'},
#  'aaacceprs': {'accapares', 'carapaces'},
#  'aacceinstu': {'accentuais', 'accusaient'},
#  'aacceeinrstu': {'accentuerais', 'accuseraient'},
#  'aaccdeeinrt': {'accidentera', 'cadencerait'},
#  'aaaccilmt': {'acclamait', 'acclimata'},
#  'aaacceilmrt': {'acclamerait', 'acclimatera'},
#  'aacceiilmnorst': {'acclimaterions', 'calomniatrices'},
#  'acceinot': {'accointe', 'occitane'},
#  'acceinnott': {'accointent', 'connectait'},
#  'acceinort': {'accointer', 'accroient', 'concertai'},
#  'acceinnoortt': {'accointeront', 'concertation'},
#  'acceinost': {'accointes', 'occitanes'},
#  'aaccelor': {'accolera', 'caracole'},
#  'aaccelors': {'accoleras', 'caracoles'},
#  'accdemmoor': {'accommoder', 'raccommode'},
#  'accdeor': {'accorde', 'cocarde'},
#  'accdeorr': {'accorder', 'raccorde'},
#  'accdeinoorrs': {'accorderions', 'concorderais'},
#  'accdenoorrs': {'accorderons', 'concorderas'},
#  'accdeors': {'accordes', 'cocardes'},
#  'accdinoors': {'accordions', 'concordais'},
#  'accdnoors': {'accordons', 'concordas'},
#  'acceort': {'accorte', 'accoter'},
#  'acceorst': {'accortes', 'accoster'},
#  'aaccost': {'accosta', 'accotas'},
#  'aacciost': {'accostai', 'accotais'},
#  'aaccnostt': {'accostant', 'contactas'},
#  'aacceossst': {'accostasse', 'accotasses'},
#  'aaccenossstt': {'accostassent', 'contactasses'},
#  'acceost': {'accoste', 'accotes'},
#  'accenostt': {'accostent', 'contactes'},
#  'aacceorst': {'accostera', 'accoteras'},
#  'aacceiorst': {'accosterai', 'accoterais'},
#  'accosté': {'accosté', 'accotés'},
#  'acceosté': {'accostée', 'accotées'},
#  'aaccnott': {'accotant', 'contacta'},
#  'aaccenosstt': {'accotassent', 'contactasse'},
#  'accenott': {'accotent', 'contacte'},
#  'aacciortu': {'accourait', 'accoutrai'},
#  'accinoorsu': {'accourions', 'concourais'},
#  'accinoorrsu': {'accourrions', 'concourrais'},
#  'accnoorrsu': {'accourrons', 'concourras'},
#  'acccehorr': {'accrocher', 'raccroche'},
#  'acceior': {'accroie', 'coriace'},
#  'acceiors': {'accroies', 'coriaces'},
#  'acciors': {'accrois', 'occiras'},
#  'acceiopru': {'accroupie', 'occuperai'},
#  'acceioprsu': {'accroupies', 'occuperais'},
#  'accersu': {'accrues', 'accuser'},
#  'accdeirrté': {'accréditer', 'rédactrice'},
#  'aacceillntu': {'accueillant', 'calculaient'},
#  'accelnorsu': {'acculerons', 'caroncules'},
#  'accilnosu': {'acculions', 'concluais'},
#  'accenorssu': {'accuserons', 'concasseur'},
#  'aaccdsé': {'accédas', 'cascadé', 'saccadé'},
#  'aaccdessé': {'accédasse', 'cascadées', 'saccadées'},
#  'accdeinorsé': {'accéderions', 'concéderais'},
#  'accdenorsé': {'accéderons', 'concéderas'},
#  'accdenorté': {'accéderont', 'déconcerta'},
#  'accdinosé': {'accédions', 'concédais'},
#  'accdnosé': {'accédons', 'concédas'},
#  'aaacehinrrt': {'acharnerait', 'arrachaient'},
#  'aceehimnr': {'acheminer', 'cheminera'},
#  'acehimntâ': {'acheminât', 'mâchaient'},
#  'acehimné': {'acheminé', 'machinée'},
#  'acehimnsé': {'acheminés', 'machinées'},
#  'aacehitt': {'achetait', 'tachetai'},
#  'aceehrt': {'acheter', 'hectare'},
#  'aacehiv': {'achevai', 'avachie'},
#  'aacehisv': {'achevais', 'avachies'},
#  'acehoppr': {'achopper', 'approche'},
#  'achoppé': {'achoppé', 'échoppa'},
#  'achoppsé': {'achoppés', 'échoppas'},
#  'aacehirttè': {'achèterait', 'tachèterai'},
#  'acehnorttè': {'achèteront', 'cahotèrent'},
#  'acdiité': {'acidité', 'édictai'},
#  'acdiisté': {'acidités', 'édictais'},
#  'acdilué': {'acidulé', 'élucida'},
#  'acdilsué': {'acidulés', 'élucidas'},
#  'aceir': {'acier', 'carie', 'craie'},
#  'aceirs': {'aciers', 'caries', 'casier', 'sciera'},
#  'aacinrté': {'aciérant', 'carénait'},
#  'aacirsé': {'aciéras', 'écrasai'},
#  'aceiré': {'aciére', 'cariée'},
#  'aceinrté': {'aciérent', 'créaient'},
#  'aceirré': {'aciérer', 'créerai', 'recréai', 'écriera'},
#  'aaceirrsé': {'aciéreras', 'écraserai'},
#  'aceinorrsé': {'aciérerons', 'nécroserai', 'écornerais'},
#  'aceinorrté': {'aciéreront', 'contrariée', 'écornerait'},
#  'aceirsé': {'aciéres', 'cariées'},
#  'acinorsé': {'aciérons', 'nécrosai', 'scénario', 'écornais'},
#  'acné': {'acné', 'cané'},
#  'acemopst': {'acomptes', 'escompta'},
#  'acinot': {'aconit', 'action', 'contai'},
#  'acinost': {'aconits', 'actions', 'contais'},
#  'aceinoqué': {'acoquinée', 'océanique'},
#  'aceinoqsué': {'acoquinées', 'océaniques'},
#  'aaceqrru': {'acquerra', 'craquera'},
#  'aaceiqrru': {'acquerrai', 'craquerai'},
#  'aaceeinqrrtu': {'acquerraient', 'craqueraient'},
#  'aaceiqrrsu': {'acquerrais', 'craquerais'},
#  'aaceiqrrtu': {'acquerrait', 'craquerait'},
#  'aaceqrrsu': {'acquerras', 'craqueras'},
#  'aceeqrruz': {'acquerrez', 'craquerez'},
#  'aceeiqrruz': {'acquerriez', 'craqueriez'},
#  'aceinoqrrsu': {'acquerrions', 'conquerrais', 'craquerions'},
#  'acenoqrrsu': {'acquerrons', 'conquerras', 'craquerons'},
#  'acenoqrrtu': {'acquerront', 'craqueront'},
#  'aceiqrtu': {'acquiert', 'arctique'},
#  'aceiqssu': {'acquises', 'acquisse'},
#  'aceiqttu': {'acquitte', 'tactique'},
#  'aceiqsttu': {'acquittes', 'tactiques'},
#  'acinoqrsué': {'acquérions', 'conquérais'},
#  'accehiorst': {'acrostiche', 'crochetais'},
#  'acest': {'actes', 'caste'},
#  'aceiinst': {'actinies', 'sciaient'},
#  'aaceiinnort': {'actionnaire', 'actionnerai'},
#  'aaceiinnorst': {'actionnaires', 'actionnerais', 'canoniserait'},
#  'aaciinnost': {'actionnais', 'canonisait'},
#  'aceinnort': {'actionner', 'container', 'cornaient'},
#  'aaceiinnortt': {'actionnerait', 'incantatoire'},
#  'aceiinnnoorst': {'actionnerions', 'renonciations'},
#  'aceinnnoorst': {'actionnerons', 'canoniseront'},
#  'aceinnost': {'actionnes', 'contenais', 'sectionna'},
#  'aceirtv': {'activer', 'crevait'},
#  'aaceiirtv': {'activerai', 'aviatrice'},
#  'aaceiirstv': {'activerais', 'aviatrices'},
#  'aceinorstv': {'activerons', 'conservait', 'conversait', 'novatrices'},
#  'aciinostv': {'activions', 'noviciats'},
#  'acitvé': {'activé', 'cavité'},
#  'acistvé': {'activés', 'cavités'},
#  'aaceirtu': {'actuaire', 'autarcie'},
#  'aaceirstu': {'actuaires', 'autarcies', 'causerait', 'saucerait'},
#  'aacilstué': {'actualisé', 'causalité'},
#  'aacilsstué': {'actualisés', 'causalités'},
#  'accenoprtuu': {'acuponcteur', 'acuponcture'},
#  'accenoprstuu': {'acuponcteurs', 'acuponctures'},
#  'accenprtuuu': {'acupuncteur', 'acupuncture'},
#  'accenprstuuu': {'acupuncteurs', 'acupunctures'},
#  'acrséé': {'acérés', 'écrasé'},
#  'aceiqstué': {'acétiques', 'ascétique'},
#  'acenoté': {'acétone', 'canotée'},
#  'adegjué': {'adjugée', 'déjugea'},
#  'adegjsué': {'adjugées', 'déjugeas'},
#  'adeiimnrst': {'administre', 'dirimantes'},
#  'adeiimnrsté': {'administrée', 'démentirais', 'déterminais'},
#  'aadeiimnrt': {'admiraient', 'diamantier'},
#  'aadeimrrstu': {'admirateurs', 'musarderait'},
#  'adeimr': {'admire', 'damier'},
#  'adeimrr': {'admirer', 'madrier'},
#  'adeiimnorrs': {'admirerions', 'endormirais'},
#  'adeimnorrs': {'admirerons', 'endormiras'},
#  'adeimnorrt': {'admireront', 'mordraient'},
#  'adeimrs': {'admires', 'damiers'},
#  'adiimnors': {'admirions', 'amoindris'},
#  'adimré': {'admiré', 'médira'},
#  'adeimré': {'admirée', 'remédia'},
#  'adeimrsé': {'admirées', 'remédias', 'réadmise'},
#  'adimrsé': {'admirés', 'médiras', 'réadmis'},
#  'adims': {'admis', 'daims'},
#  'adeims': {'admise', 'samedi'},
#  'adeimss': {'admises', 'sadisme', 'samedis'},
#  'aadeimnosst': {'admonestais', 'amodiassent'},
#  'ademnossté': {'admonestés', 'démontasse'},
#  'adinos': {'adonis', 'aidons', 'danois', 'sondai'},
#  'adennor': {'adonner', 'donnera', 'redonna'},
#  'adopté': {'adopté', 'dépota'},
#  'adopsté': {'adoptés', 'dépotas'},
#  'aadeinort': {'adoraient', 'donataire'},
#  'aadiort': {'adorait', 'radotai'},
#  'aadeorss': {'adorasse', 'adossera'},
#  'aadeorsss': {'adorasses', 'adosseras'},
#  'adenort': {'adorent', 'tornade'},
#  'adeorr': {'adorer', 'dorera', 'redora', 'rodera'},
#  'aadeiorrt': {'adorerait', 'radoterai'},
#  'adeors': {'adores', 'dosera'},
#  'adoré': {'adoré', 'éroda'},
#  'adorsé': {'adorés', 'érodas'},
#  'adeorss': {'adosser', 'dorasse', 'doseras', 'rodasse'},
#  'adeosss': {'adosses', 'dosasse'},
#  'adosssé': {'adossés', 'désossa'},
#  'acdiou': {'adouci', 'coudai'},
#  'acdioru': {'adoucir', 'coudrai', 'radouci'},
#  'acdeinortu': {'adoucirent', 'coudraient'},
#  'acdiosu': {'adoucis', 'coudais'},
#  'acdeiossuz': {'adoucissez', 'coudassiez'},
#  'acdinoosssu': {'adoucissons', 'coudassions'},
#  'acdiotu': {'adoucit', 'coudait'},
#  'aaderss': {'adressa', 'rasades'},
#  'aadeirss': {'adressai', 'radiasse'},
#  'aadeeinrsst': {'adressaient', 'entraidasse'},
#  'aadeirsss': {'adressais', 'radiasses'},
#  'adeerrss': {'adresser', 'desserra', 'dressera', 'redressa'},
#  'adeenorrsst': {'adresseront', 'redorassent'},
#  'adiort': {'adroit', 'dorait', 'rodait'},
#  'adeiort': {'adroite', 'doterai'},
#  'adeiorst': {'adroites', 'doserait', 'doterais'},
#  'adiorst': {'adroits', 'tordais'},
#  'aabdeinorst': {'adsorbaient', 'sabordaient'},
#  'aabdiorss': {'adsorbais', 'sabordais'},
#  'aabdiorst': {'adsorbait', 'sabordait'},
#  'aabdnorst': {'adsorbant', 'sabordant'},
#  'aabdorss': {'adsorbas', 'sabordas'},
#  'aabdenorssst': {'adsorbassent', 'sabordassent'},
#  'aabdeorssss': {'adsorbasses', 'sabordasses'},
#  'aabdeiorsssz': {'adsorbassiez', 'sabordassiez'},
#  'aabdinoorssss': {'adsorbassions', 'sabordassions'},
#  'abdenorst': {'adsorbent', 'sabordent'},
#  'abdeorrs': {'adsorber', 'borderas', 'broderas', 'saborder'},
#  'aabdeeinorrst': {'adsorberaient', 'saborderaient'},
#  'aabdeiorrss': {'adsorberais', 'saborderais'},
#  'aabdeiorrst': {'adsorberait', 'saborderait'},
#  'aabdeorrss': {'adsorberas', 'saborderas'},
#  'abdeeorrsz': {'adsorberez', 'saborderez'},
#  'abdeeiorrsz': {'adsorberiez', 'saborderiez'},
#  'abdeinoorrss': {'adsorberions', 'saborderions'},
#  'abdenoorrss': {'adsorberons', 'saborderons'},
#  'abdenoorrst': {'adsorberont', 'saborderont'},
#  'abdeorss': {'adsorbes', 'bordasse', 'brodasse', 'sabordes'},
#  'abdeorsz': {'adsorbez', 'sabordez'},
#  'abdeiorsz': {'adsorbiez', 'sabordiez'},
#  'abdinoorss': {'adsorbions', 'sabordions'},
#  'abdnoorss': {'adsorbons', 'sabordons'},
#  'abdemorssâ': {'adsorbâmes', 'sabordâmes'},
#  'abdorstâ': {'adsorbât', 'sabordât'},
#  'abdeorsstâ': {'adsorbâtes', 'sabordâtes'},
#  'abdenorrstè': {'adsorbèrent', 'sabordèrent'},
#  'abdeorssé': {'adsorbées', 'dérobasse', 'obséderas', 'sabordées'},
#  'abdorssé': {'adsorbés', 'sabordés'},
#  'aadlsu': {'adulas', 'salaud'},
#  'adeilnorsu': {'adulerions', 'ondulerais'},
#  'adelnorsu': {'adulerons', 'onduleras'},
#  'adilnosu': {'adulions', 'ondulais'},
#  'adlnosu': {'adulons', 'ondulas'},
#  'adlnorstué': {'adultérons', 'déroulants'},
#  'adlué': {'adulé', 'éluda'},
#  'adlsué': {'adulés', 'éludas'},
#  'adeinrv': {'advenir', 'veinard', 'vendrai', 'viendra'},
#  'adeeinssv': {'advenisse', 'devinasse'},
#  'adeeinnsstv': {'advenissent', 'devinassent'},
#  'adeirstvé': {'adversité', 'déversait'},
#  'adeintv': {'advient', 'vendait'},
#  'adintv': {'advint', 'vidant'},
#  'adeinrtv': {'advirent', 'vendrait'},
#  'aabefflru': {'affabuler', 'affublera'},
#  'aaaeffirss': {'affairasse', 'affaissera'},
#  'aaaeffirsss': {'affairasses', 'affaisseras'},
#  'aaeffir': {'affaire', 'effarai'},
#  'aaeeffimnrt': {'affairement', 'affermaient'},
#  'aaeffinorrt': {'affaireront', 'affronterai'},
#  'aaeffirs': {'affaires', 'effarais'},
#  'aaeeffirssz': {'affaisserez', 'effarassiez'},
#  'aaeffinorsss': {'affaisserons', 'effarassions'},
#  'aaefflr': {'affaler', 'raffale'},
#  'aaeffmr': {'affamer', 'afferma'},
#  'aaceeffirt': {'affecterai', 'effacerait'},
#  'aeffimr': {'affermi', 'affirme'},
#  'aeffimrr': {'affermir', 'affirmer', 'raffermi'},
#  'aaeffimrr': {'affermira', 'affirmera'},
#  'aaeffiimrr': {'affermirai', 'affirmerai'},
#  'aaeeffiimnrrt': {'affermiraient', 'affirmeraient'},
#  'aaeffiimrrs': {'affermirais', 'affirmerais'},
#  'aaeffiimrrt': {'affermirait', 'affirmerait'},
#  'aaeffimrrs': {'affermiras', 'affirmeras'},
#  'aeeffimrrz': {'affermirez', 'affirmerez'},
#  'aeeffiimrrz': {'affermiriez', 'affirmeriez'},
#  'aeffiimnorrs': {'affermirions', 'affirmerions'},
#  'aeffimnorrs': {'affermirons', 'affirmerons'},
#  'aeffimnorrt': {'affermiront', 'affirmeront'},
#  'aeffimrs': {'affermis', 'affirmes'},
#  'aaeffimnrsst': {'affermissant', 'affirmassent'},
#  'aaffiil': {'affilai', 'affilia'},
#  'aaffiils': {'affilais', 'affilias', 'falsifia'},
#  'aeffil': {'affile', 'effila'},
#  'aeffilnt': {'affilent', 'effilant'},
#  'aaeffiilr': {'affilerai', 'affiliera'},
#  'aaeffiilrs': {'affilerais', 'affilieras', 'falsifiera'},
#  'aeeffiilrz': {'affileriez', 'affilierez'},
#  'aeffiilnors': {'affilerions', 'affilierons'},
#  'aeffilnort': {'affileront', 'affriolent'},
#  'aeffils': {'affiles', 'effilas'},
#  'aaffiiils': {'affiliais', 'falsifiai'},
#  'aaeffiilsss': {'affiliasses', 'falsifiasse'},
#  'aeffiil': {'affilie', 'effilai'},
#  'aaeffiiilrs': {'affilierais', 'falsifierai'},
#  'aeffiils': {'affilies', 'effilais', 'falsifie'},
#  'aeffiilsé': {'affiliées', 'falsifiée'},
#  'affiilsé': {'affiliés', 'falsifié'},
#  'aeffinr': {'affiner', 'raffine'},
#  'aaefflru': {'affleura', 'affluera'},
#  'aaeffilru': {'affleurai', 'affluerai', 'faufilera'},
#  'aaeeffilnrtu': {'affleuraient', 'afflueraient'},
#  'aaeffilrsu': {'affleurais', 'affluerais', 'faufileras'},
#  'aaeffilrtu': {'affleurait', 'affluerait'},
#  'aaefflrsu': {'affleuras', 'afflueras'},
#  'aeefflru': {'affleure', 'effleura', 'farfelue'},
#  'aeefflnrtu': {'affleurent', 'effleurant'},
#  'aeefflrsu': {'affleures', 'effleuras', 'farfelues'},
#  'aeefflruz': {'affleurez', 'affluerez'},
#  'aeeffilruz': {'affleuriez', 'afflueriez', 'faufilerez'},
#  'aeffilnorsu': {'affleurions', 'affluerions', 'faufilerons'},
#  'aefflnorsu': {'affleurons', 'affluerons'},
#  'aaffilu': {'affluai', 'faufila'},
#  'aaffilsu': {'affluais', 'faufilas'},
#  'aefflru': {'affluer', 'farfelu'},
#  'aeffiluz': {'affluiez', 'faufilez'},
#  'affilnosu': {'affluions', 'faufilons'},
#  'aefflor': {'affoler', 'raffole'},
#  'aaffiilloru': {'affouillira', 'farfouillai'},
#  'aaffiillorsu': {'affouilliras', 'farfouillais'},
#  'aeffiilloruz': {'affouillirez', 'farfouilliez'},
#  'affiillnoorsu': {'affouillirons', 'farfouillions'},
#  'aaffilor': {'affriola', 'raffolai'},
#  'aaeffilnort': {'affriolante', 'raffolaient'},
#  'aaffilors': {'affriolas', 'raffolais'},
#  'aaeffilorr': {'affriolera', 'raffolerai'},
#  'aaeffilorrs': {'affrioleras', 'raffolerais'},
#  'aeeffilorrz': {'affriolerez', 'raffoleriez'},
#  'aeffilnoorrs': {'affriolerons', 'raffolerions'},
#  'aeffilorz': {'affriolez', 'raffoliez'},
#  'affilnoors': {'affriolons', 'raffolions'},
#  'affnort': {'affront', 'offrant'},
#  'affnorsté': {'affrontés', 'affrétons'},
#  'abefflru': {'affubler', 'bluffera'},
#  'aacefiinr': {'africaine', 'fiancerai'},
#  'aacefiinrs': {'africaines', 'fascinerai', 'fiancerais'},
#  'aacfiinrs': {'africains', 'francisai'},
#  'aacegs': {'agaces', 'sagace'},
#  'aagr': {'agar', 'gara'},
#  'aacgir': {'agaric', 'gracia'},
#  'aacgirs': {'agarics', 'gracias'},
#  'aceegn': {'agence', 'encage'},
#  'aceegnnt': {'agencent', 'encagent'},
#  'aceegnr': {'agencer', 'encager', 'encrage'},
#  'aaceegnr': {'agencera', 'encagera'},
#  'aaceeginr': {'agencerai', 'encagerai'},
#  'aaceeeginnrt': {'agenceraient', 'encageraient'},
#  'aaceeginrs': {'agencerais', 'encagerais'},
#  'aaceeginrt': {'agencerait', 'encagerait'},
#  'aaceegnrs': {'agenceras', 'encageras'},
#  'aceeegnrz': {'agencerez', 'encagerez'},
#  'aceeeginrz': {'agenceriez', 'encageriez'},
#  'aceeginnors': {'agencerions', 'encagerions', 'engoncerais'},
#  'aceegnnors': {'agencerons', 'encagerons', 'engonceras'},
#  'aceegnnort': {'agenceront', 'encageront'},
#  'aceegns': {'agences', 'encages'},
#  'aceegnz': {'agencez', 'encagez'},
#  'aceeginz': {'agenciez', 'encagiez'},
#  'aceginnos': {'agencions', 'encagions'},
#  'aceegnnrtè': {'agencèrent', 'encagèrent'},
#  'acegné': {'agencé', 'encagé'},
#  'aceegné': {'agencée', 'encagée'},
#  'aceegnsé': {'agencées', 'encagées'},
#  'acegnsé': {'agencés', 'encagés'},
#  'aaegiillnotu': {'agenouillait', 'gouaillaient'},
#  'aaeegiillnortu': {'agenouillerait', 'gouailleraient'},
#  'aegnt': {'agent', 'gante'},
#  'aegnst': {'agents', 'gantes', 'stagne'},
#  'aegnnosç': {'agençons', 'engonças'},
#  'agi': {'agi', 'gai'},
#  'aegi': {'agie', 'gaie', 'geai'},
#  'aegis': {'agies', 'gaies', 'geais'},
#  'aegil': {'agile', 'aigle', 'gelai'},
#  'aegils': {'agiles', 'aigles', 'gelais', 'glaise'},
#  'aegiort': {'agioter', 'ergotai'},
#  'aegiorstu': {'agioteurs', 'soutirage'},
#  'aagir': {'agira', 'garai'},
#  'aaegiinrt': {'agiraient', 'gainerait'},
#  'aagirs': {'agiras', 'garais'},
#  'aeginrt': {'agirent', 'gantier', 'granite', 'gratine', 'ingrate'},
#  'aegirz': {'agirez', 'gariez', 'gazier', 'ragiez'},
#  'agiinors': {'agirions', 'ignorais'},
#  'aginors': {'agirons', 'garions', 'ignoras', 'ragions', 'rognais'},
#  'aginort': {'agiront', 'rognait'},
#  'agis': {'agis', 'gais'},
#  'aaginsst': {'agissant', 'assignat', 'stagnais'},
#  'aeginsst': {'agissent', 'gisantes', 'tignasse', 'tsiganes'},
#  'aagintt': {'agitant', 'gantait'},
#  'aegirt': {'agiter', 'tirage', 'triage'},
#  'aaegirt': {'agitera', 'rageait'},
#  'aaegiirst': {'agiterais', 'stagiaire'},
#  'aegiinorst': {'agiterions', 'soignerait'},
#  'aeginorst': {'agiterons', 'organiste', 'songerait'},
#  'agiinost': {'agitions', 'soignait'},
#  'agittâ': {'agitât', 'gâtait'},
#  'aegité': {'agitée', 'gaieté', 'étiage'},
#  'aegisté': {'agitées', 'gaietés', 'étiages'},
#  'aeginos': {'agonies', 'agonise', 'songeai'},
#  'aginor': {'agonir', 'ignora', 'rognai'},
#  'aginos': {'agonis', 'soigna'},
#  'aagiinoss': {'agonisais', 'angoissai'},
#  'aaginnosst': {'agonisants', 'angoissant'},
#  'aaginoss': {'agonisas', 'angoissa'},
#  'aaeginossss': {'agonisasses', 'angoissasse'},
#  'aeginnost': {'agonisent', 'soignante'},
#  'aeginors': {'agoniser', 'organise', 'rongeais', 'soignera', 'songerai'},
#  'aaegiinorss': {'agoniserais', 'angoisserai'},
#  'aaeginorss': {'agoniseras', 'angoissera'},
#  'aeginoss': {'agonises', 'angoisse', 'songeais'},
#  'aeginossé': {'agonisées', 'angoissée'},
#  'aginossé': {'agonisés', 'angoissé'},
#  'aaegirr': {'agraire', 'garerai', 'ragerai'},
#  'aaegirrs': {'agraires', 'garerais', 'ragerais'},
#  'aadeginr': {'agrandie', 'daignera', 'drainage'},
#  'aadeginrs': {'agrandies', 'daigneras', 'drainages', 'sardaigne'},
#  'aadginrr': {'agrandir', 'grandira'},
#  'aadeginnrsst': {'agrandissent', 'grandissante'},
#  'aaegrss': {'agressa', 'garasse'},
#  'aaegirsst': {'agressait', 'ratissage'},
#  'aaegnrsst': {'agressant', 'garassent', 'stagneras'},
#  'aaegrsss': {'agressas', 'garasses', 'sargasse'},
#  'aeegrrss': {'agresser', 'serrages'},
#  'aeginorss': {'agression',
#   'angoisser',
#   'ignorasse',
#   'organises',
#   'soigneras',
#   'songerais'},
#  'aeginorsss': {'agressions', 'ignorasses'},
#  'aegnorsss': {'agressons', 'rognasses'},
#  'aegrssé': {'agressé', 'gréasse', 'gérasse'},
#  'aegrsssé': {'agressés', 'gréasses', 'gérasses'},
#  'aeegrsst': {'agrestes', 'tressage'},
#  'acegilrrtuu': {'agriculteur', 'agriculture'},
#  'aegipprr': {'agripper', 'grippera'},
#  'aegmrsu': {'agrumes', 'murages'},
#  'aeggnrtè': {'agrègent', 'gagèrent'},
#  'aagré': {'agréa', 'égara'},
#  'aagiré': {'agréai', 'égarai'},
#  'aaeginrté': {'agréaient', 'égaraient'},
#  'aagirsé': {'agréais', 'égarais'},
#  'aagirté': {'agréait', 'égarait'},
#  'aagnrté': {'agréant', 'égarant'},
#  'aagrsé': {'agréas', 'égaras'},
#  'aaegrssé': {'agréasse', 'égarasse'},
#  'aaegrsssé': {'agréasses', 'égarasses'},
#  'aaegirsszé': {'agréassiez', 'égarassiez'},
#  'aaginorsssé': {'agréassions', 'égarassions'},
#  'aegré': {'agrée', 'garée', 'ragée', 'égare'},
#  'aegnrté': {'agréent',
#   'argenté',
#   'gérante',
#   'renégat',
#   'régenta',
#   'égarent',
#   'étrange'},
#  'aegrré': {'agréer', 'gréera', 'gérera', 'égarer'},
#  'aaegrré': {'agréera', 'égarera'},
#  'aaegirré': {'agréerai', 'égarerai'},
#  'aaeeginrrté': {'agréeraient', 'égareraient'},
#  'aaegirrsé': {'agréerais', 'égarerais'},
#  'aaegirrté': {'agréerait', 'égarerait'},
#  'aaegrrsé': {'agréeras', 'égareras'},
#  'aeegrrzé': {'agréerez', 'égarerez'},
#  'aeegirrzé': {'agréeriez', 'égareriez'},
#  'aeginorrsé': {'agréerions', 'réorganise', 'égarerions'},
#  'aegnorrsé': {'agréerons', 'égarerons'},
#  'aegnorrté': {'agréeront', 'égareront'},
#  'aegrsé': {'agrées', 'garées', 'ragées', 'égares'},
#  'aegrzé': {'agréez', 'égarez'},
#  'aaeggirrsé': {'agrégerais', 'gargarisée'},
#  'aegirzé': {'agréiez', 'égariez'},
#  'aginorsé': {'agréions', 'organisé', 'égarions'},
#  'aegmnrté': {'agrément', 'émargent'},
#  'aaegmnrté': {'agrémenta', 'émargeant'},
#  'aaegimnrté': {'agrémentai', 'ménagerait'},
#  'aaegimnrsté': {'agrémentais', 'magnétisera'},
#  'aaeegmnrssté': {'agrémentasse', 'émargeassent'},
#  'aeegmnrté': {'agrémente', 'égarement', 'émergeant'},
#  'aeegmnnrtté': {'agrémentent', 'étrangement'},
#  'aaeegimnrrté': {'agrémenterai', 'émargeraient'},
#  'aeegmnrsté': {'agrémentes', 'égarements'},
#  'agnorsé': {'agréons', 'orangés', 'égarons'},
#  'aegmrsâé': {'agréâmes', 'égarâmes'},
#  'agrtâé': {'agréât', 'égarât'},
#  'aegrstâé': {'agréâtes', 'égarâtes'},
#  'aegnrrtèé': {'agréèrent', 'égarèrent', 'étrangère'},
#  'agréé': {'agréé', 'égaré'},
#  'aegréé': {'agréée', 'égarée'},
#  'aegrséé': {'agréées', 'égarées'},
#  'agrséé': {'agréés', 'égarés'},
#  'aegirru': {'aguerri', 'aigreur'},
#  'aegirrsu': {'aguerris', 'aigreurs'},
#  'aceghiu': {'aguiche', 'gauchie'},
#  'aceghisu': {'aguiches', 'gauchies'},
#  'agtî': {'agît', 'gîta'},
#  'adeint': {'aident', 'dentai'},
#  'adeir': {'aider', 'aride', 'radie', 'raide'},
#  'adeinors': {'aiderons', 'sonderai'},
#  'adeinort': {'aideront', 'doraient', 'rodaient'},
#  'aeint': {'aient', 'entai'},
#  'aeis': {'aies', 'aise', 'asie', 'saie'},
#  'aefgiiln': {'aiglefin', 'infligea'},
#  'aefgiilns': {'aiglefins', 'infligeas'},
#  'agilno': {'aiglon', 'galion'},
#  'agilnos': {'aiglons', 'galions'},
#  'aeegimnrt': {'aigrement', 'germaient'},
#  'agiirs': {'aigris', 'grisai'},
#  'aagiinrsst': {'aigrissant', 'garnissait'},
#  'aegiinrsst': {'aigrissent', 'astreignis'},
#  'aegiirssz': {'aigrissez', 'graissiez'},
#  'agiinorsss': {'aigrissons', 'graissions'},
#  'aegirstî': {'aigrîtes', 'gîterais'},
#  'aegiillnortu': {'aiguilleront', 'grouillaient', 'guillotinera'},
#  'ail': {'ail', 'lai', 'lia'},
#  'aeil': {'aile', 'laie'},
#  'aeilnors': {'ailerons', 'nolisera'},
#  'aeils': {'ailes', 'alise', 'asile', 'laies', 'salie'},
#  'aeiilr': {'ailier', 'lierai', 'reliai'},
#  'aeiilrs': {'ailiers', 'alisier', 'lierais', 'reliais'},
#  'aeill': {'aille', 'allie'},
#  'aeills': {'ailles', 'allies', 'sellai'},
#  'aeiillz': {'ailliez', 'alliiez'},
#  'aiillnos': {'aillions', 'alliions'},
#  'aillé': {'aillé', 'allié'},
#  'aeillé': {'aillée', 'alliée'},
#  'aeillsé': {'aillées', 'alliées'},
#  'aillsé': {'aillés', 'alliés'},
#  'ails': {'ails', 'lais', 'lias', 'sali'},
#  'ailsé': {'ailés', 'lésai'},
#  'aabeilm': {'aimable', 'amiable'},
#  'aabeeilmmnt': {'aimablement', 'amiablement'},
#  'aabeilms': {'aimables', 'amiables'},
#  'aaaeimnsst': {'aimantasse', 'amassaient'},
#  'aaeimnt': {'aimante', 'amenait', 'amiante', 'entamai'},
#  'aaeimnrt': {'aimanter', 'armaient', 'ramaient', 'ramenait'},
#  'aaaeiimnrst': {'aimanterais', 'samaritaine'},
#  'aaeiimnnorst': {'aimanterions', 'romanisaient'},
#  'aaeimnst': {'aimantes', 'entamais'},
#  'aaiimnnost': {'aimantions', 'animations'},
#  'aaimnté': {'aimanté', 'émanait'},
#  'aaeimss': {'aimasse', 'essaima'},
#  'aaeimnsst': {'aimassent', 'essaimant', 'massaient', 'satanisme'},
#  'aaeimsss': {'aimasses', 'essaimas'},
#  'aeim': {'aime', 'amie', 'maie'},
#  'aeimnt': {'aiment', 'mainte', 'menait'},
#  'aeimr': {'aimer', 'maire', 'marie'},
#  'aeimnors': {'aimerons', 'moraines', 'romaines', 'romanise'},
#  'aeimnort': {'aimeront', 'maronite', 'monterai', 'remontai'},
#  'aeims': {'aimes', 'amies', 'maies', 'semai'},
#  'aimnos': {'aimons', 'maison'},
#  'aimtâ': {'aimât', 'mâtai'},
#  'aeimnrtè': {'aimèrent', 'mènerait'},
#  'aeins': {'aines', 'niase', 'saine', 'sanie'},
#  'aiins': {'ainsi', 'niais'},
#  'air': {'air', 'ira', 'rai'},
#  'aaiinr': {'airain', 'rainai'},
#  'aeir': {'aire', 'raie'},
#  'aeeillrs': {'airelles', 'sellerai'},
#  'aeirs': {'aires', 'raies', 'serai'},
#  'airs': {'airs', 'iras', 'rais', 'sari'},
#  'aaceinss': {'aisances', 'encaissa'},
#  'aeiss': {'aises', 'essai', 'saies'},
#  'aeimnsté': {'aisément', 'étamines'},
#  'aaijortu': {'ajourait', 'rajoutai'},
#  'aejoru': {'ajoure', 'jouera', 'rejoua'},
#  'aejnortu': {'ajourent', 'rejouant'},
#  'aaeijorrtu': {'ajourerait', 'rajouterai'},
#  'aejorsu': {'ajoures', 'joueras', 'rejouas'},
#  'ajnorsué': {'ajournés', 'séjourna'},
#  'aejortu': {'ajouter', 'rajoute'},
#  'aejrstu': {'ajuster', 'juteras', 'rajuste'},
#  'aejsstu': {'ajustes', 'jutasse'},
#  'aijnosstu': {'ajustions', 'jouissant'},
#  'aagilnru': {'alanguir', 'languira'},
#  'aagilnnortu': {'alanguiront', 'granulation'},
#  'aaegilnssu': {'alanguisse', 'alunissage'},
#  'aaegilnsssu': {'alanguisses', 'alunissages'},
#  'aaailmr': {'alarmai', 'malaria'},
#  'aaeilmnorrs': {'alarmerions', 'normalisera'},
#  'aailmnors': {'alarmions', 'normalisa'},
#  'aaeilmrst': {'alarmiste', 'maritales', 'martelais', 'martiales'},
#  'abilnos': {'albinos', 'anoblis'},
#  'aacill': {'alcali', 'cailla'},
#  'aaceilln': {'alcaline', 'alliance', 'canaille'},
#  'aaceillns': {'alcalines', 'alliances', 'canailles'},
#  'aacills': {'alcalis', 'caillas'},
#  'aacillnoost': {'alcoolisant', 'allocations'},
#  'aelnortu': {'alentour', 'relouant', 'roulante'},
#  'aelnorstu': {'alentours', 'roulantes', 'salueront'},
#  'aaelrt': {'alerta', 'relata'},
#  'aaeilrt': {'alertai', 'alitera', 'relatai'},
#  'aaeeilnrtt': {'alertaient', 'relataient'},
#  'aaeilrst': {'alertais', 'aliteras', 'relatais', 'salerait'},
#  'aaeilrtt': {'alertait', 'relatait'},
#  'aaelnrtt': {'alertant', 'alternat', 'relatant'},
#  'aaelrst': {'alertas', 'astrale', 'relatas'},
#  'aaeelrsst': {'alertasse', 'relatasse'},
#  'aaeelnrsstt': {'alertassent', 'relatassent'},
#  'aaeelrssst': {'alertasses', 'relatasses'},
#  'aaeeilrsstz': {'alertassiez', 'relatassiez'},
#  'aaeilnorssst': {'alertassions', 'relatassions'},
#  'aeelrt': {'alerte', 'relate'},
#  'aeelnrtt': {'alertent', 'relatent'},
#  'aeelrrt': {'alerter', 'relater'},
#  'aaeelrrt': {'alertera', 'relatera'},
#  'aaeeilrrt': {'alerterai', 'relaterai'},
#  'aaeeeilnrrtt': {'alerteraient', 'relateraient'},
#  'aaeeilrrst': {'alerterais', 'relaterais'},
#  'aaeeilrrtt': {'alerterait', 'relaterait'},
#  'aaeelrrst': {'alerteras', 'relateras'},
#  'aeeelrrtz': {'alerterez', 'relaterez'},
#  'aeeeilrrtz': {'alerteriez', 'relateriez'},
#  'aeeilnorrst': {'alerterions', 'relaterions', 'rentoileras'},
#  'aeelnorrst': {'alerterons', 'relaterons'},
#  'aeelnorrtt': {'alerteront', 'relateront'},
#  'aeelrst': {'alertes', 'lestera', 'relates'},
#  'aeelrtz': {'alertez', 'relatez'},
#  'aeeilrtz': {'alertiez', 'aliterez', 'relatiez'},
#  'aeilnorst': {'alertions',
#   'aliterons',
#   'laiterons',
#   'relations',
#   'rentoilas'},
#  'aelnorst': {'alertons', 'relatons', 'saleront'},
#  'aeelmrstâ': {'alertâmes', 'relatâmes'},
#  'aelrttâ': {'alertât', 'relatât'},
#  'aeelrsttâ': {'alertâtes', 'relatâtes'},
#  'aeelnrrttè': {'alertèrent', 'relatèrent'},
#  'aelrté': {'alerté', 'relaté', 'étaler'},
#  'aeelrté': {'alertée', 'relatée'},
#  'aeelrsté': {'alertées', 'relatées'},
#  'aelrsté': {'alertés', 'relatés'},
#  'aeilnv': {'alevin', 'envila', 'levain', 'nivela'},
#  'aeeilnv': {'alevine', 'enlevai'},
#  'aeeilnntv': {'alevinent', 'levantine'},
#  'aeeilnsv': {'alevines', 'enlevais', 'vaseline'},
#  'aeilnsv': {'alevins', 'nivelas'},
#  'aeghilmort': {'algorithme', 'logarithme'},
#  'aeghilmorst': {'algorithmes', 'logarithmes'},
#  'aeglu': {'algue', 'gaule'},
#  'aeglsu': {'algues', 'gaules'},
#  'aegilré': {'algérie', 'élargie'},
#  'aegilnré': {'algérien', 'galérien', 'régalien'},
#  'aeegilnnré': {'algérienne', 'régalienne'},
#  'aeegilnnrsé': {'algériennes', 'régaliennes'},
#  'aegilnrsé': {'algériens', 'galériens', 'régaliens'},
#  'aails': {'alias', 'salai'},
#  'aagiln': {'aligna', 'glanai'},
#  'aagiilns': {'alignais', 'signalai'},
#  'aagilns': {'alignas', 'anglais', 'glanais', 'sanglai', 'signala'},
#  'aaegilnss': {'alignasse', 'anglaises'},
#  'aaegilnsss': {'alignasses', 'signalasse'},
#  'aeegilmnnst': {'alignements', 'signalement'},
#  'aaegilnr': {'alignera', 'glanerai', 'langerai'},
#  'aaegiilnrs': {'alignerais', 'signalerai'},
#  'aaegilnrs': {'aligneras',
#   'glanerais',
#   'langerais',
#   'sanglerai',
#   'signalera'},
#  'aeegilnrz': {'alignerez', 'glaneriez', 'langeriez'},
#  'aegilnnors': {'alignerons', 'glanerions', 'langerions'},
#  'aegilnnort': {'aligneront', 'lorgnaient'},
#  'aegilns': {'alignes', 'signale'},
#  'aegilnz': {'alignez', 'glaniez', 'langiez'},
#  'agilnnos': {'alignons', 'glanions', 'langions'},
#  'agilné': {'aligné', 'génial', 'inégal'},
#  'aegilné': {'alignée', 'géniale', 'inégale'},
#  'aegilnsé': {'alignées', 'géniales', 'inégales', 'signalée'},
#  'agilnsé': {'alignés', 'signalé'},
#  'aaeilmnt': {'alimenta', 'lamentai', 'matinale'},
#  'aaeeiilmnrt': {'alimentaire', 'alimenterai'},
#  'aaeeiilmnrst': {'alimentaires', 'alimenterais'},
#  'aaeilmnst': {'alimentas', 'lamentais', 'matinales'},
#  'aeeilmnrt': {'alimenter', 'terminale'},
#  'aaeeilmnrt': {'alimentera', 'lamenterai'},
#  'aaeeilmnrst': {'alimenteras', 'lamenterais'},
#  'aeeeilmnrtz': {'alimenterez', 'lamenteriez'},
#  'aeeilmnnorst': {'alimenterons', 'lamenterions'},
#  'aeeilmntz': {'alimentez', 'lamentiez'},
#  'aeilmnnost': {'alimentons', 'lamentions'},
#  'aailné': {'alinéa', 'aliéna'},
#  'aailnsé': {'alinéas', 'aliénas'},
#  'aeilss': {'alises', 'asiles', 'laisse', 'liasse', 'salies'},
#  'aeiilrss': {'alisiers', 'lisserai', 'relisais'},
#  'aailst': {'alitas', 'salait'},
#  'aeilt': {'alite', 'laite'},
#  'aeilrt': {'aliter', 'altier'},
#  'aeiilnorst': {'aliterions', 'rentoilais'},
#  'aeilst': {'alites', 'laites', 'lestai'},
#  'aiilnost': {'alitions', 'nolisait'},
#  'ailnost': {'alitons', 'isolant', 'laitons', 'talions'},
#  'ailté': {'alité', 'laité'},
#  'aeilté': {'alitée', 'laitée'},
#  'aeilsté': {'alitées', 'laitées'},
#  'ailsté': {'alités', 'laités', 'lésait'},
#  'aeilszé': {'alizées', 'alésiez'},
#  'aaeilnssé': {'aliénasse', 'nasalisée'},
#  'aaeilnsssé': {'aliénasses', 'nasalisées'},
#  'aaiilnnosté': {'aliénations', 'nationalisé'},
#  'aaill': {'allai', 'allia'},
#  'aaeillnt': {'allaient', 'entailla', 'tenailla'},
#  'aaills': {'allais', 'allias'},
#  'aaillt': {'allait', 'tailla'},
#  'aaeillrt': {'allaiter', 'retailla', 'taillera'},
#  'aaeillssz': {'allassiez', 'assaillez'},
#  'aaillnosss': {'allassions', 'assaillons'},
#  'aacillé': {'alliacé', 'écailla'},
#  'aacillsé': {'alliacés', 'écaillas'},
#  'aaeiillnt': {'alliaient', 'entaillai', 'tenaillai'},
#  'aaiillt': {'alliait', 'taillai'},
#  'aaeillss': {'alliasse', 'assaille'},
#  'aaeillnsst': {'alliassent', 'assaillent', 'saillantes'},
#  'aaeillsss': {'alliasses', 'assailles'},
#  'aaeiillssz': {'alliassiez', 'assailliez'},
#  'aaiillnosss': {'alliassions', 'assaillions'},
#  'aeillr': {'allier', 'raille', 'rallie'},
#  'aaeeiillnrt': {'allieraient', 'entaillerai', 'tenaillerai'},
#  'aaeiillrt': {'allierait', 'retaillai', 'taillerai'},
#  'aillté': {'allité', 'taillé'},
#  'aegllnor': {'allonger', 'rallonge'},
#  'aaegllnor': {'allongera', 'rallongea'},
#  'aaegillnor': {'allongerai', 'rallongeai'},
#  'aaeegillnnort': {'allongeraient', 'rallongeaient'},
#  'aaegillnors': {'allongerais', 'rallongeais'},
#  'aaegillnort': {'allongerait', 'rallongeait'},
#  'aaegllnors': {'allongeras', 'rallongeas'},
#  'aegllnnoors': {'allongerons', 'rallongeons'},
#  'aegllnosé': {'allongées', 'allégeons'},
#  'aellmru': {'allumer', 'rallume'},
#  'afillsu': {'allusif', 'fusilla'},
#  'afillssu': {'allusifs', 'fusillas'},
#  'aeegllmnté': {'allégement', 'légalement'},
#  'aaegillré': {'allégerai', 'égaillera'},
#  'aaegillrsé': {'allégerais', 'légalisera', 'égailleras'},
#  'aeegillrzé': {'allégeriez', 'égaillerez'},
#  'aegillnorsé': {'allégerions', 'égaillerons'},
#  'aegllnorsé': {'allégerons', 'rallongées'},
#  'aegillzé': {'allégiez', 'égaillez'},
#  'agillnosé': {'allégions', 'égaillons'},
#  'aegillorsé': {'allégories', 'égosillera'},
#  'ailos': {'alois', 'isola'},
#  'aeloss': {'aloses', 'assole'},
#  'aelp': {'alpe', 'lape', 'pela'},
#  'aelps': {'alpes', 'lapes', 'pelas'},
#  'aeelprst': {'alpestre', 'palestre'},
#  'aeelprsst': {'alpestres', 'palestres'},
#  'ailnp': {'alpin', 'lapin', 'plain'},
#  'aeilnp': {'alpine', 'lapine', 'plaine'},
#  'aeilnps': {'alpines', 'lapines', 'plaines'},
#  'aeiilnpsst': {'alpinistes', 'plissaient'},
#  'ailnps': {'alpins', 'lapins', 'plains'},
#  'aacels': {'alsace', 'salace'},
#  'aaceilns': {'alsacien', 'canalise'},
#  'aaceilnss': {'alsaciens', 'canalises'},
#  'aeilnnorst': {'alternions', 'rationnels'},
#  'aelnrttâ': {'alternât', 'râtelant'},
#  'aeelssst': {'altesses', 'lestasse'},
#  'adeilttu': {'altitude', 'latitude'},
#  'adeilsttu': {'altitudes', 'latitudes'},
#  'aeilmrstu': {'altruisme', 'mutileras', 'stimulera'},
#  'aeilmrsstu': {'altruismes', 'stimuleras'},
#  'aeilrsttu': {'altruiste', 'lutterais'},
#  'aeilnorrsté': {'altérerions', 'réaliseront'},
#  'aalsé': {'aléas', 'alésa'},
#  'aaeglssé': {'alésages', 'égalasse'},
#  'aailsté': {'alésait', 'étalais'},
#  'aelrsé': {'aléser', 'lésera'},
#  'aaeilrsé': {'aléserai', 'salariée'},
#  'aaeilrssé': {'aléserais', 'salariées'},
#  'aaeilrsté': {'aléserait', 'étalerais'},
#  'aelnorsté': {'aléseront', 'étalerons'},
#  'aaegiimr': {'amaigrie', 'imagerai'},
#  'aaegiimrs': {'amaigries', 'imagerais'},
#  'aagiimrr': {'amaigrir', 'maigrira'},
#  'aademn': {'amande', 'amenda'},
#  'aademns': {'amandes', 'amendas'},
#  'aadeimnr': {'amandier', 'damnerai', 'manderai', 'marinade'},
#  'aadeimnrs': {'amandiers', 'damnerais', 'manderais', 'marinades'},
#  'aaemnt': {'amante', 'entama'},
#  'aaemnst': {'amantes', 'entamas'},
#  'aaaegmrr': {'amarrage', 'ramagera'},
#  'aaaegmrrs': {'amarrages', 'ramageras'},
#  'aaaemrrss': {'amarrasse', 'ramassera'},
#  'aaaemrrsss': {'amarrasses', 'ramasseras'},
#  'aaemrr': {'amarre', 'armera', 'ramera'},
#  'aaemnrrt': {'amarrent', 'marrante'},
#  'aaemrrr': {'amarrer', 'marrera'},
#  'aaemrrs': {'amarres', 'armeras', 'rameras'},
#  'aamrré': {'amarré', 'réarma'},
#  'aamrrsé': {'amarrés', 'réarmas'},
#  'aaemrss': {'amasser', 'armasse', 'massera', 'ramasse'},
#  'aaeimnorsss': {'amasserions', 'romanisasse'},
#  'aaemnorsss': {'amasserons', 'ramonasses'},
#  'aaemrtu': {'amateur', 'marteau'},
#  'abelms': {'ambles', 'sembla'},
#  'aabmr': {'ambra', 'brama'},
#  'aabimr': {'ambrai', 'bramai'},
#  'aabeimnrt': {'ambraient', 'bramaient'},
#  'aabimrs': {'ambrais', 'bramais'},
#  'aabimrt': {'ambrait', 'bramait'},
#  'aabmnrt': {'ambrant', 'bramant'},
#  'aabmrs': {'ambras', 'bramas'},
#  'aabemrss': {'ambrasse', 'bramasse', 'embrasas', 'embrassa'},
#  'aabemnrsst': {'ambrassent', 'bramassent', 'embrassant'},
#  'aabemrsss': {'ambrasses', 'bramasses', 'embrassas'},
#  'aabeimrssz': {'ambrassiez', 'bramassiez'},
#  'aabimnorsss': {'ambrassions', 'bramassions'},
#  'abemr': {'ambre', 'brame'},
#  'abemrr': {'ambrer', 'bramer', 'marbre'},
#  'aabemrr': {'ambrera', 'bramera'},
#  'aabeimrr': {'ambrerai', 'bramerai'},
#  'aabeeimnrrt': {'ambreraient', 'brameraient'},
#  'aabeimrrs': {'ambrerais', 'bramerais'},
#  'aabeimrrt': {'ambrerait', 'bramerait'},
#  'aabemrrs': {'ambreras', 'brameras', 'embarras'},
#  'abeemrrz': {'ambrerez', 'bramerez'},
#  'abeeimrrz': {'ambreriez', 'brameriez'},
#  'abeimnorrs': {'ambrerions', 'bramerions'},
#  'abemnorrs': {'ambrerons', 'bramerons'},
#  'abemnorrt': {'ambreront', 'brameront'},
#  'abemrs': {'ambres', 'brames'},
#  'abemrz': {'ambrez', 'bramez'},
#  'abeimrz': {'ambriez', 'bramiez'},
#  'abimnors': {'ambrions', 'bramions'},
#  'abmnors': {'ambrons', 'bramons'},
#  'abemmrsâ': {'ambrâmes', 'bramâmes'},
#  'abmrtâ': {'ambrât', 'bramât'},
#  'abemrstâ': {'ambrâtes', 'bramâtes', 'embrasât'},
#  'abemnrrtè': {'ambrèrent', 'bramèrent'},
#  'abmré': {'ambré', 'bramé'},
#  'abemré': {'ambrée', 'bramée'},
#  'abemrsé': {'ambrées', 'bramées', 'embrasé'},
#  'abmrsé': {'ambrés', 'bramés'},
#  'aemn': {'amen', 'mena'},
#  'aadeimnt': {'amendait', 'damaient'},
#  'aadeimnnosss': {'amendassions', 'amidonnasses'},
#  'aadeeimnrt': {'amenderait', 'dameraient'},
#  'adeimnnos': {'amendions', 'amidonnes', 'mondaines'},
#  'ademné': {'amendé', 'damnée', 'démena', 'mandée'},
#  'ademnsé': {'amendés', 'damnées', 'démenas', 'mandées'},
#  'aeimnnos': {'amenions', 'monnaies', 'onanisme'},
#  'aemns': {'amens', 'menas'},
#  'aeeimnnstu': {'amenuisent', 'maintenues'},
#  'aemné': {'amené', 'émane'},
#  'aemnsé': {'amenés', 'émanes'},
#  'aemr': {'amer', 'arme', 'mare', 'rame'},
#  'aeimrr': {'amerri', 'arrime', 'marier', 'mirera', 'ramier', 'rimera'},
#  'aeeimrr': {'amerrie', 'remarie'},
#  'aeeimrrs': {'amerries', 'remaries', 'remisera'},
#  'aeimrrr': {'amerrir', 'arrimer'},
#  'aaeimrrr': {'amerrira', 'arrimera', 'marrerai'},
#  'aaeiimrrr': {'amerrirai', 'arrimerai'},
#  'aaeeiimnrrrt': {'amerriraient', 'arrimeraient'},
#  'aaeiimrrrs': {'amerrirais', 'arrimerais'},
#  'aaeiimrrrt': {'amerrirait', 'arrimerait'},
#  'aaeimrrrs': {'amerriras', 'arrimeras', 'marrerais'},
#  'aeeimrrrz': {'amerrirez', 'arrimerez', 'marreriez'},
#  'aeeiimrrrz': {'amerririez', 'arrimeriez'},
#  'aeiimnorrrs': {'amerririons', 'arrimerions'},
#  'aeimnorrrs': {'amerrirons', 'arrimerons', 'marrerions'},
#  'aeimnorrrt': {'amerriront', 'arrimeront'},
#  'aeimrrs': {'amerris', 'arrimes', 'mireras', 'ramiers', 'rimeras', 'simarre'},
#  'aaeimnrrsst': {'amerrissant', 'arrimassent'},
#  'aeeimrrss': {'amerrisse', 'remiseras'},
#  'aeeimnrrsst': {'amerrissent', 'retransmise'},
#  'aeimrrt': {'amerrit', 'trimera'},
#  'aemrs': {'amers', 'armes', 'mares', 'rames'},
#  'abeilmu': {'ameubli', 'meublai'},
#  'abeilmsu': {'ameublis', 'meublais'},
#  'abeilmnosssu': {'ameublissons', 'meublassions'},
#  'abeilmtu': {'ameublit', 'meublait'},
#  'aemnostu': {'ameutons', 'automnes'},
#  'aim': {'ami', 'mai'},
#  'aacilm': {'amical', 'calmai', 'clamai'},
#  'adimno': {'amidon', 'domina', 'mondai'},
#  'adeimnno': {'amidonne', 'mondaine'},
#  'adeimnnor': {'amidonner', 'normandie'},
#  'aeimns': {'amiens', 'animes', 'manies', 'menais'},
#  'aimnsé': {'aminés', 'animés', 'maniés'},
#  'aaimrtué': {'amirauté', 'matériau'},
#  'aims': {'amis', 'mais', 'misa'},
#  'aeiimnst': {'amnistie', 'animiste', 'misaient', 'mitaines'},
#  'aeiimnrst': {'amnistier', 'intimeras', 'mentirais', 'terminais'},
#  ...}

# %%
# smart anagram search: look up myword's signature, return set

def find_anagram_fast(myword):
    sig = signature(myword)
    
    return anagrams_by_sig[sig]

# %%
find_anagram_fast('arts')
# Out:
# {'arts', 'rats', 'star', 'tsar'}

# %%
find_anagram_fast('martialo')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c818177fbbdf> in <module>
# ----> 1 find_anagram_fast('martialo')
#
# <ipython-input-19-7c5abf600b7f> in find_anagram_fast(myword)
#       4     sig = signature(myword)
#       5
# ----> 6     return anagrams_by_sig[sig]
#
# KeyError: 'aailmort'

# %%
# handle case when myword's signature is not found, returning the empty set

def find_anagram_fast(myword):
    sig = signature(myword)

    try:
        return anagrams_by_sig[sig]
    except KeyError:
        return set()

# %%
find_anagram_fast('martialo')
# Out:
# set()

# %%
# %time find_anagram_fast('armée')
# Out:
# Wall time: 0 ns
# {'armée', 'marée', 'ramée'}

# %%
# list of signatures, sorted by length, longest first
sorted(anagrams_by_sig.keys(), key=len, reverse=True)
# Out:
# [' aacehhiiiprrrsséé',
#  'aaeeiimnnnnorsttu',
#  'aceiiimmnnoorsss',
#  'abdiillnoorsssué',
#  ' aahiinoprssssué',
#  ' aehiinnnoprrsté',
#  'aeeiiimnnoprrsss',
#  'aaeeiimnnnnorttu',
#  'aeiilnnoorrstuvé',
#  'aeiiimnnoorssssu',
#  'aceiiimmnnoorss',
#  'aceeiinnorstttu',
#  'aceegiinnnorstt',
#  'abdeillnorsstué',
#  'abdeiillorssuzé',
#  'adeiiimnnorsssé',
#  'eeeimmnnnoopsst',
#  ' aaehinprssstué',
#  ' aaehiiprsssuzé',
#  'aeeiiimnnoprrss',
#  'aaaeiiilnnorstt',
#  'aeeiilnnprrttuu',
#  'aceeiinnoprrsté',
#  'ceeiinorrsssstu',
#  'aaaeeiillnrrttv',
#  'aeiilnnoorrtuvé',
#  'aeiiimnnoorsssu',
#  'aacceiilmnorst',
#  'aaeegiillnortu',
#  'aeeillmmnossst',
#  'abeeginnnoortu',
#  'abeeinnnoorttu',
#  'aceiinnnoorstu',
#  'aaceiilnnorstt',
#  'acefiiinorssst',
#  'aceeefiiinrrtt',
#  'aacdeeimmnnort',
#  'aacdeiimmnorst',
#  'acceeeimmnorrt',
#  'aceinnoorssssv',
#  'aceeeinnorrstv',
#  'ceiinnoorssttu',
#  'acdeeiinnnortt',
#  'acdeeiinnorrtt',
#  'aceeiinorrsttu',
#  'adeeinorrsssss',
#  'adeeeeinrrrsst',
#  'adeeeiinrrsstt',
#  'adeeeiinrrsstv',
#  'acdeiiiilnprss',
#  'abdeillorsssué',
#  'accdeeinnortté',
#  'adeiiimnnorssé',
#  'aeeimnnoopssss',
#  'aeeiimnnooprss',
#  'aeeiimnnoprrss',
#  'aeeegiinnrrstt',
#  'aaeiillnnossst',
#  'aaeeeiillnnrtt',
#  'aeeiillnorrttt',
#  'eeiinnoprrssst',
#  'aaeeeiillnrrtt',
#  'acefiinnnoorst',
#  'aacefiinnorrst',
#  'aceefiiilnrtté',
#  ' aaeghinprrssé',
#  ' aaehiprssssué',
#  ' aaehiiprrsssé',
#  ' aaehiiprrstué',
#  'aeegiinorrsttv',
#  'affinooqssssuu',
#  'aeeffinoqrstuu',
#  'aaeeeilmnprrst',
#  'aaceiilprrstué',
#  'aaeiilloprrttu',
#  'eiilnnoprrstuu',
#  'aaeiilnnoprsst',
#  'abceiiilprssté',
#  'aeeeinnprrstté',
#  'aeiiinnoprstté',
#  'aeeiinnoqrsstu',
#  'aceeiiillnqrsu',
#  'aaeiillnorrstv',
#  'cdeinoorrrsuvé',
#  'aaeegiinnrrsst',
#  'aaeeiilnorrstv',
#  'aeeegilmnrrsté',
#  'aacfiiinorssss',
#  'aaccefiirrsstu',
#  'aaceefiiinrrst',
#  'abdeinnoorrssu',
#  'aabeiimnorrstu',
#  'aabdeinorrstu',
#  'aceiinnnoorst',
#  'aabdinoorssss',
#  'aabdeeinorrst',
#  'aaeeffiimnrrt',
#  'affiillnoorsu',
#  'aaeegillnnort',
#  'aaceeinnnnort',
#  'aaaeeinnpprtt',
#  'aachiinorsssv',
#  'aaceehiinrrtv',
#  'aaeginnorssst',
#  'aaeegimnrrstu',
#  'aaeegiinnrsst',
#  'aaeegiinnrstt',
#  'aehimopqrstué',
#  'beginnnooorsu',
#  'abdennoorsssu',
#  'abdeinnoorrsu',
#  'beinnnooorstu',
#  'abceinnoorrst',
#  'abcefiiinrséé',
#  'acceehinorstt',
#  'aaceinnnossst',
#  'aaceilnorrsss',
#  'aceeinnorrrst',
#  'aceinnnoorstu',
#  'aceinnnoorttu',
#  'aaceeilnrssst',
#  'aaceeiilnrrst',
#  'aceefiinrsstt',
#  'aceefiiirsstz',
#  'ceefiiinorrst',
#  'aabceehimnrrt',
#  'aaceehinrsstu',
#  'acceeehhinrrt',
#  'abciimnnoosss',
#  'abceeiimnnort',
#  'acdeimmnnoors',
#  'aacdeiimmnort',
#  'cceeimmnnoors',
#  'aacimnooprsss',
#  'aceeimnooprst',
#  'acceinnoorstt',
#  'accdeeinnorté',
#  'aceeiillnorst',
#  'aceennorssstv',
#  'aceeinorsssvz',
#  'aceenorrsstuv',
#  'aceinnoorsstv',
#  'ceeinnoorrssv',
#  'aceeinnorrsst',
#  'aceeinnorrstt',
#  'aceiinorssttu',
#  'aceiinorstttu',
#  'ceeiinorsttuz',
#  'ceinnoorssttu',
#  'ceeinnnoorstt',
#  'aciinnnoosttu',
#  'acegiinnorsst',
#  'aaceinorrssst',
#  'ceeinorrsstuv',
#  'aceinoprssstu',
#  'aceiillorrstu',
#  'acdeeiinrrtté',
#  'aciilmnnosssu',
#  'aaddeeeimnnrt',
#  'adeeenrrsssst',
#  'adeeeirrssssz',
#  'deeeinorrrsss',
#  'deeiinorrssst',
#  'adeeinrsssstt',
#  'deeiinorrsssv',
#  'acdeffiinnrté',
#  'acdeiiiilnprs',
#  'adeeiiinprsst',
#  'adiiimnnossté',
#  'acdeeimnorstu',
#  'acdeiiiilmors',
#  'abdeillorssué',
#  'cdeeinnorrsté',
#  'acdilnoosssué',
#  'acdeeilnortué',
#  'acdeffinossté',
#  'acdeinorsssté',
#  'acdeefinnorté',
#  'adgiinnorsssé',
#  'degiinoprrsué',
#  'adeeiimnnrtté',
#  'aacdeimorrsté',
#  'adiinoprsssté',
#  'adeeinorsssté',
#  'aeeimnnooprss',
#  'aeimnooprssst',
#  'aeeeimnoprrtt',
#  'ceehinrrsssué',
#  'adeeiimnnorrt',
#  'aceefhinorrtu',
#  'aeeegginnorrt',
#  'aaeegiinrrsst',
#  'eegiinnorrsst',
#  'aaeeillnnsstt',
#  'aaeeiillnsstz',
#  'aeeiillnnorst',
#  'aeeillnorsstt',
#  'aceeeinoprrtu',
#  'adeeeinnprrrt',
#  'eeeinnprrsstt',
#  'eeeiinprrsstz',
#  'adeeeiinnrrtt',
#  'aacffiiilnost',
#  'aeefimnnorstt',
#  'acefiinnnoort',
#  'aacefiinnorrt',
#  'aefiinnorrsst',
#  'acefiinnorsst',
#  'cefiiilnorsté',
#  'aagiinnorssst',
#  'aaeegiinnrrtt',
#  ' aahinprsttâé',
#  ' aaeghinprrsé',
#  ' aaehiprsssué',
#  'aeiilmmorssté',
#  'aeimnoprssstu',
#  'ceiinnorrsstu',
#  'eiiinnoqrstué',
#  'aeiinnorrsstu',
#  'aeeilmnnrsttu',
#  'eeilnnooprrst',
#  'aeeiinnoprstt',
#  'aeeiinoprrstt',
#  'aeeeiinnnrttv',
#  'eiiilnnorsttu',
#  'aeeinnrssstté',
#  'aeeiinrrsstté',
#  'aeiinnnossstv',
#  'aegimnnorssté',
#  'aaeilmnorssst',
#  'aeeiimnnnortt',
#  'afiiinnoossst',
#  'aeefiiinnortt',
#  'aeffnoqssstuu',
#  'aeffioqsssuuz',
#  'effinooqrssuu',
#  'aeeeimnnorrtt',
#  'ceilorrsttuué',
#  'aiillnoossstu',
#  'aeeiillnorttu',
#  'aaeinoprsssss',
#  'aaeeeinprrsst',
#  'aaeeeilmnprrt',
#  'aeiilnprrstuu',
#  'aeiilnprrttuu',
#  'eeiilnprrtuuz',
#  'eilnnoprrstuu',
#  'aeeiinnnoprss',
#  'aeghooprrstuv',
#  'aeeiiinnprtté',
#  'abceiiilprsté',
#  'adeeiinprrsté',
#  'eeinoprrsttxé',
#  'eeinnoprrssté',
#  'aeiiinnoprtté',
#  'aeeiinnoqrstu',
#  'aceeiiillnqru',
#  'aaeeiinprsstt',
#  'aeinorrsssstt',
#  'aacfiiinorstt',
#  'aaeinoprrrstt',
#  'aaaeiillrrstv',
#  'aaeeiillrrtvz',
#  'aaceinnnorsst',
#  'deeiinnorsssv',
#  'acdeiorrrsuvé',
#  'cdeeiorrruvzé',
#  'aaeeegginnrrt',
#  'aegiinnorrsss',
#  'aeiinoprrssss',
#  'aeeeiinprrrst',
#  'aeeiinrssssst',
#  'aaceehinnrrtt',
#  'aaaeiillrrttv',
#  'aaeillnorrstv',
#  'aeeinorrssttu',
#  'aeiilnoorrssv',
#  'aeefiiiinrtvv',
#  'aeeegilmnrrté',
#  'aacefiinrssst',
#  'aacefiiirsssz',
#  'aaccefiirrstu',
#  'acefiiinorrss',
#  'aaeiinnorsstt',
#  'abdennoorrssu',
#  'aeeinopprsstu',
#  'aabeiimnorrtu',
#  'abiinorssstu',
#  'abdeinnorsst',
#  'aacceeinrstu',
#  'acceinnoortt',
#  'accdeinoorrs',
#  'aaccenossstt',
#  'aaceeinqrrtu',
#  'aaceiinnorst',
#  'aaceiinnortt',
#  'aceinnnoorst',
#  'accenoprstuu',
#  'accenprstuuu',
#  'aabdenorssst',
#  'aabdeiorsssz',
#  'abdeinoorrss',
#  'aaeffinorsss',
#  'aeffiimnorrs',
#  'aaeffimnrsst',
#  'aaeeffilnrtu',
#  'aaffiillorsu',
#  'aeffiilloruz',
#  'aeffilnoorrs',
#  'aaceeeginnrt',
#  'aaegiillnotu',
#  'aadeginnrsst',
#  'aaeegmnrssté',
#  'aaeegimnrrté',
#  'aegiillnortu',
#  'aaeiimnnorst',
#  'aaeilnorssst',
#  'aaeeeilnrrtt',
#  'aaeeiilmnrst',
#  'aeeilmnnorst',
#  'aadeimnnosss',
#  'aaeeiimnrrrt',
#  'abeilmnosssu',
#  'aeiimnnorsst',
#  'aaceiimnrssé',
#  'aaceeiillnrs',
#  'aeginnoorsss',
#  'aceinnnnoors',
#  'aceiinnoprst',
#  'aiinorrsttéé',
#  'aaeinnnsstté',
#  'aaeinnopprst',
#  'aaaeinpprsst',
#  'aacehinrsstv',
#  'aacehiirssvz',
#  'acehiinorrsv',
#  'aaeegimnrrtu',
#  'adeinnorrsst',
#  'aaceiilrrstu',
#  'aeeinoprssst',
#  'aaeiillnrsst',
#  'aaiillnorsss',
#  'aaiinnosssss',
#  'aegiinnorsss',
#  'aaeiiilmnsst',
#  'aegiinorsssé',
#  'ainoopsssssu',
#  'aadeiinrrsst',
#  'aadeiinrrstt',
#  'adeinnorrstt',
#  'aaeiirrssttt',
#  'aaiinorssstt',
#  'aaeeiinrrttt',
#  'aaeinoprrstt',
#  'aaefiinrsstu',
#  'aaeiiorrsttu',
#  'aaeeinrrttuv',
#  'aeiinorssstv',
#  'abcehinoorst',
#  'aabeilnnorss',
#  'aabeilnnorst',
#  'abeeeirrsttv',
#  'abceehinortu',
#  'abeginnoorsu',
#  'abeginnoortu',
#  'beeginnooruz',
#  'begnnnooorsu',
#  'abdennoorrsu',
#  'abeinnoorstu',
#  'abeinnoorttu',
#  'beeinnoortuz',
#  'bennnooorstu',
#  'abcehinnorrs',
#  'abinoorssstu',
#  'abeeinorrttu',
#  'abeeiinnrrtu',
#  'abeeiillnrtâ',
#  'abcefiiinréé',
#  'acceehnorstt',
#  'aacilnoqsssu',
#  'aaceeilnqrtu',
#  'aaceilnnorss',
#  'aaceinnnorst',
#  'aaceinnnortt',
#  'aceinoprrstu',
#  'aaceenrsssst',
#  'aaceeilrrssz',
#  'aaceinorrsst',
#  'aceeinnorrrt',
#  'aceeinnorrst',
#  'aceeemnnrsst',
#  'aaceeinrrstt',
#  'aacgilnoostu',
#  'aciinnnoostu',
#  'aaceeilnrrst',
#  'acceeeilnrrt',
#  'aceefiiinrtt',
#  'aceefiirssst',
#  'aceefiiirrst',
#  'aceefiiirrtt',
#  'ceeefiiirrtz',
#  'ceefiinorrst',
#  'ceefiinorrtt',
#  'ceefiinrrttè',
#  'aaceehinnrtt',
#  'aacehinnoprs',
#  'aachimnorsss',
#  'aaceehimnrrt',
#  'acehinorsssu',
#  'cceehhinorrs',
#  'aceehinoqrtu',
#  'acehiiinrsst',
#  'acehiinrssté',
#  'acgiilnnosss',
#  'aceegiilnnrt',
#  'acceiinnorsv',
#  'aacefiilrsss',
#  'aaceeilnrsst',
#  'cceehinnoors',
#  'aceeffiinort',
#  'ceilnnooorss',
#  'abceimnnosst',
#  'abceiimnossz',
#  'bceiimnnoors',
#  'aacdeimmnors',
#  'aacdeimmnort',
#  'acdeeimmnorz',
#  'acdemmnnoors',
#  'acdimmnnoost',
#  'cceeeimmnorz',
#  'aceeimmnorst',
#  'aceeimmnortç',
#  'acimmnnooost',
#  'aaceimoprssz',
#  'acimnoopssst',
#  'aceilmoprstu',
#  'ceimmnooprrt',
#  'acceeinnorrt',
#  'acceeinnortt',
#  'cdeiinnorstu',
#  'acefiimnorrt',
#  'aceglnorstué',
#  'ccejnnoorstu',
#  'aceiinnorstt',
#  'ceinnnoorsst',
#  'aceeinnorstv',
#  'aceenorssssv',
#  'aceinnoorstv',
#  'aceeinorrssv',
#  'aceeinorrstv',
#  'ceeeinorrsvz',
#  'ceennoorrssv',
#  'ceennoorrstv',
#  'ceennorrstvè',
#  'acegiinnorst',
#  'aceellnorsst',
#  'aceennorrsst',
#  'aceiinoprsst',
#  'aceiinorsttu',
#  'aceinorssttu',
#  'ceeinorsttuz',
#  'ceinorsssstu',
#  'cdeinnnoorst',
#  'acdeiinnorst',
#  'acdeiinnortt',
#  'ceinnnoorstu',
#  'aceinnoorrtu',
#  'aacenorrsstt',
#  'acdeinnorstt',
#  'cdeeinnoorrs',
#  'abceeinorrtu',
#  'ciinoorsssuv',
#  'aacceehinrrt',
#  'aceiillnrsst',
#  'acceehinortt',
#  'aceeiinorrst',
#  'aceiilmnssuz',
#  'adeeeinrrsst',
#  'adeeerrsssss',
#  'adeeeirrrsss',
#  'adeeeirrrsst',
#  'deeeeirrrssz',
#  'deeenorrrsss',
#  'deeenorrrsst',
#  'deeenrrrsstè',
#  'adeeiirrssst',
#  'adeeiirrsstt',
#  'deeeiirrsstz',
#  'deeinorrssst',
#  'deeinorrsstt',
#  'adeeiirrsssv',
#  'adeeiirrsstv',
#  'deeeinrrsstv',
#  'deeeiirrssvz',
#  'deeinorrsssv',
#  'acdeffiinrsé',
#  'adgiinorsssé',
#  'adeegiinrrté',
#  'acdeeiinnrst',
#  'acdeiinorstu',
#  'acdiilnopstu',
#  'adeeiinprsss',
#  'adeeiinprsst',
#  'acdeeimnortu',
#  'acdeiiiilmor',
#  'abdeeilnortu',
#  'aadginorsssu',
#  'aadeeginrrtu',
#  'acdeiinrsstu',
#  'acdeinorssté',
#  'aacdeeilnrté',
#  'acdiinosssté',
#  'acdeeinrrsté',
#  'cdeeeinrrtzé',
#  'acdeennrssté',
#  'acdelnosstué',
#  'acdeilossuzé',
#  'cdeilnoorsué',
#  'acdeeiinrrté',
#  'cdefinnoorsé',
#  'adfinorssséé',
#  'adeefinrrtéé',
#  'adegiinrsszé',
#  'adfiiinosssé',
#  'acdfiiinosté',
#  'adeefiiinrté',
#  'adeilnorsssé',
#  'aadilnosssvé',
#  'aadeeilnrtvé',
#  'adeiiilmrsté',
#  'aadeimnqrtué',
#  'deiimnnorsté',
#  'adeeiimnrtté',
#  'adiimnnosssé',
#  'acdeimorrsté',
#  'adinnoosssté',
#  'adeeinnortté',
#  'aadinoprsssé',
#  'aadeeinprrté',
#  'adeinprsstté',
#  'adeiiprsstzé',
#  'cdeinoprrséé',
#  'adeimnoprssé',
#  'adehiirrstéé',
#  'adiinorssssé',
#  'adeeiinrrsté',
#  'adeeimnrssté',
#  'adeinorrstué',
#  'dinoorssstué',
#  'adeilnorstvé',
#  'ceeffinoorrs',
#  'abeeemmnrsst',
#  'aeeeiimnprrt',
#  'aeeeimprrsss',
#  'aeiimnnoopss',
#  'eeimnnoopssé',
#  'aeemnoprsstt',
#  'aeeimoprsstz',
#  'eeimnooprrst',
#  'aeeeimnprsst',
#  'aeiimnnoprss',
#  'aeeimnnprttu',
#  'aceeinnorsss',
#  'aceeinnorsst',
#  'aaceeinrrsst',
#  'cdeeiinnnors',
#  'aaceehnnssst',
#  'ceehinrrssué',
#  'eeefinnorrrs',
#  'aeefiinnortu',
#  'aaeeegginnrt',
#  'aegiilnorstu',
#  'egilnnoorstu',
#  'aeeggnnnrrtè',
#  'aeeegilnrtuu',
#  'aeiilnnossss',
#  'aeeeiilnnrst',
#  'eeeegimnnnst',
#  'aaceeinnrsss',
#  'aaceeiinnrrt',
#  'aeegiinrrsst',
#  'aeegiinrrstt',
#  'aeeginnrrstt',
#  'eeeginnrrstt',
#  'eeegiinrrstz',
#  'eeginnorrsst',
#  'aeinnoorsssu',
#  'aeeeinnorrtu',
#  'aaeeiillnntt',
#  'aaeeillnssst',
#  'aaeeiillnrst',
#  'aaeeiillnrtt',
#  'aeeeiillnrtz',
#  'aeeillnnorst',
#  'aeeillnnortt',
#  'aeeillnnrttè',
#  'aeiillnorttt',
#  'aeeillnorrtt',
#  'aaeeinnrrttî',
#  'aaceeeilnrrt',
#  'aeeeimnrrttt',
#  'aeeemnrrsttt',
#  'eeeimnnrsstt',
#  'aeeeinoprrst',
#  'aeeeinrrrstv',
#  'eeennorrrstv',
#  'aeiinorrrtuv',
#  'aeeiinnrrsté',
#  'eeinnnorrsté',
#  'aeeiinnoprss',
#  'aeinoorsssss',
#  'aeimnooqsstu',
#  'beinoorrsstu',
#  'acdeeeinrtxé',
#  'aeilnooprstx',
#  'aacefiinrsst',
#  'aefinorssstu',
#  'afiilnorssst',
#  'aeefiilnrrtt',
#  'aefiinnorsss',
#  'efiinorrsssu',
#  'aeefgilnorrs',
#  'aefilnorsssu',
#  'aeeefilnrrtu',
#  'aefilmorsstâ',
#  'aacfiinnorst',
#  'aaeefgimnrrt',
#  'adeefinnorrt',
#  'eefiinnoprrs',
#  'aceefinnorrt',
#  'acefiiilrsté',
#  'acefiiilrtté',
#  'ceefiiilrtzé',
#  'cefiilnorsté',
#  'aaeginnrsstt',
#  'aaegiinrsstz',
#  'aeegimnrsstâ',
#  'aeegiinnorst',
#  'aeefgilnnort',
#  'aegiinnorrst',
#  'aagilnrrstué',
#  'aefgiinorrtt',
#  'aeegiimnprrt',
#  'cehilorrttuu',
#  'aehiiloprsst',
#  'aaehiimnrstu',
#  'aeiilmmorsté',
#  'aeiiimmnrstu',
#  'eeiimnnpstté',
#  'aaciinnnostt',
#  'acdeeiiinnrs',
#  'efgiiilnnors',
#  'eiinnnoorsst',
#  'aceeiinprstt',
#  'ceeinnoprstt',
#  'aeinnorrsstu',
#  'aabeiilnrsst',
#  'aaceeiilnrrt',
#  'eeimnoprrstu',
#  'eeiinnnorstv',
#  'eeiinnnorttv',
#  'aeiilnsssttu',
#  'aegiinrssstu',
#  'aeiinnorssst',
#  'aeeinnrsstté',
#  'aeeinrssssté',
#  'aeeiinrrssté',
#  'aeiiinnorstv',
#  'eiinnnoorstv',
#  'aeiilnnorrst',
#  'aadiilnopsss',
#  'aadeeiilnprt',
#  'abeiilorrsté',
#  'aiiilmnossst',
#  'aeeiiilmnrtt',
#  'aegillrsstué',
#  'aaeeiillmnrt',
#  'aabeeimnrrrt',
#  'aaiimnnorsss',
#  'aaeeiimnnrrt',
#  'aaeeilmmnrtt',
#  'aaeeimnqrrtu',
#  'aeilmnorrstè',
#  'aeimnnorsttu',
#  'aeeimnnnorst',
#  'aeeeimnrrstu',
#  'aiimnnossstu',
#  'aeeiimnnrttu',
#  'aaeiiillmrrt',
#  'aeeimnnorrtt',
#  'aaeiilmnorst',
#  'cehmnnnoorsâ',
#  'aaciimnnosté',
#  'eiimnoprrssé',
#  'aaeiillmrsté',
#  'aeiillnnorss',
#  'aaeilnnrsttu',
#  'aaeilmnrsstu',
#  'aefiinnosstt',
#  'aefiiinosstz',
#  'efiiinnoorst',
#  'einorrrsssuu',
#  'aeffinoqstuu',
#  'aeffoqssssuu',
#  'aeffioqrssuu',
#  'aeffioqrstuu',
#  'eeffioqrsuuz',
#  'effnooqrssuu',
#  'effnooqrstuu',
#  'effnoqrstuuè',
#  'eiimnooprsst',
#  'adeiinorsstu',
#  'aeillnossttu',
#  'aeiillosstuz',
#  'eiillnoorstu',
#  'aaeilnossstv',
#  'aefiiinnoprs',
#  'aaeillopprst',
#  'aaaeiiprrsst',
#  'aaeinoprrsst',
#  'aaceeillprrs',
#  'aaeenprsssst',
#  'aaeeiprssssz',
#  'aeeinoprrsss',
#  'aaeeilmnprst',
#  'aaeeilmnprtt',
#  'aaaeegprssst',
#  'aeinoprssstu',
#  'aeeinnoprstt',
#  'aceeiinnprst',
#  'aaiilloprttu',
#  'aeiilnprrtuu',
#  'aeilnprrstuu',
#  'eeilnprrtuuz',
#  'aeeiinnnoprs',
#  'aeeiinprsstt',
#  'aeilnnoprssé',
#  'aeilnnoprsté',
#  'aceeprrsstué',
#  'aeeeilnpprtu',
#  'aeghooprrtuv',
#  'aeeilnprrttâ',
#  'aiinnoopssst',
#  'aeeiinnoprtt',
#  'aeilnopprstu',
#  'aeeinoprsstu',
#  'aaeilnnprsst',
#  'aeeinprrssst',
#  'aeeeinprrsst',
#  'aeeimnoprttt',
#  'aceiinoprrsé',
#  'deinnoprssté',
#  'aeeinprrssté',
#  'aeeinprrstté',
#  'eeeinprrstzé',
#  'eennoprrssté',
#  'abeeiilnprtu',
#  'aabinorssttu',
#  'aaeeiillnrrt',
#  'aaeiinnorrst',
#  'aeinnnoorrst',
#  'aaeinoprssst',
#  'aeiinoprssst',
#  'aaeeillpprrs',
#  'aaeillpprrsé',
#  'aacfiiinortt',
#  'aaiilnorssté',
#  'aaeinrsssstt',
#  'aeiinorrssst',
#  'aaenoprrrstt',
#  'aaaeiillrrtv',
#  'aaiillnorstv',
#  'bceehnoorrtu',
#  'ceeinorrsttu',
#  'ceeinorrrstu',
#  'deeeinnrsstv',
#  'deeeiinrssvz',
#  'aeegginnorrs',
#  'aaegiinrrsss',
#  'aaegiinrrsst',
#  'aaeginnrrsst',
#  'aeeginnrrsst',
#  'aeegiinrrssz',
#  'aeginnorrsss',
#  'aeeglnrsstué',
#  'abeemorrrssu',
#  'aeeimnoprrtt',
#  'aeeiiprrsssz',
#  'eeiinoprrrss',
#  'aeeiinrrssst',
#  'aaeeirrssttu',
#  'aeenorrssstu',
#  'aaeeinrrsttu',
#  'aaeeillrssst',
#  'aeeiinrssstt',
#  'aceehinorttu',
#  'aeeinnorrttu',
#  'acehinnorrst',
#  'aeeimnrrssst',
#  'aaaeillrrstv',
#  'aaeeillrrtvz',
#  'aeeeimnprrtt',
#  'einoorrssstu',
#  'aeeinorrttuv',
#  'aaeiilorrssv',
#  'aaeiilorrstv',
#  'aeeiilorrsvz',
#  'aeilnoorrssv',
#  'efiiiinorsvv',
#  'aeillnorsstu',
#  'eegimnrssstu',
#  'acfinoorrtté',
#  'aefmnorrssté',
#  'aacefirrrsté',
#  'aeegiimnrrté',
#  'aeeglmnnrtté',
#  'adeinrssttéé',
#  'aacefiiinrst',
#  'aacefiirssss',
#  'aacefiiirrss',
#  'aacefiiirrst',
#  'aceefiiirrsz',
#  'acefiinorrss',
#  'acefiinorrst',
#  'acefiinrrstè',
#  'aeeegimnrsst',
#  'aeinorsssttu',
#  'aaeiinnorstt',
#  'abdinnoorssu',
#  'einoopprsssu',
#  'aeeinrsstuzé',
#  'acilnorsssué',
#  'aaeiillrssst',
#  'aaeiilorsttt',
#  'aaeiinrrsstt',
#  'aaeimnrrsttu',
#  'aenoprrsstté',
#  'aeiiinnorssv',
#  'ceiilrsttuuv',
#  'acehiilrsuvé',
#  'aaceeilnrtté',
#  'aiinopsssssé',
#  'aiilnoosssté',
#  'aeeiilnortté',
#  'aaabeinrttt',
#  'aabeiilnort',
#  'aabdennosst',
#  'abeinrssttu',
#  'abeiirsstuz',
#  'abeginorrsé',
#  'aabeeinnstt',
#  'abeennorsst',
#  'aabbeiorrst',
#  'abbenoorrst',
#  'aabinorrstt',
#  'aaccdeeinrt',
#  'aaacceilmrt',
#  'accdenoorrs',
#  'aaccenosstt',
#  'accinoorrsu',
#  'aacceillntu',
#  'accdeinorsé',
#  'aaacehinrrt',
#  'aceinoqrrsu',
#  'aaceiinnort',
#  'accenoprtuu',
#  'accenprtuuu',
#  'adeiimnrsté',
#  'aadeimrrstu',
#  'adeiimnorrs',
#  'aadeimnosst',
#  'acdinoosssu',
#  'aadeeinrsst',
#  'adeenorrsst',
#  'aabdeinorst',
#  'aabdeorssss',
#  'aabdeiorrss',
#  'aabdeiorrst',
#  'abdeeiorrsz',
#  'abdenoorrss',
#  'abdenoorrst',
#  'abdenorrstè',
#  'adeeinnsstv',
#  'aaaeffirsss',
#  'aaeeffimnrt',
#  'aaeffinorrt',
#  'aaeeffirssz',
#  'aaeffiimrrs',
#  'aaeffiimrrt',
#  'aeeffiimrrz',
#  'aeffimnorrs',
#  'aeffimnorrt',
#  'aeffiilnors',
#  'aaeffiilsss',
#  'aaeffiiilrs',
#  'aeffilnorsu',
#  'aaffiilloru',
#  'aaeffilnort',
#  'aaeffilorrs',
#  'aeeffilorrz',
#  'aceeginnors',
#  'aaeginossss',
#  'aaegiinorss',
#  'acegilrrtuu',
#  'aaginorsssé',
#  'aaeeginrrté',
#  'aaegimnrsté',
#  'aeegmnnrtté',
#  'aabeeilmmnt',
#  'aaaeiimnrst',
#  'aagilnnortu',
#  'aaegilnsssu',
#  'aaeilmnorrs',
#  'aacillnoost',
#  'aaeelnrsstt',
#  'aaeeilrsstz',
#  'aeeilnorrst',
#  'aeghilmorst',
#  'aeegilnnrsé',
#  'aeegilmnnst',
#  'aaeeiilmnrt',
#  'aaeeilmnrst',
#  'aeeeilmnrtz',
#  'aaiilnnosté',
#  'aaiillnosss',
#  'aaeeiillnrt',
#  'aaegillnors',
#  'aaegillnort',
#  'aegllnnoors',
#  'aegillnorsé',
#  'aeilnorrsté',
#  'aaeimnorsss',
#  'aabimnorsss',
#  'aabeeimnrrt',
#  'aeiimnorrrs',
#  'aaeimnrrsst',
#  'aeeimnrrsst',
#  'adeiimnorss',
#  'aeimnorsstt',
#  'aaeegmmnnté',
#  'aaceiimnrsé',
#  'aaceelnrsst',
#  'aaceeiillnr',
#  'aacinnorsss',
#  'aaceeinnrrt',
#  'aeegimnoprs',
#  'aaeginorsss',
#  'aeeginorssz',
#  'aaiimnnosss',
#  'aaeeiimnnrt',
#  'aaceinnnors',
#  'aaceinnnort',
#  'aceeinnnorz',
#  'acennnnoors',
#  'acennnnoort',
#  'acennnnortè',
#  'aaceinnortt',
#  'aabcehimnrt',
#  'aaeiinqrstu',
#  'aeiillnortu',
#  'aaceiilnost',
#  'aeiimnsstté',
#  'aeeinrrstué',
#  'aiinorrttéé',
#  'aaaiilnpsst',
#  'aailnnopsss',
#  'aeinooprsst',
#  'aaeeillpprr',
#  'aaeeillpprs',
#  'aaaeinpprst',
#  'aaaeinpprtt',
#  'aaaennpprtt',
#  'aaeeinpprtz',
#  'aaenoppssst',
#  'aaeinopprtt',
#  'aaeeinnpprt',
#  'aaabeinrsst',
#  'aabeiirrrst',
#  'aacehiinrtv',
#  'aacehirsssv',
#  'aacehiirrsv',
#  'aacehiirrtv',
#  'aceehiirrvz',
#  'acehinorrsv',
#  'acehinorrtv',
#  'acehinrrtvè',
#  'aaeeginnrtt',
#  'aaceiorrstt',
#  'aaeeinprrst',
#  'aaeeinprrtt',
#  'aaeeinqrrtu',
#  'aaeinnorrss',
#  'aaceiilrrtu',
#  'aeeimnrsttt',
#  'aeeinnrssté',
#  'aacdeennsst',
#  'aaiinoprsst',
#  'aaeiillrssz',
#  'aaiinnorsss',
#  'aaeiinssssz',
#  ...]

# %%
# list of anagram sets, sorted by signature length
[anagrams_by_sig[sig] for sig in sorted(anagrams_by_sig.keys(), key=len, reverse=True)]
# Out:
# [{'hiérarchies aspiré', 'hiérarchise aspiré'},
#  {'manutentionnaires', 'manutentionnerais'},
#  {'commissionnaires', 'commissionnerais'},
#  {'débrouillassions', 'débroussaillions'},
#  {'haussions aspiré', 'huassions aspiré'},
#  {'henniront aspiré', 'honnirent aspiré'},
#  {'impressionnerais', 'permissionnaires'},
#  {'manutentionnaire', 'manutentionnerai'},
#  {'révolutionnaires', 'révolutionnerais'},
#  {'soumissionnaires', 'soumissionnerais'},
#  {'commissionnaire', 'commissionnerai'},
#  {'constitueraient', 'reconstituaient'},
#  {'contingenterais', 'contresignaient'},
#  {'débrouillassent', 'débroussaillent'},
#  {'débrouillassiez', 'débroussailliez'},
#  {'démissionnaires', 'démissionnerais'},
#  {'empoisonnements', 'empoissonnement'},
#  {'haussent aspiré', 'huassent aspiré'},
#  {'haussiez aspiré', 'huassiez aspiré'},
#  {'impressionnerai', 'permissionnaire'},
#  {'nationaliserait', 'rationalisaient'},
#  {'peinturluraient', 'turlupineraient'},
#  {'préconiseraient', 'réceptionnaires'},
#  {'reconstruisisse', 'ressusciterions'},
#  {'retravaillaient', 'travailleraient'},
#  {'révolutionnaire', 'révolutionnerai'},
#  {'soumissionnaire', 'soumissionnerai'},
#  {'acclimaterions', 'calomniatrices'},
#  {'agenouillerait', 'gouailleraient'},
#  {'amollissements', 'sommeillassent'},
#  {'bougonneraient', 'bourgeonnaient'},
#  {'boutonneraient', 'reboutonnaient'},
#  {'cautionnerions', 'contusionnerai'},
#  {'centralisation', 'intercalations'},
#  {'certifiassions', 'rectifiassions'},
#  {'certifieraient', 'rectifieraient'},
#  {'commanderaient', 'recommandaient'},
#  {'commanditaires', 'commanditerais'},
#  {'commerceraient', 'recommencerait'},
#  {'conservassions', 'conversassions'},
#  {'conserveraient', 'converseraient'},
#  {'constituerions', 'reconstituions'},
#  {'contiendraient', 'endoctrinaient'},
#  {'contrediraient', 'endoctrinerait'},
#  {'courtiseraient', 'reconstituerai'},
#  {'desserrassions', 'redressassions'},
#  {'desserreraient', 'redresseraient'},
#  {'dessertiraient', 'disserteraient'},
#  {'desserviraient', 'reverdissaient'},
#  {'disciplinaires', 'disciplinerais'},
#  {'débrouillasses', 'débroussailles'},
#  {'déconcertaient', 'déconnecterait'},
#  {'démissionnaire', 'démissionnerai'},
#  {'empoisonnasses', 'empoissonnasse'},
#  {'empoisonnerais', 'empoissonnerai'},
#  {'emprisonnerais', 'impressionnera'},
#  {'enregistraient', 'restreignaient'},
#  {'entaillassions', 'tenaillassions'},
#  {'entailleraient', 'tenailleraient'},
#  {'entortillerait', 'tortilleraient'},
#  {'entreprissions', 'pressentirions'},
#  {'entretaillerai', 'retailleraient'},
#  {'fonctionnaires', 'fonctionnerais'},
#  {'fractionnaires', 'fractionnerais'},
#  {'féliciteraient', 'électrifiaient'},
#  {'harengs aspiré', 'hargnes aspiré'},
#  {'hausses aspiré', 'huasses aspiré'},
#  {'hersais aspiré', 'hissera aspiré'},
#  {'heurtai aspiré', 'huerait aspiré'},
#  {'interrogatives', 'tergiversation'},
#  {'offusquassions', 'suffoquassions'},
#  {'offusqueraient', 'suffoqueraient'},
#  {'parlementaires', 'parlementerais'},
#  {'particularisée', 'récapitulerais'},
#  {'patrouillerait', 'tripatouillera'},
#  {'peinturlurions', 'turlupinerions'},
#  {'personnalisait', 'plaisanterions'},
#  {'plébiscitaires', 'plébisciterais'},
#  {'présenteraient', 'représentaient'},
#  {'pétitionnaires', 'pétitionnerais'},
#  {'questionnaires', 'questionnerais'},
#  {'quincailleries', 'quincaillieres'},
#  {'ravitaillerons', 'retravaillions', 'travaillerions'},
#  {'redécourvirons', 'redécourvrions'},
#  {'regarnissaient', 'rengraissaient'},
#  {'revalorisaient', 'valoriseraient'},
#  {'réglementaires', 'réglementerais'},
#  {'sacrifiassions', 'scarifiassions'},
#  {'sacrificateurs', 'scarificateurs'},
#  {'sacrifieraient', 'scarifieraient'},
#  {'subordonnerais', 'surabonderions'},
#  {'tambourinaires', 'tambourinerais'},
#  {'abasourdirent', 'surabonderait'},
#  {'actionnerions', 'renonciations'},
#  {'adsorbassions', 'sabordassions'},
#  {'adsorberaient', 'saborderaient'},
#  {'affermiraient', 'affirmeraient'},
#  {'affouillirons', 'farfouillions'},
#  {'allongeraient', 'rallongeaient'},
#  {'annonceraient', 'canonneraient'},
#  {'apparentaient', 'appartenaient'},
#  {'archivassions', 'chavirassions'},
#  {'archiveraient', 'chavireraient'},
#  {'argentassions', 'organisassent'},
#  {'argumentaires', 'argumenterais'},
#  {'assigneraient', 'engraissaient'},
#  {'astreignaient', 'transigeaient'},
#  {'atmosphérique', 'métaphoriques'},
#  {'bougonnerions', 'bourgeonnions'},
#  {'bourdonnasses', 'subordonnasse'},
#  {'bourdonnerais', 'subordonnerai'},
#  {'boutonnerions', 'reboutonnions'},
#  {'brocanterions', 'carboniseront'},
#  {'bénéficiaires', 'bénéficierais'},
#  {'cachetterions', 'technocraties'},
#  {'canonisassent', 'sanctionnasse'},
#  {'carrelassions', 'sacraliserons'},
#  {'cartonneriers', 'rencontrerais'},
#  {'cautionnerons', 'contusionnera'},
#  {'cautionneront', 'contournaient'},
#  {'centralisasse', 'intercalasses'},
#  {'centraliserai', 'intercalaires', 'intercalerais'},
#  {'certifiassent', 'rectifiassent'},
#  {'certifiassiez', 'rectifiassiez'},
#  {'certifierions', 'rectifierions'},
#  {'chambreraient', 'embrancherait'},
#  {'chausseraient', 'enchausserait', 'rechaussaient'},
#  {'chercheraient', 'recherchaient'},
#  {'combinassions', 'incombassions'},
#  {'combineraient', 'incomberaient'},
#  {'commanderions', 'recommandions'},
#  {'commanditaire', 'commanditerai'},
#  {'commencerions', 'recommencions'},
#  {'comparaissons', 'comparassions'},
#  {'compensatoire', 'composeraient'},
#  {'concertations', 'contacterions'},
#  {'concéderaient', 'déconnecterai'},
#  {'conseillerait', 'oscilleraient'},
#  {'conservassent', 'conversassent'},
#  {'conservassiez', 'conversassiez'},
#  {'conservateurs', 'recouvrassent'},
#  {'conservations', 'conversations'},
#  {'conserverions', 'converserions', 'reconversions'},
#  {'consternerais', 'encastrerions'},
#  {'consternerait', 'entrecroisant'},
#  {'constituerais', 'reconstituais'},
#  {'constituerait', 'reconstituait'},
#  {'constitueriez', 'reconstituiez'},
#  {'constituerons', 'reconstituons'},
#  {'contenterions', 'sectionneront'},
#  {'continuations', 'contusionnait'},
#  {'contraignisse', 'contresignais'},
#  {'contrariasses', 'tracasserions'},
#  {'convertisseur', 'recouvrissent'},
#  {'croupissantes', 'percutassions'},
#  {'croustillerai', 'sourcillerait'},
#  {'créditeraient', 'intercéderait'},
#  {'culminassions', 'masculinisons'},
#  {'demanderaient', 'redemandaient'},
#  {'desserrassent', 'redressassent'},
#  {'desserrassiez', 'redressassiez'},
#  {'desserrerions', 'redresserions'},
#  {'dessertirions', 'disserterions'},
#  {'dessertissant', 'dissertassent'},
#  {'desservirions', 'reverdissions'},
#  {'différancient', 'différenciant'},
#  {'disciplinaire', 'disciplinerai'},
#  {'dissiperaient', 'stipendierais'},
#  {'dissémination', 'démissionnait'},
#  {'documentaires', 'documenterais'},
#  {'domiciliaires', 'domicilierais'},
#  {'débrouillasse', 'débroussaille'},
#  {'décentrerions', 'intercéderons'},
#  {'déclouassions', 'découlassions'},
#  {'décloueraient', 'découleraient'},
#  {'décoiffassent', 'désaffections'},
#  {'décroisassent', 'décroissantes'},
#  {'défonceraient', 'féconderaient'},
#  {'dégarnissions', 'dénigrassions'},
#  {'déguerpirions', 'périgourdines'},
#  {'démentiraient', 'déterminaient'},
#  {'démocratisera', 'désamorcerait'},
#  {'départissions', 'trépidassions'},
#  {'désorientasse', 'désosseraient'},
#  {'empoisonneras', 'empoissonnera'},
#  {'emportassions', 'rempotassions'},
#  {'emporteraient', 'rempoteraient'},
#  {'enchérisseurs', 'surenchérisse'},
#  {'endormiraient', 'ordinairement'},
#  {'enfourcherait', 'fourcheraient'},
#  {'engorgeraient', 'rengorgeaient'},
#  {'engraisserait', 'graisseraient'},
#  {'enregistrions', 'restreignions'},
#  {'entaillassent', 'tenaillassent'},
#  {'entaillassiez', 'tenaillassiez'},
#  {'entaillerions', 'tenaillerions'},
#  {'entortillasse', 'satelliseront'},
#  {'entrecouperai', 'recouperaient'},
#  {'entreprendrai', 'reprendraient'},
#  {'entreprissent', 'pressentirent'},
#  {'entreprissiez', 'pressentiriez'},
#  {'entretiendrai', 'retiendraient'},
#  {'falsification', 'officialisant'},
#  {'fermentations', 'manifesteront'},
#  {'fonctionnaire', 'fonctionnerai'},
#  {'fractionnaire', 'fractionnerai'},
#  {'fraternisions', 'frissonnerait'},
#  {'frictionnasse', 'sanctifierons'},
#  {'féliciterions', 'électrifiions'},
#  {'garantissions', 'granitassions', 'gratinassions'},
#  {'graniteraient', 'gratineraient'},
#  {'hantât aspiré', 'hâtant aspiré'},
#  {'hareng aspiré', 'hargne aspiré'},
#  {'hausse aspiré', 'huasse aspiré'},
#  {'immortalisées', 'mémorialistes'},
#  {'importunasses', 'permutassions'},
#  {'incrusterions', 'insurrections'},
#  {'inquiéterions', 'réquisitionne'},
#  {'instaurerions', 'nourrissaient'},
#  {'instrumentale', 'suralimentent'},
#  {'interpolerons', 'poltronneries'},
#  {'interposaient', 'patienterions'},
#  {'interposerait', 'riposteraient'},
#  {'intervenaient', 'inventeraient'},
#  {'intitulerions', 'inutiliseront'},
#  {'intéressantes', 'éternisassent'},
#  {'intéresserait', 'résisteraient'},
#  {'inventassions', 'visionnassent'},
#  {'magnétiserons', 'morigénassent'},
#  {'martelassions', 'moralisassent'},
#  {'mentionnerait', 'mitonneraient'},
#  {'notifiassions', 'tonifiassions'},
#  {'notifieraient', 'tonifieraient'},
#  {'offusquassent', 'suffoquassent'},
#  {'offusquassiez', 'suffoquassiez'},
#  {'offusquerions', 'suffoquerions'},
#  {'ornementerait', 'remonteraient'},
#  {'ostréiculteur', 'ostréiculture'},
#  {'outillassions', 'touillassions'},
#  {'outilleraient', 'touilleraient'},
#  {'paressassions', 'repassassions'},
#  {'paresseraient', 'repasseraient'},
#  {'parlementaire', 'parlementerai'},
#  {'peinturlurais', 'turlupinerais'},
#  {'peinturlurait', 'turlupinerait'},
#  {'peinturluriez', 'turlupineriez'},
#  {'peinturlurons', 'turlupinerons'},
#  {'pensionnaires', 'pensionnerais'},
#  {'photograveurs', 'photogravures'},
#  {'piétineraient', 'pénitentiaire'},
#  {'plébiscitaire', 'plébisciterai'},
#  {'prédestinerai', 'présideraient'},
#  {'préexisteront', 'prétexterions'},
#  {'présenterions', 'représentions'},
#  {'pétitionnaire', 'pétitionnerai'},
#  {'questionnaire', 'questionnerai'},
#  {'quincaillerie', 'quincailliere'},
#  {'rapetissaient', 'repaissaientt', 'tapisseraient'},
#  {'rassortissent', 'ressortissant'},
#  {'ratifications', 'tarifications'},
#  {'rattraperions', 'transporterai'},
#  {'ravitailleras', 'retravaillais', 'travaillerais'},
#  {'ravitaillerez', 'retravailliez', 'travailleriez'},
#  {'reconnaissant', 'sanctionneras'},
#  {'redevinssions', 'revendissions'},
#  {'redécourviras', 'redécourvrais'},
#  {'redécourvirez', 'redécourvriez'},
#  {'regagneraient', 'rengageraient'},
#  {'regarnissions', 'rengraissions'},
#  {'reprisassions', 'respirassions'},
#  {'repriseraient', 'respireraient'},
#  {'ressaisissent', 'ressentissais'},
#  {'retranchaient', 'trancheraient'},
#  {'retravaillait', 'travaillerait'},
#  {'retravaillons', 'travaillerons'},
#  {'retroussaient', 'trousseraient'},
#  {'revalorisions', 'valoriserions'},
#  {'revivifiaient', 'vivifieraient'},
#  {'réglementaire', 'réglementerai'},
#  {'sacrifiassent', 'scarifiassent'},
#  {'sacrifiassiez', 'scarifiassiez'},
#  {'sacrificateur', 'scarificateur'},
#  {'sacrifierions', 'scarifierions'},
#  {'stationnaires', 'stationnerais'},
#  {'subordonneras', 'surabonderons'},
#  {'superposaient', 'supposeraient'},
#  {'tambourinaire', 'tambourinerai'},
#  {'abrutissions', 'bruitassions'},
#  {'abstiendrons', 'rebondissant'},
#  {'accentuerais', 'accuseraient'},
#  {'accointeront', 'concertation'},
#  {'accorderions', 'concorderais'},
#  {'accostassent', 'contactasses'},
#  {'acquerraient', 'craqueraient'},
#  {'actionnaires', 'actionnerais', 'canoniserait'},
#  {'actionnerait', 'incantatoire'},
#  {'actionnerons', 'canoniseront'},
#  {'acuponcteurs', 'acuponctures'},
#  {'acupuncteurs', 'acupunctures'},
#  {'adsorbassent', 'sabordassent'},
#  {'adsorbassiez', 'sabordassiez'},
#  {'adsorberions', 'saborderions'},
#  {'affaisserons', 'effarassions'},
#  {'affermirions', 'affirmerions'},
#  {'affermissant', 'affirmassent'},
#  {'affleuraient', 'afflueraient'},
#  {'affouilliras', 'farfouillais'},
#  {'affouillirez', 'farfouilliez'},
#  {'affriolerons', 'raffolerions'},
#  {'agenceraient', 'encageraient'},
#  {'agenouillait', 'gouaillaient'},
#  {'agrandissent', 'grandissante'},
#  {'agrémentasse', 'émargeassent'},
#  {'agrémenterai', 'émargeraient'},
#  {'aiguilleront', 'grouillaient', 'guillotinera'},
#  {'aimanterions', 'romanisaient'},
#  {'alertassions', 'relatassions'},
#  {'alerteraient', 'relateraient'},
#  {'alimentaires', 'alimenterais'},
#  {'alimenterons', 'lamenterions'},
#  {'amendassions', 'amidonnasses'},
#  {'amerriraient', 'arrimeraient'},
#  {'ameublissons', 'meublassions'},
#  {'amnistierons', 'terminaisons'},
#  {'américanises', 'mécaniserais'},
#  {'ancillairees', 'canailleries'},
#  {'angoisserons', 'rongeassions'},
#  {'annoncerions', 'canonnerions'},
#  {'anticiperons', 'conspiraient'},
#  {'antériorités', 'réitérations'},
#  {'anéantissent', 'instantanées'},
#  {'apparentions', 'appartenions'},
#  {'appariassent', 'appesantiras'},
#  {'archivassent', 'chavirassent'},
#  {'archivassiez', 'chavirassiez'},
#  {'archiverions', 'chavirerions'},
#  {'argumentaire', 'argumenterai'},
#  {'arrondissent', 'astreindrons'},
#  {'articulaires', 'articulerais'},
#  {'aseptiserons', 'interposasse'},
#  {'assaillirent', 'installerais'},
#  {'assaillirons', 'raillassions', 'ralliassions'},
#  {'assainissons', 'assassinions'},
#  {'assignerions', 'engraissions'},
#  {'assimilaient', 'italianismes'},
#  {'assiégerions', 'érigeassions'},
#  {'assoupissons', 'poussassions'},
#  {'astreindrais', 'irradiassent'},
#  {'astreindrait', 'attendrirais'},
#  {'astreindront', 'attendrirons'},
#  {'atterrissait', 'attristerais'},
#  {'attirassions', 'traitassions'},
#  {'attireraient', 'traiteraient'},
#  {'attraperions', 'parasiteront'},
#  {'aurifiassent', 'surfaisaient'},
#  {'autoriserait', 'autoritaires'},
#  {'aventurerait', 'vautreraient'},
#  {'avertissions', 'rivetassions'},
#  {'bachoterions', 'cohabiterons'},
#  {'banaliserons', 'blasonnerais', 'raisonnables'},
#  {'banaliseront', 'blasonnerait', 'laborantines'},
#  {'betteraviers', 'brevetterais'},
#  {'boucheraient', 'rebouchaient'},
#  {'bougonnerais', 'bourgeonnais'},
#  {'bougonnerait', 'bourgeonnait'},
#  {'bougonneriez', 'bourgeonniez'},
#  {'bougonnerons', 'bourgeonnons'},
#  {'bourdonneras', 'subordonnera'},
#  {'boutonnerais', 'reboutonnais'},
#  {'boutonnerait', 'reboutonnait'},
#  {'boutonneriez', 'reboutonniez'},
#  {'boutonnerons', 'reboutonnons'},
#  {'brancherions', 'charbonniers'},
#  {'broutassions', 'obturassions', 'raboutissons'},
#  {'brouteraient', 'obtureraient'},
#  {'burineraient', 'interurbaine'},
#  {'bâilleraient', 'entrebâillai'},
#  {'bénéficiaire', 'bénéficierai'},
#  {'cachetterons', 'technocrates'},
#  {'calquassions', 'claquassions'},
#  {'calqueraient', 'claqueraient', 'craquelaient'},
#  {'canaliserons', 'claironnasse'},
#  {'cantonnerais', 'sanctionnera'},
#  {'cantonnerait', 'cartonnaient'},
#  {'capturerions', 'conspirateur'},
#  {'caressassent', 'encastrasses'},
#  {'carrelassiez', 'sacraliserez'},
#  {'carrossaient', 'contrariasse'},
#  {'cartonnerier', 'rencontrerai'},
#  {'cartonneries', 'consternerai', 'encarterions'},
#  {'casernements', 'encrassement'},
#  {'castreraient', 'encastrerait'},
#  {'cataloguions', 'coagulations'},
#  {'cautionnions', 'contusionnai'},
#  {'centralisera', 'intercaleras', 'sarcleraient'},
#  {'cercleraient', 'encerclerait'},
#  {'certifiaient', 'rectifiaient'},
#  {'certifiasses', 'rectifiasses'},
#  {'certifierais', 'rectifierais'},
#  {'certifierait', 'rectifierait'},
#  {'certifieriez', 'rectifieriez'},
#  {'certifierons', 'rectifierons'},
#  {'certifieront', 'rectifieront'},
#  {'certifièrent', 'rectifièrent'},
#  {'chanteraient', 'enchanterait'},
#  {'chaperonnais', 'panacherions'},
#  {'charmassions', 'marchassions'},
#  {'charmeraient', 'marcheraient'},
#  {'chausserions', 'rechaussions'},
#  {'chercherions', 'recherchions'},
#  {'choqueraient', 'entrechoquai'},
#  {'christianise', 'enrichissait'},
#  {'chérissaient', 'enchérissait'},
#  {'cinglassions', 'clignassions'},
#  {'cingleraient', 'cligneraient'},
#  {'circonvenais', 'vaccinerions'},
#  {'clarifiasses', 'classifieras'},
#  {'classeraient', 'intercalasse', 'reclassaient'},
#  {'cochonneries', 'encocherions'},
#  {'coifferaient', 'recoiffaient'},
#  {'coloniserons', 'consolerions'},
#  {'combinassent', 'incombassent'},
#  {'combinassiez', 'incombassiez'},
#  {'combinerions', 'incomberions'},
#  {'commanderais', 'recommandais'},
#  {'commanderait', 'commanditera', 'recommandait'},
#  {'commanderiez', 'recommandiez'},
#  {'commanderons', 'recommandons'},
#  {'commanditons', 'incommodants'},
#  {'commenceriez', 'recommenciez'},
#  {'commentaires', 'commenterais'},
#  {'commerçaient', 'recommençait'},
#  {'commotionnas', 'consommation'},
#  {'comparaissez', 'comparassiez'},
#  {'compatissons', 'comptassions'},
#  {'compilateurs', 'compulserait'},
#  {'comprimeront', 'compromirent'},
#  {'concentrerai', 'concernerait'},
#  {'concertaient', 'connecterait'},
#  {'conduisirent', 'discontinuer'},
#  {'confirmerait', 'informatrice'},
#  {'congratulées', 'congélateurs'},
#  {'conjecturons', 'conjonctures'},
#  {'consentirait', 'interactions'},
#  {'consentirons', 'consternions'},
#  {'conservaient', 'contrevenais', 'conversaient'},
#  {'conservasses', 'conversasses'},
#  {'conservation', 'conversation'},
#  {'conserverais', 'converserais'},
#  {'conserverait', 'converserait'},
#  {'conserveriez', 'converseriez'},
#  {'conserverons', 'converserons'},
#  {'conserveront', 'converseront'},
#  {'conservèrent', 'conversèrent'},
#  {'consignerait', 'contresignai'},
#  {'constelleras', 'recollassent'},
#  {'consterneras', 'encastrerons', 'encrasseront', 'rencontrasse'},
#  {'constiperais', 'pactiserions'},
#  {'constituerai', 'courtisaient', 'reconstituai'},
#  {'constitueras', 'reconstituas'},
#  {'constituerez', 'reconstituez'},
#  {'construisses', 'ressuscitons', 'souscrissent'},
#  {'contendrions', 'endoctrinons'},
#  {'contiendrais', 'endoctrinais'},
#  {'contiendrait', 'endoctrinait'},
#  {'continuerons', 'contusionner'},
#  {'contournerai', 'couronnerait'},
#  {'contrasteras', 'tracasseront'},
#  {'contredisant', 'distanceront'},
#  {'cordonneries', 'encorderions'},
#  {'courberaient', 'recourbaient'},
#  {'couvrissions', 'souscrivions'},
#  {'cracheraient', 'recrachaient'},
#  {'cristallines', 'scintilleras'},
#  {'crochetaient', 'technocratie'},
#  {'croiseraient', 'entrecroisai'},
#  {'culminassiez', 'masculinisez'},
#  {'desserraient', 'dresseraient', 'redressaient'},
#  {'desserrasses', 'redressasses'},
#  {'desserrerais', 'redresserais'},
#  {'desserrerait', 'redresserait'},
#  {'desserreriez', 'redresseriez'},
#  {'desserrerons', 'redresserons'},
#  {'desserreront', 'redresseront'},
#  {'desserrèrent', 'redressèrent'},
#  {'dessertirais', 'disserterais'},
#  {'dessertirait', 'disserterait'},
#  {'dessertiriez', 'disserteriez'},
#  {'dessertirons', 'disserterons'},
#  {'dessertiront', 'disserteront', 'retordissent'},
#  {'desservirais', 'reverdissais'},
#  {'desservirait', 'reverdissait'},
#  {'desservirent', 'reverdissent'},
#  {'desserviriez', 'reverdissiez'},
#  {'desservirons', 'reverdissons'},
#  {'différancies', 'différencias'},
#  {'digérassions', 'dégraissions'},
#  {'digéreraient', 'rédigeraient'},
#  {'discernaient', 'scinderaient'},
#  {'discouraient', 'reconduisait'},
#  {'disculpation', 'duplications'},
#  {'dispensaires', 'dispenserais'},
#  {'dispenserait', 'dispersaient', 'stipendieras'},
#  {'documentaire', 'documenterai'},
#  {'domiciliaire', 'domicilierai'},
#  {'doubleraient', 'redoublaient'},
#  {'draguassions', 'graduassions'},
#  {'dragueraient', 'gradueraient'},
#  {'durcissaient', 'endurcissait'},
#  {'décaisseront', 'décroissante'},
#  {'décaleraient', 'délaceraient'},
#  {'décatissions', 'édictassions'},
#  {'décentrerais', 'intercéderas'},
#  {'décentreriez', 'intercéderez'},
#  {'décernassent', 'transcendées'},
#  {'déclouassent', 'découlassent'},
#  {'déclouassiez', 'découlassiez'},
#  {'déclouerions', 'découlerions'},
#  {'décrieraient', 'intercéderai'},
#  {'défoncerions', 'féconderions'},
#  {'déférassions', 'fédérassions'},
#  {'déféreraient', 'fédéreraient'},
#  {'dégarnissiez', 'dénigrassiez'},
#  {'déifiassions', 'édifiassions'},
#  {'déifications', 'édifications'},
#  {'déifieraient', 'édifieraient'},
#  {'délaisserons', 'délasserions'},
#  {'délavassions', 'dévalassions'},
#  {'délaveraient', 'dévaleraient'},
#  {'délimiterais', 'démilitarise'},
#  {'démarquaient', 'quémanderait'},
#  {'démentirions', 'déterminions'},
#  {'démeritaient', 'méditeraient'},
#  {'déminassions', 'démissionnas'},
#  {'démocratiser', 'modératrices'},
#  {'dénotassions', 'détonassions'},
#  {'dénoteraient', 'détoneraient'},
#  {'déparassions', 'dérapassions'},
#  {'dépareraient', 'déraperaient'},
#  {'départissent', 'trépidassent'},
#  {'départissiez', 'trépidassiez'},
#  {'déprécierons', 'précéderions'},
#  {'désemparions', 'prédominasse'},
#  {'déshériterai', 'héréditaires'},
#  {'désirassions', 'résidassions', 'sidérassions'},
#  {'désireraient', 'résideraient', 'sidéreraient'},
#  {'déterminasse', 'remédiassent'},
#  {'détournerais', 'résoudraient'},
#  {'détroussions', 'étourdissons'},
#  {'dévaliseront', 'dévalorisent'},
#  {'efforcerions', 'recoifferons'},
#  {'embrasements', 'embrassement'},
#  {'empierraient', 'empireraient'},
#  {'empierrasses', 'empresserais'},
#  {'empoisonnais', 'empoissonnai'},
#  {'empoisonnées', 'empoissonnée'},
#  {'emportassent', 'rempotassent'},
#  {'emportassiez', 'rempotassiez'},
#  {'emporterions', 'rempoterions'},
#  {'empressaient', 'passementier'},
#  {'emprisonnais', 'impressionna'},
#  {'empruntaient', 'empuantirent'},
#  {'encaisserons', 'reconnaisses'},
#  {'encaisseront', 'sectionneras'},
#  {'encastrerais', 'encrasserait'},
#  {'enceindrions', 'endocriniens', 'incendierons'},
#  {'enchantasses', 'ensachassent'},
#  {'enchérisseur', 'surenchéries'},
#  {'enferrerions', 'ferronneries'},
#  {'enfouiraient', 'fouineraient'},
#  {'engageraient', 'rengageaient'},
#  {'engloutirais', 'soulignerait'},
#  {'engloutirons', 'souligneront'},
#  {'engrangèrent', 'gangrenèrent'},
#  {'engueulerait', 'gueuleraient'},
#  {'enlisassions', 'ensilassions'},
#  {'enliseraient', 'ensileraient'},
#  {'enneigements', 'enseignement'},
#  {'enracinasses', 'renaissances'},
#  {'enracinerait', 'ricaneraient'},
#  {'enregistrais', 'restreignais'},
#  {'enregistrait', 'restreignait'},
#  {'enregistrant', 'restreignant'},
#  {'enregistrent', 'restreignent'},
#  {'enregistriez', 'restreigniez'},
#  {'enregistrons', 'restreignons'},
#  {'enrouassions', 'renouassions'},
#  {'enroueraient', 'renoueraient'},
#  {'entaillaient', 'tenaillaient'},
#  {'entaillasses', 'tenaillasses'},
#  {'entaillerais', 'tenaillerais'},
#  {'entaillerait',
#   'entretaillai',
#   'retaillaient',
#   'tailleraient',
#   'tenaillerait'},
#  {'entailleriez', 'tenailleriez'},
#  {'entaillerons', 'rationnelles', 'relationnels', 'tenaillerons'},
#  {'entailleront', 'tenailleront'},
#  {'entaillèrent', 'tenaillèrent'},
#  {'entortillait', 'tortillaient'},
#  {'entortillera', 'retailleront'},
#  {'entraînerait', 'renaîtraient', 'traîneraient'},
#  {'entrelacerai', 'recaleraient'},
#  {'entremettrai', 'remettraient'},
#  {'entremettras', 'retransmette'},
#  {'entremissent', 'ressentiment'},
#  {'entreposerai', 'reposeraient'},
#  {'entreverrais', 'renverserait'},
#  {'entreverrons', 'renverseront'},
#  {'entrouvrirai', 'rouvriraient'},
#  {'entérinerais', 'inséreraient'},
#  {'entérinerons', 'étrennerions'},
#  {'espionnerais', 'paroissienne'},
#  {'essorassions', 'sonorisasses'},
#  {'estomaquions', 'onomastiques'},
#  {'estourbirons', 'obstruerions'},
#  {'excédentaire', 'excéderaient'},
#  {'explorations', 'extrapolions'},
#  {'farcissaient', 'fricassaient', 'sanctifieras'},
#  {'feutrassions', 'furetassions'},
#  {'filtrassions', 'flirtassions'},
#  {'filtreraient', 'flirteraient'},
#  {'finasserions', 'fissionneras', 'freinassions'},
#  {'fissurerions', 'russifierons'},
#  {'flagorneries', 'regonflerais'},
#  {'fleurassions', 'refluassions'},
#  {'fleureraient', 'reflueraient'},
#  {'formalisâtes', 'rafistolâmes'},
#  {'fractionnais', 'francisation'},
#  {'fragmentaire', 'fragmenterai'},
#  {'fredonnerait', 'fronderaient', 'refondraient'},
#  {'friponneries', 'personnifier'},
#  {'fronceraient', 'renfoncerait'},
#  {'féliciterais', 'électrifiais'},
#  {'féliciterait', 'électrifiait'},
#  {'féliciteriez', 'électrifiiez'},
#  {'féliciterons', 'électrifions'},
#  {'garantissent', 'granitassent', 'gratinassent'},
#  {'garantissiez', 'granitassiez', 'gratinassiez'},
#  {'germanisâtes', 'transigeâmes'},
#  {'gestionnaire', 'soigneraient'},
#  {'gonfleraient', 'regonflaient'},
#  {'graniterions', 'gratinerions', 'grisonnerait'},
#  {'granularités', 'régularisant'},
#  {'gratifieront', 'interrogatif'},
#  {'grimperaient', 'regrimpaient'},
#  {'horticulteur', 'horticulture'},
#  {'hospitaliers', 'hospitaliser'},
#  {'humaniserait', 'humanitaires'},
#  {'immortalisée', 'mémorialiste'},
#  {'immuniserait', 'immunitaires'},
#  {'impénitentes', 'piétinements'},
#  {'incantations', 'sanctionnait'},
#  {'incendiaires', 'incendierais'},
#  {'infligerions', 'lignifierons'},
#  {'insonorisent', 'tisonnerions'},
#  {'inspecterait', 'interceptais'},
#  {'inspecteront', 'interceptons'},
#  {'instaurerons', 'nourrissante'},
#  {'intarissable', 'rentabilisas'},
#  {'intercalaire', 'intercalerai'},
#  {'interrompues', 'permuterions'},
#  {'intervenions', 'inventerions'},
#  {'intervention', 'inventorient'},
#  {'intitulasses', 'utilisassent'},
#  {'intriguasses', 'surgissaient'},
#  {'intronisasse', 'ironisassent'},
#  {'intéressante', 'éreintassent'},
#  {'intéressasse', 'éternisasses'},
#  {'intéresserai', 'éterniserais'},
#  {'inventoriais', 'visionnerait'},
#  {'inventorions', 'visionneront'},
#  {'irrationnels', 'ralentirions'},
#  {'lapidassions', 'palissadions', 'plaidassions'},
#  {'lapideraient', 'plaideraient'},
#  {'libératoires', 'oblitérerais'},
#  {'limitassions', 'militassions'},
#  {'limiteraient', 'militeraient'},
#  {'législateurs', 'législatures'},
#  {'mailleraient', 'remaillaient'},
#  {'marbreraient', 'rembarraient'},
#  {'marinassions', 'ranimassions'},
#  {'marineraient', 'ranimeraient'},
#  {'maritalement', 'martialement'},
#  {'marqueraient', 'remarquaient'},
#  {'martèlerions', 'moralisèrent'},
#  {'menstruation', 'surmontaient'},
#  {'mentionneras', 'raisonnement', 'sermonnaient'},
#  {'mesureraient', 'remesuraient'},
#  {'minutassions', 'mutinassions'},
#  {'minuteraient', 'mutineraient'},
#  {'mitraillerai', 'rimaillerait'},
#  {'montreraient', 'remontraient'},
#  {'moralisaient', 'rationalisme'},
#  {'mâchonnerons', 'ronchonnâmes'},
#  {'mécanisation', 'méconnaisait'},
#  {'mépriserions', 'réimpression'},
#  {'mésallierait', 'métalliserai'},
#  {'nasillerions', 'sillonnerais'},
#  {'naturalisent', 'neutralisant'},
#  {'naturalismes', 'suralimentas'},
#  {'notifiassent', 'tonifiassent'},
#  {'notifiassiez', 'tonifiassiez'},
#  {'notifierions', 'tonifierions'},
#  {'nourrisseurs', 'susurrerions'},
#  {'offusquaient', 'suffoquaient'},
#  {'offusquasses', 'suffoquasses'},
#  {'offusquerais', 'suffoquerais'},
#  {'offusquerait', 'suffoquerait'},
#  {'offusqueriez', 'suffoqueriez'},
#  {'offusquerons', 'suffoquerons'},
#  {'offusqueront', 'suffoqueront'},
#  {'offusquèrent', 'suffoquèrent'},
#  {'optimiserons', 'temporisions'},
#  {'ourdissaient', 'soutiendrais'},
#  {'outillassent', 'touillassent'},
#  {'outillassiez', 'touillassiez'},
#  {'outillerions', 'touillerions'},
#  {'ovalisassent', 'tavelassions'},
#  {'panifierions', 'personnifiai'},
#  {'papilloteras', 'parpaillotes'},
#  {'parasitaires', 'parasiterais', 'reparaissait'},
#  {'parasiterons', 'transposerai'},
#  {'parcellaires', 'parcellerais'},
#  {'paressassent', 'repassassent'},
#  {'paressassiez', 'repassassiez'},
#  {'paresserions', 'repasserions'},
#  {'parlementais', 'paternalisme'},
#  {'parlementait', 'partialement'},
#  {'partageasses', 'rapetassages'},
#  {'pasteurisons', 'soupirassent'},
#  {'patenterions', 'patienterons'},
#  {'patriciennes', 'praticiennes'},
#  {'patrouillait', 'tripatouilla'},
#  {'peinturlurai', 'turlupinerai'},
#  {'peinturluras', 'turlupineras'},
#  {'peinturlurez', 'turlupinerez'},
#  {'pensionnaire', 'pensionnerai'},
#  {'persistaient', 'repentissait'},
#  {'personnalisé', 'pénaliserons'},
#  {'personnalité', 'pénaliseront'},
#  {'persécuteras', 'répercutasse'},
#  {'peupleraient', 'repeuplaient'},
#  {'photograveur', 'photogravure'},
#  {'plâtreraient', 'replâtraient'},
#  {'pointassions', 'potinassions'},
#  {'pointeraient', 'potineraient'},
#  {'popularisent', 'propulsaient'},
#  {'pousseraient', 'repoussaient'},
#  {'pralinassent', 'transalpines'},
#  {'pressentiras', 'reprisassent', 'respirassent'},
#  {'presseraient', 'serpenterais'},
#  {'promettaient', 'trompetaient'},
#  {'préconiserai', 'rapiécerions'},
#  {'prédestinons', 'répondissent'},
#  {'présenterais', 'représentais'},
#  {'présenterait', 'représentait'},
#  {'présenteriez', 'représentiez'},
#  {'présenterons', 'représentons'},
#  {'publieraient', 'republiaient'},
#  {'raboutissant', 'tarabustions'},
#  {'railleraient', 'rallieraient'},
#  {'raisonnerait', 'rationnerais'},
#  {'raisonneront', 'rationnerons'},
#  {'rapetassions', 'retapassions'},
#  {'rapetissions', 'tapisserions'},
#  {'rappareilles', 'rappellerais'},
#  {'rappareillés', 'éparpilleras'},
#  {'ratification', 'tarification'},
#  {'rationalisés', 'réalisations'},
#  {'ratissassent', 'transitasses'},
#  {'ratisserions', 'ressaisiront', 'retirassions'},
#  {'rattraperons', 'transportera'},
#  {'ravitaillera', 'retravaillai', 'travaillerai'},
#  {'ravitaillons', 'travaillions'},
#  {'reboucheront', 'tournebroche'},
#  {'reconstituer', 'reconstruite'},
#  {'reconstruire', 'recruterions'},
#  {'redevinssent', 'revendissent'},
#  {'redevinssiez', 'revendissiez'},
#  {'regagnerions', 'rengagerions'},
#  {'regarnissais', 'rengraissais'},
#  {'regarnissait', 'rengraissait', 'transigerais'},
#  {'regarnissant', 'rengraissant'},
#  {'regarnissent', 'rengraissent'},
#  {'regarnissiez', 'rengraissiez'},
#  {'regarnissons', 'rengraissons'},
#  {'reléguassent', 'étrangleuses'},
#  {'rembourrasse', 'rembourseras'},
#  {'remportaient', 'tromperaient'},
#  {'reprisassiez', 'respirassiez'},
#  {'repriserions', 'respirerions'},
#  {'ressaisirent', 'ressentirais'},
#  {'ressauterait', 'tressauterai'},
#  {'ressauterons', 'retournasses'},
#  {'restauraient', 'satureraient'},
#  {'retaillasses', 'satelliseras'},
#  {'retentissais', 'sertissaient'},
#  {'retouchaient', 'toucheraient'},
#  {'retournaient', 'tourneraient'},
#  {'retranchions', 'trancherions'},
#  {'retransmises', 'retransmisse'},
#  {'retravaillas', 'travailleras'},
#  {'retravaillez', 'travaillerez'},
#  {'retrempaient', 'tremperaient'},
#  {'retroussions', 'trousserions'},
#  {'retrouvaient', 'trouveraient'},
#  {'revalorisais', 'valoriserais'},
#  {'revalorisait', 'valoriserait'},
#  {'revalorisiez', 'valoriseriez'},
#  {'revalorisons', 'valoriserons'},
#  {'revivifiions', 'vivifierions'},
#  {'rouillassent', 'sautillerons'},
#  {'rugissements', 'surgissement'},
#  {'réconfortait', 'torréfaction'},
#  {'réformassent', 'transformées'},
#  {'réfractaires', 'réfracterais'},
#  {'régimentaire', 'émigreraient'},
#  {'réglementant', 'étranglement'},
#  {'rééditassent', 'sédentarités'},
#  {'sacrifiaient', 'sanctifierai', 'scarifiaient'},
#  {'sacrifiasses', 'scarifiasses'},
#  {'sacrifierais', 'scarifierais'},
#  {'sacrifierait', 'scarifierait'},
#  {'sacrifieriez', 'scarifieriez'},
#  {'sacrifierons', 'scarifierons'},
#  {'sacrifieront', 'scarifieront'},
#  {'sacrifièrent', 'scarifièrent'},
#  {'segmentaires', 'segmenterais'},
#  {'soutirassent', 'tressautions'},
#  {'stationnaire', 'stationnerai'},
#  {'subordonnais', 'surabondions'},
#  {'superposions', 'supposerions'},
#  {'suzerainetés', 'éternuassiez'},
#  {'sécularisons', 'ulcérassions'},
#  {'tiraillasses', 'tressaillais'},
#  {'totaliserait', 'totalitaires'},
#  {'transitaires', 'transiterais'},
#  {'transmuerait', 'transmuterai'},
#  {'transportées', 'trépasseront'},
#  {'visionnaires', 'visionnerais'},
#  {'viticulteurs', 'viticultures'},
#  {'véhiculaires', 'véhiculerais'},
#  {'écartelaient', 'éclateraient'},
#  {'épaississons', 'épissassions'},
#  {'étiolassions', 'étoilassions'},
#  {'étioleraient', 'étoileraient'},
#  {'abattraient', 'barattaient', 'rabattaient'},
#  {'aboliraient', 'bariolaient'},
#  {'abondassent', 'bastonnades'},
#  {'abrutissent', 'bruitassent'},
#  {'abrutissiez', 'bruitassiez'},
#  {'abrégerions', 'éborgnerais'},
#  {'absentaient', 'abstenaient'},
#  {'absenterons', 'enrobassent'},
#  {'absorberait', 'barboterais'},
#  {'absorberont', 'barboterons'},
#  {'abstrairont', 'rabattrions'},
#  {'accidentera', 'cadencerait'},
#  {'acclamerait', 'acclimatera'},
#  {'accorderons', 'concorderas'},
#  {'accotassent', 'contactasse'},
#  {'accourrions', 'concourrais'},
#  {'accueillant', 'calculaient'},
#  {'accéderions', 'concéderais'},
#  {'acharnerait', 'arrachaient'},
#  {'acquerrions', 'conquerrais', 'craquerions'},
#  {'actionnaire', 'actionnerai'},
#  {'acuponcteur', 'acuponcture'},
#  {'acupuncteur', 'acupuncture'},
#  {'administrée', 'démentirais', 'déterminais'},
#  {'admirateurs', 'musarderait'},
#  {'admirerions', 'endormirais'},
#  {'admonestais', 'amodiassent'},
#  {'adoucissons', 'coudassions'},
#  {'adressaient', 'entraidasse'},
#  {'adresseront', 'redorassent'},
#  {'adsorbaient', 'sabordaient'},
#  {'adsorbasses', 'sabordasses'},
#  {'adsorberais', 'saborderais'},
#  {'adsorberait', 'saborderait'},
#  {'adsorberiez', 'saborderiez'},
#  {'adsorberons', 'saborderons'},
#  {'adsorberont', 'saborderont'},
#  {'adsorbèrent', 'sabordèrent'},
#  {'advenissent', 'devinassent'},
#  {'affairasses', 'affaisseras'},
#  {'affairement', 'affermaient'},
#  {'affaireront', 'affronterai'},
#  {'affaisserez', 'effarassiez'},
#  {'affermirais', 'affirmerais'},
#  {'affermirait', 'affirmerait'},
#  {'affermiriez', 'affirmeriez'},
#  {'affermirons', 'affirmerons'},
#  {'affermiront', 'affirmeront'},
#  {'affilerions', 'affilierons'},
#  {'affiliasses', 'falsifiasse'},
#  {'affilierais', 'falsifierai'},
#  {'affleurions', 'affluerions', 'faufilerons'},
#  {'affouillira', 'farfouillai'},
#  {'affriolante', 'raffolaient'},
#  {'affrioleras', 'raffolerais'},
#  {'affriolerez', 'raffoleriez'},
#  {'agencerions', 'encagerions', 'engoncerais'},
#  {'agonisasses', 'angoissasse'},
#  {'agoniserais', 'angoisserai'},
#  {'agriculteur', 'agriculture'},
#  {'agréassions', 'égarassions'},
#  {'agréeraient', 'égareraient'},
#  {'agrémentais', 'magnétisera'},
#  {'agrémentent', 'étrangement'},
#  {'aimablement', 'amiablement'},
#  {'aimanterais', 'samaritaine'},
#  {'alanguiront', 'granulation'},
#  {'alanguisses', 'alunissages'},
#  {'alarmerions', 'normalisera'},
#  {'alcoolisant', 'allocations'},
#  {'alertassent', 'relatassent'},
#  {'alertassiez', 'relatassiez'},
#  {'alerterions', 'relaterions', 'rentoileras'},
#  {'algorithmes', 'logarithmes'},
#  {'algériennes', 'régaliennes'},
#  {'alignements', 'signalement'},
#  {'alimentaire', 'alimenterai'},
#  {'alimenteras', 'lamenterais'},
#  {'alimenterez', 'lamenteriez'},
#  {'aliénations', 'nationalisé'},
#  {'alliassions', 'assaillions'},
#  {'allieraient', 'entaillerai', 'tenaillerai'},
#  {'allongerais', 'rallongeais'},
#  {'allongerait', 'rallongeait'},
#  {'allongerons', 'rallongeons'},
#  {'allégerions', 'égaillerons'},
#  {'altérerions', 'réaliseront'},
#  {'amasserions', 'romanisasse'},
#  {'ambrassions', 'bramassions'},
#  {'ambreraient', 'brameraient'},
#  {'amerririons', 'arrimerions'},
#  {'amerrissant', 'arrimassent'},
#  {'amerrissent', 'retransmise'},
#  {'amoindrisse', 'modernisais'},
#  {'amortissent', 'assortiment'},
#  {'aménagement', 'emménageant'},
#  {'américaines', 'américanise', 'mécaniserai'},
#  {'ancestrales', 'recalassent'},
#  {'ancillairee', 'canaillerie'},
#  {'ancrassions', 'nacrassions'},
#  {'ancreraient', 'nacreraient'},
#  {'angiosperme', 'empoigneras'},
#  {'angoisseras', 'organisasse', 'rageassions'},
#  {'angoisserez', 'rongeassiez'},
#  {'animassions', 'maniassions'},
#  {'animeraient', 'manieraient', 'remaniaient'},
#  {'annoncerais', 'canonnerais'},
#  {'annoncerait', 'canonnerait', 'cantonnerai'},
#  {'annonceriez', 'canonneriez'},
#  {'annoncerons', 'canonnerons'},
#  {'annonceront', 'canonneront'},
#  {'annoncèrent', 'canonnèrent'},
#  {'annotatrice', 'racontaient'},
#  {'antichambre', 'chambraient', 'embranchait'},
#  {'antiquaires', 'taquinerais'},
#  {'antirouille', 'rouillaient'},
#  {'antisociale', 'coalisaient'},
#  {'antisémites', 'métissaient'},
#  {'antérieures', 'éternuerais'},
#  {'antériorité', 'réitération'},
#  {'aplanissait', 'plaisantais'},
#  {'aplanissons', 'planassions'},
#  {'aposterions', 'patoiserons'},
#  {'appareiller', 'rappareille', 'rappellerai'},
#  {'appareilles', 'appellerais'},
#  {'apparentais', 'appartenais', 'appesantira'},
#  {'apparentait', 'appartenait'},
#  {'apparentant', 'appartenant'},
#  {'apparentiez', 'apparteniez'},
#  {'appontasses', 'apposassent'},
#  {'apponterait', 'apportaient'},
#  {'apprenaient', 'inapparente'},
#  {'arabisantes', 'baratinasse'},
#  {'arbitraires', 'arbitrerais'},
#  {'archivaient', 'chaviraient'},
#  {'archivasses', 'chavirasses'},
#  {'archiverais', 'chavirerais'},
#  {'archiverait', 'chavirerait'},
#  {'archiveriez', 'chavireriez'},
#  {'archiverons', 'chavirerons'},
#  {'archiveront', 'chavireront'},
#  {'archivèrent', 'chavirèrent'},
#  {'argentaient', 'ganteraient'},
#  {'aristocrate', 'carotterais'},
#  {'arpenterais', 'partenaires'},
#  {'arpenterait', 'repartaient'},
#  {'arqueraient', 'quaternaire'},
#  {'arraisonnes', 'raisonneras'},
#  {'articulaire', 'articulerai'},
#  {'artistement', 'traitements'},
#  {'artésiennes', 'entérinasse'},
#  {'ascendantes', 'cadenassent'},
#  {'aspirations', 'parasitions'},
#  {'assaillirez', 'raillassiez', 'ralliassiez'},
#  {'assainirons', 'rainassions'},
#  {'assainissez', 'assassiniez'},
#  ...]

# %%
# list of anagram sets, sorted by their length, largest first
sorted(anagrams_by_sig.values(), key=len, reverse=True)
# Out:
# [{'asservi',
#   'ravises',
#   'ravisse',
#   'rivasse',
#   'servais',
#   'sevrais',
#   'versais',
#   'virasse',
#   'viseras',
#   'vissera'},
#  {'engrais',
#   'garnies',
#   'graines',
#   'ignares',
#   'regains',
#   'saigner',
#   'seringa',
#   'signera',
#   'singera'},
#  {'assister',
#   'ratisses',
#   'striasse',
#   'tarisses',
#   'tirasses',
#   'tisseras',
#   'tressais',
#   'triasses'},
#  {'aviser',
#   'ravies',
#   'ravise',
#   'sevrai',
#   'varies',
#   'versai',
#   'visera',
#   'vraies'},
#  {'ratiers',
#   'retiras',
#   'sertira',
#   'striera',
#   'tarsier',
#   'terrais',
#   'tireras',
#   'trieras'},
#  {'ratisse',
#   'restais',
#   'satires',
#   'tarisse',
#   'tirasse',
#   'tissera',
#   'tressai',
#   'triasse'},
#  {'agréent', 'argenté', 'gérante', 'renégat', 'régenta', 'égarent', 'étrange'},
#  {'amuser', 'masure', 'maures', 'mesura', 'mueras', 'musera', 'remuas'},
#  {'ancre', 'caner', 'carne', 'cerna', 'encra', 'nacre', 'rance'},
#  {'arrives', 'raviers', 'raviser', 'riveras', 'servira', 'verrais', 'vireras'},
#  {'aspirer', 'praires', 'prieras', 'prisera', 'reprisa', 'respira', 'riperas'},
#  {'creusé', 'curées', 'céruse', 'césure', 'récuse', 'sucrée', 'écrues'},
#  {'entrais', 'riantes', 'satiner', 'sentira', 'tarsien', 'transie', 'tsarine'},
#  {'errait', 'ratier', 'retira', 'terrai', 'tirera', 'traire', 'triera'},
#  {'estropia',
#   'opterais',
#   'patoiser',
#   'poserait',
#   'posterai',
#   'reposait',
#   'toperais'},
#  {'gantiers',
#   'granites',
#   'gratines',
#   'grisante',
#   'ingrates',
#   'seringat',
#   'transige'},
#  {'granitée',
#   'gratinée',
#   'gréaient',
#   'géraient',
#   'régentai',
#   'égrenait',
#   'érigeant'},
#  {'agression',
#   'angoisser',
#   'ignorasse',
#   'organises',
#   'soigneras',
#   'songerais'},
#  {'amerri', 'arrime', 'marier', 'mirera', 'ramier', 'rimera'},
#  {'amerris', 'arrimes', 'mireras', 'ramiers', 'rimeras', 'simarre'},
#  {'ancres', 'carnes', 'cernas', 'encras', 'nacres', 'rances'},
#  {'argentai', 'ganterai', 'garaient', 'garantie', 'nagerait', 'rangeait'},
#  {'arpentés', 'espérant', 'parentés', 'présenta', 'séparent', 'trépanes'},
#  {'arrive', 'ravier', 'rivera', 'varier', 'verrai', 'virera'},
#  {'arsenic', 'cernais', 'encrais', 'racines', 'rancies', 'ricanes'},
#  {'aspirasse',
#   'paraisses',
#   'paressais',
#   'pariasses',
#   'passerais',
#   'repassais'},
#  {'assagirent',
#   'garantisse',
#   'granitasse',
#   'gratinasse',
#   'stagnerais',
#   'transigeas'},
#  {'assignerait',
#   'astreignais',
#   'engraissait',
#   'graissaient',
#   'signataires',
#   'transigeais'},
#  {'assirent', 'astreins', 'sentiras', 'tarsiens', 'transies', 'tsarines'},
#  {'assumer', 'masseur', 'masures', 'mesuras', 'murasse', 'museras'},
#  {'aster', 'astre', 'rates', 'resta', 'tares', 'tarse'},
#  {'asters', 'astres', 'restas', 'tarses', 'tasser', 'tressa'},
#  {'astreints',
#   'ratissent',
#   'tarissent',
#   'tirassent',
#   'transites',
#   'triassent'},
#  {'atterri', 'attirer', 'retrait', 'terrait', 'titrera', 'traiter'},
#  {'attribue', 'buterait', 'butterai', 'rebutait', 'titubera', 'tuberait'},
#  {'autres', 'sature', 'sauret', 'sauter', 'surate', 'tueras'},
#  {'avenirs', 'enivras', 'inversa', 'navires', 'nervais', 'ravines'},
#  {'carient', 'centrai', 'cernait', 'certain', 'crainte', 'encrait'},
#  {'causeront',
#   'courantes',
#   'outrances',
#   'recousant',
#   'sauceront',
#   'secourant'},
#  {'densité', 'destiné', 'déteins', 'détiens', 'éteinds', 'étendis'},
#  {'diantre', 'radient', 'rendait', 'teindra', 'tendrai', 'tiendra'},
#  {'dispersé', 'déprises', 'déprisse', 'prédises', 'prédisse', 'présides'},
#  {'enlisait', 'ensilait', 'italiens', 'latinise', 'lisaient', 'litanies'},
#  {'garerions',
#   'ignoreras',
#   'organiser',
#   'ragerions',
#   'rognerais',
#   'rongerais'},
#  {'intimera', 'mentirai', 'minerait', 'miraient', 'rimaient', 'terminai'},
#  {'ivres', 'revis', 'rives', 'servi', 'vires', 'viser'},
#  {'loverais', 'ovaliser', 'valorise', 'violeras', 'voileras', 'volerais'},
#  {'onagres', 'oranges', 'organes', 'rageons', 'rongeas', 'songera'},
#  {'optais', 'patios', 'patois', 'posait', 'postai', 'topais'},
#  {'ossature', 'outrasse', 'routasse', 'sourates', 'toussera', 'trouasse'},
#  {'outer', 'outre', 'rouet', 'route', 'touer', 'troue'},
#  {'palier', 'pareil', 'perlai', 'plaire', 'pliera', 'replia'},
#  {'paliers', 'pareils', 'perlais', 'plieras', 'replias', 'spirale'},
#  {'paraisse', 'paressai', 'pariasse', 'passerai', 'repassai', 'saperais'},
#  {'parasites',
#   'paressait',
#   'passerait',
#   'rapetissa',
#   'repassait',
#   'tapissera'},
#  {'prairies', 'prierais', 'priserai', 'reprisai', 'respirai', 'riperais'},
#  {'restai', 'satire', 'serait', 'taries', 'tiares', 'traies'},
#  {'rites', 'serti', 'strie', 'tiers', 'tires', 'tries'},
#  {'abaisser', 'baiseras', 'baissera', 'baserais', 'rabaisse'},
#  {'agirent', 'gantier', 'granite', 'gratine', 'ingrate'},
#  {'agirons', 'garions', 'ignoras', 'ragions', 'rognais'},
#  {'agoniser', 'organise', 'rongeais', 'soignera', 'songerai'},
#  {'ailes', 'alise', 'asile', 'laies', 'salie'},
#  {'alertions', 'aliterons', 'laiterons', 'relations', 'rentoilas'},
#  {'alignas', 'anglais', 'glanais', 'sanglai', 'signala'},
#  {'aligneras', 'glanerais', 'langerais', 'sanglerai', 'signalera'},
#  {'alises', 'asiles', 'laisse', 'liasse', 'salies'},
#  {'ancrai', 'arnica', 'canari', 'nacrai', 'ricana'},
#  {'animer', 'manier', 'marine', 'minera', 'ranime'},
#  {'animerons', 'manierons', 'ramenions', 'remanions', 'sermonnai'},
#  {'anémier', 'marinée', 'ranimée', 'remanié', 'réamine'},
#  {'aplanit', 'palatin', 'planait', 'plantai', 'platina'},
#  {'apures', 'parues', 'pauser', 'pueras', 'sapeur'},
#  {'argent', 'ganter', 'garent', 'grenat', 'ragent'},
#  {'argentais', 'ganterais', 'garanties', 'stagnerai', 'transigea'},
#  {'argentas', 'ganteras', 'garantes', 'rageants', 'stagnera'},
#  {'argentions', 'ganterions', 'ignorantes', 'organisent', 'saigneront'},
#  {'argentés', 'gérantes', 'renégats', 'régentas', 'étranges'},
#  {'aridités', 'désirait', 'résidait', 'sidérait', 'tiédiras'},
#  {'armerions', 'marierons', 'ramerions', 'remarions', 'romaniser'},
#  {'armions', 'manoirs', 'marions', 'ramions', 'romains'},
#  {'armâtes', 'mâteras', 'ramâtes', 'ratâmes', 'tarâmes'},
#  {'artiste', 'attires', 'attiser', 'restait', 'traites'},
#  {'aspersions', 'paressions', 'passerions', 'repaissons', 'repassions'},
#  {'aspires', 'pissera', 'pressai', 'priasse', 'ripasse'},
#  {'asservis', 'ravisses', 'rivasses', 'virasses', 'visseras'},
#  {'assigner', 'garnisse', 'seringas', 'signeras', 'singeras'},
#  {'assigneront', 'astreignons', 'ignorassent', 'stagnerions', 'transigeons'},
#  {'assure', 'ruasse', 'saures', 'sueras', 'useras'},
#  {'astreint', 'nitrates', 'tartines', 'tinteras', 'transite'},
#  {'astreinte', 'rainettes', 'restaient', 'teinteras', 'tenterais'},
#  {'atroces', 'coteras', 'croates', 'escorta', 'socrate'},
#  {'atropine', 'paieront', 'pianoter', 'pointera', 'potinera'},
#  {'atterrai', 'attirera', 'raterait', 'tarerait', 'traitera'},
#  {'attirasse', 'attiseras', 'essartait', 'tasserait', 'traitasse'},
#  {'autoriser', 'outrerais', 'routerais', 'soutirera', 'trouerais'},
#  {'avaliser', 'laverais', 'revalais', 'salivera', 'valserai'},
#  {'avenir', 'enivra', 'navire', 'nervai', 'ravine'},
#  {'avertis', 'rivetas', 'servait', 'sevrait', 'versait'},
#  {'bores', 'orbes', 'robes', 'serbo', 'sobre'},
#  {'braiseras', 'braserais', 'brasserai', 'rabaisser', 'sabrerais'},
#  {'broutes', 'obstrue', 'obtures', 'robuste', 'tourbes'},
#  {'carieront', 'contraire', 'contrarie', 'contrerai', 'cornerait'},
#  {'carnet', 'centra', 'encart', 'nectar', 'tancer'},
#  {'carnets', 'centras', 'encarts', 'nectars', 'sacrent'},
#  {'casernait', 'encartais', 'encastrai', 'sacraient', 'tancerais'},
#  {'casiers', 'cassier', 'cirasse', 'criasse', 'scieras'},
#  {'casseur', 'cassure', 'creusas', 'curasse', 'suceras'},
#  {'cernai', 'encrai', 'racine', 'rancie', 'ricane'},
#  {'cintra', 'cirant', 'craint', 'criant', 'rancit'},
#  {'collerais', 'localiser', 'oscillera', 'recollais', 'rocailles'},
#  {'consentira', 'consternai', 'containers', 'encartions', 'tancerions'},
#  {'contraires', 'contraries', 'contrerais', 'retracions', 'tracerions'},
#  {'cousins', 'coussin', 'cuisons', 'cuisson', 'sucions'},
#  {'créas', 'césar', 'racés', 'sacré', 'sérac'},
#  {'créateur', 'créature', 'réacteur', 'écarteur', 'éructera'},
#  {'damerions', 'domineras', 'endormais', 'modernisa', 'monderais'},
#  {'desserrait', 'dessertira', 'dissertera', 'dresserait', 'redressait'},
#  {'diras', 'isard', 'radis', 'raids', 'ridas'},
#  {'disparité', 'prédisait', 'présidait', 'rapidités', 'trépidais'},
#  {'détruise', 'réduites', 'tiédeurs', 'éditeurs', 'érudites'},
#  {'enlisa', 'ensila', 'laines', 'lianes', 'saline'},
#  {'enrouait', 'entourai', 'nouerait', 'renouait', 'rouaient'},
#  {'entaillerait',
#   'entretaillai',
#   'retaillaient',
#   'tailleraient',
#   'tenaillerait'},
#  {'entais', 'sainte', 'satine', 'tenais', 'tisane'},
#  {'entait', 'teinta', 'tenait', 'tentai', 'titane'},
#  {'entiers', 'inertes', 'retiens', 'sentier', 'ternies'},
#  {'entité', 'teinté', 'tintée', 'tétine', 'éteint'},
#  {'entités', 'teintés', 'tintées', 'tétines', 'éteints'},
#  {'entrait', 'nitrate', 'tartine', 'tintera', 'traient'},
#  {'espéras', 'paressé', 'repassé', 'sépares', 'éparses'},
#  {'estropié', 'poétiser', 'périoste', 'pétoires', 'ripostée'},
#  {'ferais', 'fieras', 'fraies', 'fraise', 'refais'},
#  {'feutrais', 'furetais', 'fuserait', 'refusait', 'surfaite'},
#  {'gainer', 'garnie', 'graine', 'ignare', 'regain'},
#  {'garerons', 'orangers', 'ragerons', 'rogneras', 'rongeras'},
#  {'gravie', 'grevai', 'rivage', 'viager', 'virage'},
#  {'gravies', 'grevais', 'rivages', 'viagers', 'virages'},
#  {'grisée', 'gésier', 'régies', 'siéger', 'ériges'},
#  {'génies', 'ignées', 'neigés', 'signée', 'singée'},
#  {'instar', 'riants', 'tarins', 'trains', 'transi'},
#  {'inter', 'nitre', 'rient', 'tenir', 'terni'},
#  {'interposa', 'pointeras', 'potineras', 'retapions', 'taperions'},
#  {'laissera', 'lasserai', 'salaires', 'salaries', 'salerais'},
#  {'laves', 'levas', 'salve', 'slave', 'valse'},
#  {'loverai', 'variole', 'violera', 'voilera', 'volerai'},
#  {'marient', 'martien', 'mentira', 'minaret', 'termina'},
#  {'maronites', 'materions', 'monterais', 'remontais', 'romaniste'},
#  {'martiens', 'mentiras', 'minarets', 'remisant', 'terminas'},
#  {'massier', 'mirasse', 'miseras', 'remisas', 'rimasse'},
#  {'mirâtes', 'remisât', 'rimâtes', 'tirâmes', 'triâmes'},
#  {'mitrée', 'mérite', 'métier', 'trimée', 'trémie'},
#  {'mitrées', 'mérites', 'métiers', 'trimées', 'trémies'},
#  {'monteurs', 'montures', 'museront', 'muterons', 'surmonte'},
#  {'naisse', 'niases', 'niasse', 'saines', 'sanies'},
#  {'neutres', 'retenus', 'senteur', 'teneurs', 'tenseur'},
#  {'nieras', 'raines', 'renais', 'renias', 'serina'},
#  {'ossatures', 'outrasses', 'routasses', 'tousseras', 'trouasses'},
#  {'ouest', 'ouste', 'soute', 'toues', 'touse'},
#  {'outrais', 'routais', 'sautoir', 'soutira', 'trouais'},
#  {'outrer', 'retour', 'roture', 'router', 'trouer'},
#  {'pairs', 'paris', 'prias', 'prisa', 'ripas'},
#  {'parasse', 'paressa', 'passera', 'repassa', 'saperas'},
#  {'parlaient', 'planerait', 'plantaire', 'planterai', 'platinera'},
#  {'paroisse', 'passoire', 'poissera', 'poserais', 'reposais'},
#  {'partisse', 'persista', 'piastres', 'pressait', 'tapisser'},
#  {'patelins', 'plaintes', 'plaisent', 'platines', 'pliantes'},
#  {'pires', 'pries', 'prise', 'ripes', 'spire'},
#  {'pisseras', 'pressais', 'priasses', 'prisasse', 'ripasses'},
#  {'pores', 'poser', 'prose', 'repos', 'spore'},
#  {'prisé', 'priés', 'péris', 'ripés', 'épris'},
#  {'prisée', 'priées', 'péries', 'ripées', 'éprise'},
#  {'prisées', 'périsse', 'épisser', 'éprises', 'éprisse'},
#  {'ravi', 'riva', 'vair', 'vira', 'vrai'},
#  {'retint', 'ternit', 'tinter', 'tirent', 'trient'},
#  {'retirais', 'sertirai', 'strierai', 'tirerais', 'trierais'},
#  {'retirons', 'rosirent', 'terrions', 'tirerons', 'trierons'},
#  {'rotes', 'sorte', 'store', 'tores', 'torse'},
#  {'ruinasse', 'sauniers', 'sauriens', 'urinasse', 'usineras'},
#  {'réduite', 'tiédeur', 'éditeur', 'érudite', 'étudier'},
#  {'stria', 'taris', 'tiras', 'trais', 'trias'},
#  {'sueront', 'tonsure', 'tournes', 'tuerons', 'useront'},
#  {'abords', 'bordas', 'brodas', 'sabord'},
#  {'abordées', 'adsorbée', 'obsédera', 'sabordée'},
#  {'abordés', 'adsorbé', 'dérobas', 'sabordé'},
#  {'aboutir', 'broutai', 'obturai', 'rabouti'},
#  {'abriteras', 'abstraire', 'braserait', 'sabrerait'},
#  {'abrutie', 'buterai', 'rebutai', 'tuberai'},
#  {'abruties', 'buterais', 'rebutais', 'tuberais'},
#  {'aciers', 'caries', 'casier', 'sciera'},
#  {'aciérer', 'créerai', 'recréai', 'écriera'},
#  {'aciérons', 'nécrosai', 'scénario', 'écornais'},
#  {'activerons', 'conservait', 'conversait', 'novatrices'},
#  {'actuaires', 'autarcies', 'causerait', 'saucerait'},
#  {'adonis', 'aidons', 'danois', 'sondai'},
#  {'adorer', 'dorera', 'redora', 'rodera'},
#  {'adosser', 'dorasse', 'doseras', 'rodasse'},
#  {'adresser', 'desserra', 'dressera', 'redressa'},
#  {'adsorber', 'borderas', 'broderas', 'saborder'},
#  {'adsorbes', 'bordasse', 'brodasse', 'sabordes'},
#  {'adsorbées', 'dérobasse', 'obséderas', 'sabordées'},
#  {'advenir', 'veinard', 'vendrai', 'viendra'},
#  {'agiles', 'aigles', 'gelais', 'glaise'},
#  {'agirez', 'gariez', 'gazier', 'ragiez'},
#  {'agissent', 'gisantes', 'tignasse', 'tsiganes'},
#  {'agrandies', 'daigneras', 'drainages', 'sardaigne'},
#  {'agrée', 'garée', 'ragée', 'égare'},
#  {'agréer', 'gréera', 'gérera', 'égarer'},
#  {'agrées', 'garées', 'ragées', 'égares'},
#  {'aider', 'aride', 'radie', 'raide'},
#  {'aies', 'aise', 'asie', 'saie'},
#  {'ailiers', 'alisier', 'lierais', 'reliais'},
#  {'ails', 'lais', 'lias', 'sali'},
#  {'aimante', 'amenait', 'amiante', 'entamai'},
#  {'aimanter', 'armaient', 'ramaient', 'ramenait'},
#  {'aimassent', 'essaimant', 'massaient', 'satanisme'},
#  {'aimerons', 'moraines', 'romaines', 'romanise'},
#  {'aimeront', 'maronite', 'monterai', 'remontai'},
#  {'aimes', 'amies', 'maies', 'semai'},
#  {'aines', 'niase', 'saine', 'sanie'},
#  {'airs', 'iras', 'rais', 'sari'},
#  {'alarmiste', 'maritales', 'martelais', 'martiales'},
#  {'alertais', 'aliteras', 'relatais', 'salerait'},
#  {'alevin', 'envila', 'levain', 'nivela'},
#  {'alignées', 'géniales', 'inégales', 'signalée'},
#  {'alitons', 'isolant', 'laitons', 'talions'},
#  {'amandier', 'damnerai', 'manderai', 'marinade'},
#  {'amandiers', 'damnerais', 'manderais', 'marinades'},
#  {'amasser', 'armasse', 'massera', 'ramasse'},
#  {'ambrasse', 'bramasse', 'embrasas', 'embrassa'},
#  {'amendé', 'damnée', 'démena', 'mandée'},
#  {'amendés', 'damnées', 'démenas', 'mandées'},
#  {'amer', 'arme', 'mare', 'rame'},
#  {'amers', 'armes', 'mares', 'rames'},
#  {'amiens', 'animes', 'manies', 'menais'},
#  {'amnistie', 'animiste', 'misaient', 'mitaines'},
#  {'amnistier', 'intimeras', 'mentirais', 'terminais'},
#  {'amnésie', 'animées', 'anémies', 'maniées'},
#  {'amuses', 'assume', 'massue', 'muasse'},
#  {'ancraient', 'cannerait', 'incarnate', 'nacraient'},
#  {'ancrais', 'canaris', 'nacrais', 'ricanas'},
#  {'ancrasse', 'casernas', 'encrassa', 'nacrasse'},
#  {'ancrent', 'cernant', 'encrant', 'nacrent'},
#  {'ancreront', 'cartonner', 'nacreront', 'rencontra'},
#  {'ancré', 'carné', 'nacré', 'écran'},
#  {'ancrées', 'carnées', 'caserné', 'nacrées'},
#  {'ancrés', 'carnés', 'nacrés', 'écrans'},
#  {'angles', 'glanes', 'langes', 'sangle'},
#  {'animera', 'maniera', 'ramenai', 'remania'},
#  {'animerait', 'manierait', 'mariaient', 'remaniait'},
#  {'animeras', 'manieras', 'ramenais', 'remanias'},
#  {'animerez', 'manierez', 'rameniez', 'remaniez'},
#  {'anis', 'nais', 'nias', 'sain'},
#  {'anticiper', 'patricien', 'pincerait', 'praticien'},
#  {'antres', 'entras', 'rasent', 'transe'},
#  {'aoriste', 'oserait', 'otaries', 'toisera'},
#  {'apens', 'panes', 'panse', 'pensa'},
#  {'aposter', 'opteras', 'postera', 'toperas'},
#  {'apostes', 'optasse', 'potasse', 'topasse'},
#  {'arbres', 'barres', 'braser', 'sabrer'},
#  {'arbuste', 'buteras', 'rebutas', 'tuberas'},
#  {'argenta', 'gantera', 'garante', 'rageant'},
#  {'argenterai', 'enragerait', 'gareraient', 'rageraient'},
#  {'armais', 'marais', 'marias', 'ramais'},
#  {'armerai', 'mariera', 'ramerai', 'remaria'},
#  {'armerais', 'marieras', 'ramerais', 'remarias'},
#  {'armeriez', 'marierez', 'rameriez', 'remariez'},
#  {'armeront', 'montrera', 'rameront', 'remontra'},
#  {'armure', 'murera', 'rameur', 'ramure'},
#  {'armures', 'mureras', 'rameurs', 'ramures'},
#  {'arpentai', 'panerait', 'paraient', 'patinera'},
#  {'arpentais', 'panserait', 'partisane', 'patineras'},
#  {'arpentes', 'parentes', 'paternes', 'serpenta'},
#  {'arrimaient', 'marinerait', 'ranimerait', 'tamarinier'},
#  {'arrosent', 'raseront', 'raterons', 'tarerons'},
#  {'arts', 'rats', 'star', 'tsar'},
#  {'artésien', 'stéarine', 'éreintas', 'éternisa'},
#  {'aspire', 'paires', 'paries', 'repais'},
#  {'aspirera', 'parerais', 'parieras', 'reparais'},
#  {'aspirée', 'espérai', 'pariées', 'épieras'},
#  {'assembler', 'rassemble', 'ressembla', 'sembleras'},
#  {'assistera', 'essartais', 'sasserait', 'tasserais'},
#  {'assorti', 'rossait', 'sirotas', 'sortais'},
#  {'assumes', 'massues', 'muasses', 'musasse'},
#  {'assurer', 'raseurs', 'rassure', 'ruseras'},
#  {'atours', 'outras', 'routas', 'trouas'},
#  {'atteintes', 'intestate', 'satinette', 'testaient'},
#  {'atterries', 'resterait', 'retraites', 'sarriette'},
#  {'attira', 'ratait', 'tarait', 'traita'},
#  {'attirerions', 'sortiraient', 'traiterions', 'transitoire'},
#  {'attirées', 'traitées', 'téterais', 'étatiser'},
#  {'avarient', 'entravai', 'vanterai', 'variante'},
#  {'avent', 'navet', 'vante', 'venta'},
#  {'avers', 'raves', 'sevra', 'versa'},
#  {'avertisse', 'estiveras', 'rivetasse', 'savetiers'},
#  {'avril', 'livra', 'rival', 'viral'},
#  {'baiseront', 'obstinera', 'reboisant', 'snoberait'},
#  {'baisers', 'baisser', 'bissera', 'braises'},
#  {'balais', 'balisa', 'blasai', 'sablai'},
#  {'balisera', 'blaserai', 'rabelais', 'sablerai'},
#  {'barrasse', 'braseras', 'brassera', 'sabreras'},
#  {'barries', 'braiser', 'brasier', 'brisera'},
#  {'bastion', 'boisant', 'obstina', 'snobait'},
#  {'boiseras', 'bosserai', 'isobares', 'reboisas'},
#  {'bordées', 'brodées', 'dérobes', 'obséder'},
#  {'bouter', 'broute', 'obture', 'tourbe'},
#  {'braisa', 'brasai', 'rabais', 'sabrai'},
#  {'braisas', 'brasais', 'brassai', 'sabrais'},
#  {'brassée', 'brasées', 'sabrées', 'ébrases'},
#  {'broutais', 'obstruai', 'obturais', 'raboutis'},
#  {'broutent', 'buteront', 'obturent', 'tuberont'},
#  {'broutera', 'obturera', 'raboteur', 'rabouter'},
#  {'brouterais', 'estourbira', 'obstruerai', 'obturerais'},
#  {'brouteras', 'obstruera', 'obtureras', 'raboteurs'},
#  {'brute', 'buter', 'rebut', 'tuber'},
#  {'butait', 'buttai', 'tituba', 'tubait'},
#  {'cadraient', 'cardaient', 'encadrait', 'incartade'},
#  {'calerai', 'lacerai', 'raciale', 'recalai'},
#  {'caleraient', 'enlacerait', 'laceraient', 'recalaient'},
#  {'calerais', 'lacerais', 'raciales', 'recalais'},
#  {'calerions', 'enclorais', 'lacerions', 'recalions'},
#  {'califes', 'faciles', 'ficelas', 'fiscale'},
#  {'caressai', 'cariasse', 'caserais', 'casserai'},
#  {'caressas', 'casseras', 'rascasse', 'sacrasse'},
#  {'caressé', 'créasse', 'sacrées', 'écrases'},
#  {'carrelaient', 'intercalera', 'racleraient', 'relancerait'},
#  {'carrées', 'créeras', 'recréas', 'écraser'},
#  {'cartonnes', 'consterna', 'encartons', 'tancerons'},
#  {'cartésiens', 'résistance', 'scénariste', 'écriassent'},
#  {'casaniers', 'casernais', 'encrassai', 'ricanasse'},
#  {'casernerait', 'encarterais', 'encastrerai', 'sacreraient'},
#  {'casernes', 'cernasse', 'encrasse', 'recensas'},
#  {'casser', 'crasse', 'ressac', 'sacres'},
#  {'casseurs', 'cassures', 'curasses', 'sucrasse'},
#  {'causer', 'creusa', 'saucer', 'sucera'},
#  {'ceintes', 'escient', 'inceste', 'insecte'},
#  {'ceinturas', 'censurait', 'recuisant', 'sucraient'},
#  {'centralisa', 'intercalas', 'sarclaient', 'scarlatine'},
#  {'cires', 'cries', 'crise', 'scier'},
#  {'citronnade', 'contendrai', 'contiendra', 'endoctrina'},
#  {'classeras', 'raclasses', 'reclassas', 'sarclasse'},
#  {'codeur', 'couder', 'coudre', 'recoud'},
#  {'coeurs', 'coures', 'course', 'source'},
#  {'conservai', 'conversai', 'convieras', 'crevaison'},
#  {'conserver', 'converser', 'creverons', 'recevrons'},
#  {'consterneras', 'encastrerons', 'encrasseront', 'rencontrasse'},
#  {'coursier', 'croiseur', 'secourir', 'sourcier'},
#  {'coursiers', 'croiseurs', 'sourciers', 'souscrire'},
#  {'creusés', 'césures', 'récuses', 'sucrées'},
#  {'crues', 'cures', 'sucer', 'sucre'},
#  {'créateurs', 'créatures', 'réacteurs', 'éructeras'},
#  {'créations', 'nécrosait', 'réactions', 'écartions'},
#  {'curerions', 'noirceurs', 'nourrices', 'recuirons'},
#  {'curies', 'recuis', 'scieur', 'sciure'},
#  {'daigner', 'gardien', 'geindra', 'grandie'},
#  {'dentaires', 'denterais', 'destinera', 'entraides'},
#  {'dentais', 'destina', 'disante', 'tendais'},
#  {'denter', 'redent', 'tender', 'tendre'},
#  {'devisé', 'dévies', 'vidées', 'évides'},
#  {'dinar', 'drain', 'nadir', 'radin'},
#  {'dinars', 'drains', 'nadirs', 'radins'},
#  {'diraient', 'ridaient', 'teindrai', 'tiendrai'},
#  {'dise', 'ides', 'side', 'sied'},
#  {'dorent', 'endort', 'rodent', 'tondre'},
#  {'doreurs', 'dorures', 'ordures', 'sourdre'},
#  {'dormaient', 'endormait', 'monderait', 'mordaient'},
#  {'douterons', 'redoutons', 'souderont', 'tournedos'},
#  {'draines', 'radines', 'rendais', 'sardine'},
#  {'drupe', 'duper', 'perdu', 'prude'},
#  {'défaire', 'déferai', 'défiera', 'défraie'},
#  {'délai', 'délia', 'idéal', 'élida'},
#  {'démentirai', 'déminerait', 'déterminai', 'médiraient'},
#  {'démises', 'démisse', 'médises', 'médisse'},
#  {'déparions', 'dérapions', 'pondérais', 'répondais'},
#  {'départies', 'dépistera', 'dépiteras', 'pédiatres'},
#  {'dépister', 'prédites', 'trépides', 'trépieds'},
#  {'dépiter', 'prédite', 'trépide', 'trépied'},
#  {'déplais', 'déplias', 'lapidés', 'plaidés'},
#  {'dérisions', 'désirions', 'résidions', 'sidérions'},
#  {'désira', 'radiés', 'résida', 'sidéra'},
#  {'désiraient', 'résidaient', 'sidéraient', 'éteindrais'},
#  {'désirerai', 'irradiées', 'résiderai', 'sidérerai'},
#  {'désireront', 'déterrions', 'résideront', 'sidéreront'},
#  {'déteint', 'détient', 'éditent', 'étendit'},
#  {'détruis', 'réduits', 'surdité', 'érudits'},
#  {'empirés', 'méprise', 'primées', 'périmes'},
#  {'emporterais', 'rempoterais', 'temporaires', 'temporisera'},
#  {'enivrait', 'invitera', 'rivaient', 'viraient'},
#  {'enivre', 'envier', 'veiner', 'vernie'},
#  {'enivreras', 'inversera', 'nerverais', 'renversai'},
#  {'enivres', 'inverse', 'reviens', 'vernies'},
#  {'enlisas', 'ensilas', 'saliens', 'salines'},
#  {'enlisé', 'ensilé', 'lésine', 'sénile'},
#  {'enlisés', 'ensilés', 'lésines', 'séniles'},
#  {'enrouerait', 'entourerai', 'renouerait', 'roueraient'},
#  {'enserrait', 'enterrais', 'entrerais', 'ternaires'},
#  {'ensuis', 'nuises', 'unisse', 'usines'},
#  {'entaillerons', 'rationnelles', 'relationnels', 'tenaillerons'},
#  {'enter', 'entre', 'rente', 'terne'},
#  {'enterrai', 'entrerai', 'erraient', 'ternaire'},
#  {'enterrait', 'entrerait', 'retentira', 'terraient'},
#  {'entourait', 'outraient', 'routaient', 'trouaient'},
#  {'entourerait', 'outreraient', 'routeraient', 'troueraient'},
#  {'entrai', 'raient', 'ratine', 'riante'},
#  {'entraidés', 'sidérante', 'éteindras', 'étendrais'},
#  {'entrain', 'interna', 'rainent', 'reniant'},
#  {'entrepris', 'repentirs', 'reprisent', 'respirent'},
#  {'envers', 'nerves', 'nevers', 'vernes'},
#  {'envias', 'vaines', 'veinas', 'venais'},
#  {'envions', 'innoves', 'veinons', 'venions'},
#  {'envolait', 'lovaient', 'violenta', 'volaient'},
#  {'envolerait', 'loveraient', 'violentera', 'voleraient'},
#  {'espéra', 'parées', 'sépare', 'éparse'},
#  {'espérait', 'piratées', 'piéteras', 'péterais'},
#  {'essaieront', 'essoraient', 'notairesse', 'orientasse'},
#  {'essarta', 'ratasse', 'tarasse', 'tassera'},
#  {'essartas', 'ratasses', 'tarasses', 'tasseras'},
#  {'essarter', 'resteras', 'terrasse', 'tressera'},
#  {'estant', 'nattes', 'tantes', 'tentas'},
#  {'eurent', 'neutre', 'retenu', 'teneur'},
#  {'faire', 'ferai', 'fiera', 'fraie'},
#  {'feutrons', 'fortunes', 'furetons', 'fuseront'},
#  {'filateur', 'filature', 'fleurait', 'refluait'},
#  {'filoutera', 'flouerait', 'foulerait', 'refoulait'},
#  {'filtrée', 'flirtée', 'flétrie', 'tréfile'},
#  {'filtrées', 'flirtées', 'flétries', 'tréfiles'},
#  {'fonder', 'fondre', 'fronde', 'refond'},
#  {'fraierait', 'ratifiera', 'tarifaire', 'tariferai'},
#  {'fraiserait', 'ratifieras', 'tarifaires', 'tariferais'},
#  {'gaineras', 'nagerais', 'rangeais', 'saignera'},
#  {'gantés', 'géants', 'stagné', 'étangs'},
#  {'garnit', 'granit', 'gratin', 'ingrat'},
#  {'garé', 'gréa', 'géra', 'ragé'},
#  {'garés', 'gréas', 'géras', 'ragés'},
#  {'germai', 'imager', 'maigre', 'mirage'},
#  {'glapie', 'pilage', 'plagie', 'pliage'},
#  {'glapies', 'pilages', 'plagies', 'pliages'},
#  {'gneiss', 'seings', 'signes', 'singes'},
#  {'goure', 'orgue', 'rogue', 'rouge'},
#  {'goures', 'orgues', 'rogues', 'rouges'},
#  {'graissent', 'grisantes', 'seringats', 'transiges'},
#  {'granité', 'gratiné', 'intégra', 'régnait'},
#  {'granitées', 'gratinées', 'régentais', 'transigée'},
#  {'granités', 'gratinés', 'intégras', 'transigé'},
#  {'grimée', 'régime', 'rémige', 'émigre'},
#  {'grimées', 'régimes', 'rémiges', 'émigres'},
#  {'imiterons', 'minotiers', 'moisirent', 'timoniers'},
#  {'insertion', 'intronise', 'ironisent', 'tisonnier'},
#  {'insertions', 'intronises', 'sentirions', 'tisonniers'},
#  {'internasse', 'renaissent', 'reniassent', 'tarsiennes'},
#  {'interposai', 'patinoires', 'pointerais', 'potinerais'},
#  {'interposé', 'piéterons', 'protéines', 'péterions'},
#  {'intervenais', 'inventaires', 'inventerais', 'inversaient'},
#  {'intra', 'riant', 'tarin', 'train'},
#  {'iraient', 'nierait', 'reniait', 'riaient'},
#  {'irait', 'riait', 'tirai', 'triai'},
#  {'iriseront', 'retirions', 'tirerions', 'trierions'},
#  {'irons', 'noirs', 'orins', 'rions'},
#  {'laiteron', 'oriental', 'relation', 'rentoila'},
#  {'larguée', 'léguera', 'relégua', 'élaguer'},
#  {'latrines', 'ralentis', 'relisant', 'salirent'},
#  {'lavais', 'saliva', 'valais', 'valsai'},
#  {'laveurs', 'revalus', 'valeurs', 'valseur'},
#  {'lierons', 'liseron', 'noliser', 'relions'},
#  {'lieurs', 'liseur', 'reluis', 'silure'},
#  {'limiterais', 'militaires', 'militarise', 'militerais'},
#  {'lovais', 'violas', 'voilas', 'volais'},
#  {'loveriez', 'violerez', 'voilerez', 'voleriez'},
#  {'loverions', 'violerons', 'voilerons', 'volerions'},
#  {'loviez', 'violez', 'voilez', 'voliez'},
#  {'lovions', 'violons', 'voilons', 'volions'},
#  {'maires', 'maries', 'misera', 'remisa'},
#  {'marinera', 'marnerai', 'marraine', 'ranimera'},
#  {'marineras', 'marnerais', 'marraines', 'ranimeras'},
#  {'marinées', 'ranimées', 'remaniés', 'réamines'},
#  {'marionnette', 'monteraient', 'ornementait', 'remontaient'},
#  {'materons', 'matrones', 'monteras', 'remontas'},
#  {'mesurai', 'muerais', 'muserai', 'remuais'},
#  {'mesurait', 'muserait', 'muterais', 'tamiseur'},
#  {'mesure', 'meures', 'remues', 'semeur'},
#  {'mesuré', 'murées', 'remués', 'résume'},
#  {'minuteras', 'mutineras', 'naturisme', 'surmenait'},
#  {'mires', 'miser', 'remis', 'rimes'},
#  {'misées', 'séisme', 'émises', 'émisse'},
#  {'mornes', 'normes', 'renoms', 'sermon'},
#  {'nations', 'sonnait', 'tisonna', 'tonnais'},
#  {'natterai', 'rataient', 'ratatine', 'taraient'},
#  {'nies', 'sein', 'sien', 'sine'},
#  {'nuies', 'nuise', 'unies', 'usine'},
#  {'nuira', 'ruina', 'unira', 'urina'},
#  {'nuirai', 'ruinai', 'unirai', 'urinai'},
#  {'nuiraient', 'ruinaient', 'uniraient', 'urinaient'},
#  {'nuirais', 'ruinais', 'unirais', 'urinais'},
#  {'nuirait', 'ruinait', 'unirait', 'urinait'},
#  {'nuiras', 'ruinas', 'uniras', 'urinas'},
#  {'nuirez', 'ruinez', 'unirez', 'urinez'},
#  {'nuiriez', 'ruiniez', 'uniriez', 'uriniez'},
#  {'nuirions', 'ruinions', 'unirions', 'urinions'},
#  {'nuirons', 'ruinons', 'unirons', 'urinons'},
#  {'ocreuse', 'recouse', 'secouer', 'secoure'},
#  {'olives', 'solive', 'violes', 'voiles'},
#  {'onagre', 'orange', 'organe', 'rongea'},
#  {'opinerait', 'patinoire', 'pointerai', 'potinerai'},
#  {'opter', 'porte', 'prote', 'toper'},
#  {'options', 'positon', 'potions', 'topions'},
#  {'optées', 'postée', 'potées', 'topées'},
#  {'orateur', 'outrera', 'routera', 'trouera'},
#  {'orateurs', 'outreras', 'routeras', 'troueras'},
#  {'orties', 'sirote', 'sortie', 'toiser'},
#  {'ourlées', 'reloués', 'roulées', 'résolue'},
#  {'outrai', 'rouait', 'routai', 'trouai'},
#  {'outrassent', 'routassent', 'statuerons', 'trouassent'},
#  {'outrent', 'routent', 'trouent', 'tueront'},
#  {'outrerai', 'rouerait', 'routerai', 'trouerai'},
#  {'outres', 'rouets', 'routes', 'troues'},
#  {'outrions', 'routions', 'tournois', 'trouions'},
#  {'outrons', 'routons', 'tourons', 'trouons'},
#  {'outrés', 'routés', 'résout', 'troués'},
#  {'ouvrerait', 'retrouvai', 'trouverai', 'voiturera'},
#  {'pair', 'pari', 'pria', 'ripa'},
#  {'palatins', 'plaisant', 'plantais', 'platinas'},
#  {'pantois', 'pointas', 'potinas', 'tapions'},
#  {'paraissent', 'pariassent', 'partisanes', 'repaissant'},
#  {'parasite', 'retapais', 'saperait', 'taperais'},
#  {'parasses', 'paressas', 'passeras', 'repassas'},
#  {'paressent', 'pressante', 'repassent', 'serpentas'},
#  {'paressiez', 'passeriez', 'repaissez', 'repassiez'},
#  {'parient', 'patiner', 'pintera', 'prenait'},
#  {'parier', 'praire', 'priera', 'ripera'},
#  {'parties', 'patries', 'piastre', 'pirates'},
#  {'parts', 'rapts', 'spart', 'sprat'},
#  {'patelin', 'plainte', 'platine', 'pliante'},
#  {'patenterai', 'patientera', 'retapaient', 'taperaient'},
#  {'persistera', 'presserait', 'rapetisser', 'sparteries'},
#  {'peur', 'puer', 'pure', 'repu'},
#  {'peurs', 'pures', 'repus', 'super'},
#  {'pinot', 'piton', 'point', 'potin'},
#  {'pisser', 'prises', 'prisse', 'spires'},
#  {'piston', 'pitons', 'points', 'potins'},
#  {'piétons', 'pointés', 'potinés', 'pétions'},
#  {'plaisanter', 'plantaires', 'planterais', 'platineras'},
#  {'ploieras', 'polaires', 'polarise', 'spoliera'},
#  {'pointeurs', 'pointures', 'puiseront', 'soupirent'},
#  {'poreuses', 'prouesse', 'repousse', 'soupeser'},
#  {'pots', 'spot', 'stop', 'tops'},
#  {'poussée', 'soupesé', 'soupées', 'épouses'},
#  {'priseraient', 'repentirais', 'reprisaient', 'respiraient'},
#  {'priée', 'périe', 'ripée', 'épier'},
#  {'périt', 'pétri', 'répit', 'éprit'},
#  {'quarte', 'quater', 'quatre', 'traque'},
#  {'rainette', 'retenait', 'teintera', 'tenterai'},
#  {'rasait', 'ratais', 'tairas', 'tarais'},
#  {'raseur', 'rueras', 'rusera', 'saurer'},
#  {'rationnes', 'sonnerait', 'tisonnera', 'tonnerais'},
#  {'ratisser', 'sertiras', 'strieras', 'tarsiers'},
#  {'ratissiez', 'tarissiez', 'tirassiez', 'triassiez'},
#  {'ratissions', 'tarissions', 'tirassions', 'triassions'},
#  {'ravis', 'rivas', 'viras', 'vrais'},
#  {'ravisé', 'révisa', 'sévira', 'variés'},
#  {'redisant', 'teindras', 'tendrais', 'tiendras'},
#  {'reines', 'renies', 'serein', 'serine'},
#  {'reluit', 'rituel', 'rutile', 'treuil'},
#  {'rentier', 'retenir', 'terrien', 'terrine'},
#  {'reposant', 'retapons', 'saperont', 'taperons'},
#  {'reprisant', 'respirant', 'sprintera', 'transpire'},
#  {'ressaut', 'satures', 'saurets', 'surates'},
#  {'ressautait', 'statuaires', 'statuerais', 'tressautai'},
#  {'ressenti', 'retinsse', 'sentiers', 'ternisse'},
#  {'retentirai', 'retiraient', 'tireraient', 'trieraient'},
#  {'retirait', 'tirerait', 'titrerai', 'trierait'},
#  {'retirez', 'terriez', 'tirerez', 'trierez'},
#  {'retroussai', 'soustraire', 'soutireras', 'trousserai'},
#  {'revers', 'sevrer', 'verres', 'verser'},
#  {'revint', 'rivent', 'vernit', 'virent'},
#  {'riveté', 'rétive', 'vitrée', 'éviter'},
#  {'rivées', 'révise', 'virées', 'éviers'},
#  {'rosit', 'sorti', 'trios', 'trois'},
#  {'rouisse', 'roussie', 'souries', 'sursoie'},
#  {'rouisses', 'roussies', 'sourisse', 'sursoies'},
#  {'routines', 'sourient', 'soutenir', 'tuerions'},
#  {'rues', 'ruse', 'suer', 'user'},
#  {'saintes', 'satines', 'sentais', 'tisanes'},
#  {'sentait', 'taisent', 'teintas', 'tentais'},
#  {'sertiront', 'sortirent', 'strieront', 'titrerons'},
#  {'sertit', 'tirets', 'titres', 'triste'},
#  {'servent', 'sevrent', 'ventres', 'versent'},
#  {'serviez', 'sevriez', 'versiez', 'viserez'},
#  {'servions', 'sevrions', 'versions', 'viserons'},
#  {'situa', 'suait', 'tuais', 'usait'},
#  {'situera', 'suerait', 'tuerais', 'userait'},
#  {'siéraient', 'sériaient', 'éreintais', 'éternisai'},
#  {'striée', 'tirées', 'triées', 'étires'},
#  {'taire', 'tarie', 'tiare', 'traie'},
#  {'abaissent', 'absentais', 'abstenais'},
#  {'abasourdi', 'absoudrai', 'radoubais'},
#  {'abattraient', 'barattaient', 'rabattaient'},
#  {'abattrais', 'barattais', 'rabattais'},
#  {'abattrait', 'barattait', 'rabattait'},
#  {'abattre', 'baratte', 'rabatte'},
#  {'abattrez', 'barattez', 'rabattez'},
#  {'abattriez', 'barattiez', 'rabattiez'},
#  {'abattrions', 'barattions', 'rabattions'},
#  {'abattrons', 'barattons', 'rabattons'},
#  {'abattures', 'rabattues', 'tarabuste'},
#  {'abord', 'borda', 'broda'},
#  {'abordais', 'adsorbai', 'sabordai'},
#  {'abordas', 'adsorba', 'saborda'},
#  {'abordasses', 'adsorbasse', 'sabordasse'},
#  {'aborder', 'bordera', 'brodera'},
#  {'aborderais', 'adsorberai', 'saborderai'},
#  {'aborderas', 'adsorbera', 'sabordera'},
#  {'abordes', 'adsorbe', 'saborde'},
#  {'aboucher', 'bouchera', 'reboucha'},
#  {'aboutirent', 'broutaient', 'obturaient'},
#  {'abris', 'brisa', 'sabir'},
#  {'abritas', 'brasait', 'sabrait'},
#  {'abrutisses', 'bruitasses', 'subsistera'},
#  {'absolu', 'blousa', 'boulas'},
#  {'absoudre', 'bouderas', 'radoubes'},
#  {'abstiens', 'baissent', 'bassinet'},
#  {'abstrait', 'battrais', 'rabattis'},
#  {'accointer', 'accroient', 'concertai'},
#  {'accédas', 'cascadé', 'saccadé'},
#  {'accédasse', 'cascadées', 'saccadées'},
#  {'acier', 'carie', 'craie'},
#  {'aciérerons', 'nécroserai', 'écornerais'},
#  {'aciéreront', 'contrariée', 'écornerait'},
#  {'aconit', 'action', 'contai'},
#  {'aconits', 'actions', 'contais'},
#  {'acquerrions', 'conquerrais', 'craquerions'},
#  {'acquerrons', 'conquerras', 'craquerons'},
#  {'actionnaires', 'actionnerais', 'canoniserait'},
#  {'actionner', 'container', 'cornaient'},
#  {'actionnes', 'contenais', 'sectionna'},
#  {'administrée', 'démentirais', 'déterminais'},
#  {'admirées', 'remédias', 'réadmise'},
#  {'admirés', 'médiras', 'réadmis'},
#  {'admises', 'sadisme', 'samedis'},
#  {'adonner', 'donnera', 'redonna'},
#  {'adoucir', 'coudrai', 'radouci'},
#  {'adroit', 'dorait', 'rodait'},
#  {'adroites', 'doserait', 'doterais'},
#  {'affermir', 'affirmer', 'raffermi'},
#  {'affilais', 'affilias', 'falsifia'},
#  {'affilerais', 'affilieras', 'falsifiera'},
#  {'affilies', 'effilais', 'falsifie'},
#  {'affleurai', 'affluerai', 'faufilera'},
#  {'affleurais', 'affluerais', 'faufileras'},
#  {'affleure', 'effleura', 'farfelue'},
#  {'affleures', 'effleuras', 'farfelues'},
#  {'affleuriez', 'afflueriez', 'faufilerez'},
#  {'affleurions', 'affluerions', 'faufilerons'},
#  {'africaines', 'fascinerai', 'fiancerais'},
#  {'agencer', 'encager', 'encrage'},
#  {'agencerions', 'encagerions', 'engoncerais'},
#  {'agencerons', 'encagerons', 'engonceras'},
#  {'agents', 'gantes', 'stagne'},
#  {'agie', 'gaie', 'geai'},
#  {'agies', 'gaies', 'geais'},
#  {'agile', 'aigle', 'gelai'},
#  {'agissant', 'assignat', 'stagnais'},
#  {'agiter', 'tirage', 'triage'},
#  {'agiterons', 'organiste', 'songerait'},
#  {'agitée', 'gaieté', 'étiage'},
#  {'agitées', 'gaietés', 'étiages'},
#  {'agonies', 'agonise', 'songeai'},
#  {'agonir', 'ignora', 'rognai'},
#  {'agonises', 'angoisse', 'songeais'},
#  {'agraire', 'garerai', 'ragerai'},
#  {'agraires', 'garerais', 'ragerais'},
#  {'agrandie', 'daignera', 'drainage'},
#  {'agressant', 'garassent', 'stagneras'},
#  {'agressas', 'garasses', 'sargasse'},
#  {'agressé', 'gréasse', 'gérasse'},
#  {'agressés', 'gréasses', 'gérasses'},
#  {'agréerions', 'réorganise', 'égarerions'},
#  {'agréions', 'organisé', 'égarions'},
#  {'agrémente', 'égarement', 'émergeant'},
#  {'agréons', 'orangés', 'égarons'},
#  {'agréèrent', 'égarèrent', 'étrangère'},
#  {'aideront', 'doraient', 'rodaient'},
#  {'aiguilleront', 'grouillaient', 'guillotinera'},
#  {'ail', 'lai', 'lia'},
#  {'ailier', 'lierai', 'reliai'},
#  {'ailles', 'allies', 'sellai'},
#  {'aime', 'amie', 'maie'},
#  {'aiment', 'mainte', 'menait'},
#  {'aimer', 'maire', 'marie'},
#  {'air', 'ira', 'rai'},
#  {'aires', 'raies', 'serai'},
#  {'aises', 'essai', 'saies'},
#  {'ajoure', 'jouera', 'rejoua'},
#  {'ajoures', 'joueras', 'rejouas'},
#  {'ajuster', 'juteras', 'rajuste'},
#  {'alcaline', 'alliance', 'canaille'},
#  {'alcalines', 'alliances', 'canailles'},
#  {'alentour', 'relouant', 'roulante'},
#  {'alentours', 'roulantes', 'salueront'},
#  {'alertai', 'alitera', 'relatai'},
#  {'alertant', 'alternat', 'relatant'},
#  {'alertas', 'astrale', 'relatas'},
#  {'alerterions', 'relaterions', 'rentoileras'},
#  {'alertes', 'lestera', 'relates'},
#  {'alertiez', 'aliterez', 'relatiez'},
#  {'alertons', 'relatons', 'saleront'},
#  {'alerté', 'relaté', 'étaler'},
#  {'alevines', 'enlevais', 'vaseline'},
#  {'algérien', 'galérien', 'régalien'},
#  {'algériens', 'galériens', 'régaliens'},
#  {'alignera', 'glanerai', 'langerai'},
#  {'alignerez', 'glaneriez', 'langeriez'},
#  {'alignerons', 'glanerions', 'langerions'},
#  {'alignez', 'glaniez', 'langiez'},
#  {'alignons', 'glanions', 'langions'},
#  {'aligné', 'génial', 'inégal'},
#  {'alignée', 'géniale', 'inégale'},
#  {'alimenta', 'lamentai', 'matinale'},
#  {'alimentas', 'lamentais', 'matinales'},
#  {'alisiers', 'lisserai', 'relisais'},
#  {'alites', 'laites', 'lestai'},
#  {'alités', 'laités', 'lésait'},
#  {'allaient', 'entailla', 'tenailla'},
#  {'allaiter', 'retailla', 'taillera'},
#  {'alliaient', 'entaillai', 'tenaillai'},
#  {'alliassent', 'assaillent', 'saillantes'},
#  {'allier', 'raille', 'rallie'},
#  {'allieraient', 'entaillerai', 'tenaillerai'},
#  {'allierait', 'retaillai', 'taillerai'},
#  {'allégerais', 'légalisera', 'égailleras'},
#  {'alpe', 'lape', 'pela'},
#  {'alpes', 'lapes', 'pelas'},
#  {'alpin', 'lapin', 'plain'},
#  {'alpine', 'lapine', 'plaine'},
#  {'alpines', 'lapines', 'plaines'},
#  {'alpins', 'lapins', 'plains'},
#  {'altruisme', 'mutileras', 'stimulera'},
#  {'amarre', 'armera', 'ramera'},
#  {'amarres', 'armeras', 'rameras'},
#  {'ambrassent', 'bramassent', 'embrassant'},
#  {'ambrasses', 'bramasses', 'embrassas'},
#  {'ambrer', 'bramer', 'marbre'},
#  {'ambreras', 'brameras', 'embarras'},
#  {'ambrâtes', 'bramâtes', 'embrasât'},
#  {'ambrées', 'bramées', 'embrasé'},
#  {'amendions', 'amidonnes', 'mondaines'},
#  {'amenions', 'monnaies', 'onanisme'},
#  {'amerries', 'remaries', 'remisera'},
#  {'amerrira', 'arrimera', 'marrerai'},
#  {'amerriras', 'arrimeras', 'marrerais'},
#  {'amerrirez', 'arrimerez', 'marreriez'},
#  {'amerrirons', 'arrimerons', 'marrerions'},
#  {'amical', 'calmai', 'clamai'},
#  {'amidon', 'domina', 'mondai'},
#  {'aminés', 'animés', 'maniés'},
#  {'amis', 'mais', 'misa'},
#  {'amoindries', 'dominerais', 'modernisai'},
#  {'amollir', 'mollira', 'ramolli'},
#  {'amorties', 'atomiser', 'mortaise'},
#  {'amortirent', 'montrerait', 'remontrait'},
#  {'ample', 'lampe', 'palme'},
#  {'amples', 'lampes', 'palmes'},
#  {'américaines', 'américanise', 'mécaniserai'},
#  {'anarchiste', 'antichares', 'chanterais'},
#  {'ancrage', 'carnage', 'garance'},
#  {'ancrages', 'carnages', 'garances'},
#  {'ancrait', 'cariant', 'nacrait'},
#  {'ancrassent', 'encrassant', 'nacrassent'},
#  {'ancrasses', 'encrassas', 'nacrasses'},
#  {'ancrerai', 'nacrerai', 'ricanera'},
#  {'ancrerais', 'nacrerais', 'ricaneras'},
#  {'ancrerait', 'carraient', 'nacrerait'},
#  {'ancreriez', 'nacreriez', 'ricanerez'},
#  {'ancrerions', 'nacrerions', 'ricanerons'},
#  {'ancriez', 'nacriez', 'ricanez'},
#  {'ancrions', 'nacrions', 'ricanons'},
#  {'ancrâtes', 'casernât', 'nacrâtes'},
#  {'ancrée', 'carnée', 'nacrée'},
#  {'anges', 'ganse', 'nages'},
#  {'anglaise', 'lainages', 'langeais'},
#  {'angle', 'glane', 'lange'},
#  {'angliciser', 'cinglerais', 'clignerais'},
#  {'anglo', 'galon', 'lagon'},
#  {'angoisseras', 'organisasse', 'rageassions'},
#  {'animalier', 'laminaire', 'laminerai'},
#  {'animaliers', 'laminaires', 'laminerais'},
#  {'anime', 'manie', 'menai'},
#  {'animerai', 'manierai', 'remaniai'},
#  {'animeraient', 'manieraient', 'remaniaient'},
#  {'animerais', 'manierais', 'remaniais'},
#  {'animeriez', 'manieriez', 'remaniiez'},
#  {'animerions', 'manierions', 'remaniions'},
#  {'animeront', 'manieront', 'mitonnera'},
#  {'animée', 'anémie', 'maniée'},
#  {'annoncerait', 'canonnerait', 'cantonnerai'},
#  {'anodin', 'donnai', 'inonda'},
#  {'anodins', 'donnais', 'inondas'},
#  {'anti', 'nait', 'tain'},
#  {'antichambre', 'chambraient', 'embranchait'},
#  {'antidater', 'attendrai', 'tardaient'},
#  {'antillaise', 'entaillais', 'tenaillais'},
#  {'antiques', 'esquinta', 'taquines'},
#  {'antivol', 'violant', 'voilant'},
#  {'anuries', 'saunier', 'usinera'},
#  {'anvers', 'navres', 'nervas'},
#  {'apaiser', 'paieras', 'saperai'},
#  {'aplatir', 'parlait', 'partial'},
#  {'apostasier', 'aposterais', 'patoiseras'},
#  {'appareil', 'palperai', 'rappelai'},
#  {'appareiller', 'rappareille', 'rappellerai'},
#  {'appareils', 'palperais', 'rappelais'},
#  {'apparentais', 'appartenais', 'appesantira'},
#  {'apprise', 'papiers', 'piperas'},
#  {'aptes', 'pesta', 'tapes'},
#  {'aptère', 'arpète', 'patère'},
#  {'aptères', 'arpètes', 'patères'},
#  {'apure', 'parue', 'puera'},
#  {'apurer', 'parure', 'reparu'},
#  {'apuré', 'préau', 'épura'},
#  {'arables', 'blasera', 'sablera'},
#  {'araires', 'raieras', 'raserai'},
#  {'arcanes', 'caneras', 'caserna'},
#  {'archiva', 'avachir', 'chavira'},
#  {'ares', 'rase', 'sera'},
#  {'argon', 'orang', 'rogna'},
#  {'argots', 'gastro', 'ragots'},
#  {'arides', 'radies', 'raides'},
#  {'ariettes', 'esterait', 'testerai'},
#  {'armai', 'maria', 'ramai'},
#  {'armait', 'ramait', 'tramai'},
#  {'armasses', 'masseras', 'ramasses'},
#  {'armer', 'marre', 'ramer'},
#  {'armerait', 'ramerait', 'tramerai'},
#  {'armiez', 'mariez', 'ramiez'},
#  {'armons', 'ramons', 'romans'},
#  {'armée', 'marée', 'ramée'},
#  {'armées', 'marées', 'ramées'},
#  {'arpente', 'parente', 'paterne'},
#  {'arpenterai', 'pareraient', 'partenaire'},
#  {'arpentions', 'patinerons', 'pistonnera'},
#  {'arpentons', 'panseront', 'patronnes'},
#  {'arpenté', 'parenté', 'trépane'},
#  {'arqueront', 'quarteron', 'tronquera'},
#  {'arrachent', 'retrancha', 'tranchera'},
#  {'arrivaient', 'ravinerait', 'raviraient'},
#  {'arrivante', 'narrative', 'navrerait'},
#  {'arrivasse', 'asservira', 'raviseras'},
#  {'arriviste', 'servirait', 'vitrerais'},
#  {'arrivées', 'réservai', 'révisera'},
#  {'arrogent', 'gareront', 'rageront'},
#  {'arsouilles', 'rouillasse', 'souilleras'},
#  {'artifice', 'certifia', 'rectifia'},
#  {'artifices', 'certifias', 'rectifias'},
#  {'artimon', 'moirant', 'montrai'},
#  {'artimons', 'montrais', 'tramions'},
#  {'artisane', 'rasaient', 'satinera'},
#  {'artistes', 'titrasse', 'tressait'},
#  {'artésiens', 'intéressa', 'éternisas'},
#  {'ascension', 'canonises', 'connaisse'},
#  {'ascensions', 'connaisses', 'encaissons'},
#  {'aseptiser', 'pesterais', 'rapetisse'},
#  {'aseptisons', 'pointasses', 'potinasses'},
#  {'aseptisé', 'piétasse', 'tapissée'},
#  {'aseptisés', 'piétasses', 'tapissées'},
#  {'aspect', 'captes', 'pactes'},
#  {'aspira', 'parais', 'parias'},
#  {'aspirées', 'espérais', 'épissera'},
#  {'assaillirez', 'raillassiez', 'ralliassiez'},
#  {'assaillirons', 'raillassions', 'ralliassions'},
#  {'assainit', 'naissait', 'satinais'},
#  {'asseoir', 'essorai', 'oserais'},
#  {'assertions', 'essartions', 'tasserions'},
#  {'asseyent', 'essayent', 'seyantes'},
#  {'asseyons', 'essayons', 'noyasses'},
#  {'assigne', 'saignes', 'singeas'},
#  {'assignera', 'engraissa', 'saigneras'},
#  {'assignerai', 'engraissai', 'saignerais'},
#  {'assignerons', 'engraissons', 'grisonnasse'},
#  {'assimilent', 'latinismes', 'stalinisme'},
#  {'assista', 'sassait', 'tassais'},
#  {'assisteras', 'ratissasse', 'ressassait'},
#  {'assiéger', 'graissée', 'réagisse'},
#  {'assortie', 'essorait', 'toiseras'},
#  {'assortir', 'rassorti', 'sortiras'},
#  {'assoupi', 'poussai', 'soupais'},
#  {'assourdie', 'ressoudai', 'souderais'},
#  {'assurerait', 'restaurais', 'saturerais'},
#  {'assureront', 'restaurons', 'saturerons'},
#  {'assures', 'ruasses', 'rusasse'},
#  {'astreintes', 'ressentait', 'tressaient'},
#  {'astéries', 'ratissée', 'étirasse'},
#  {'astérisque', 'stéariques', 'séquestrai'},
#  {'atroce', 'cotera', 'croate'},
#  {'atteindre', 'attendrie', 'denterait'},
#  {'atteints', 'attisent', 'intestat'},
#  {'atterrais', 'attireras', 'traiteras'},
#  {'atterriez', 'attirerez', 'traiterez'},
#  {'atterrions', 'attirerons', 'traiterons'},
#  {'atterris', 'retraits', 'titreras'},
#  {'atterrisse', 'sarriettes', 'tresserait'},
#  {'attirai', 'tairait', 'traitai'},
#  {'attirance', 'encartait', 'tancerait'},
#  {'attirante', 'natterait', 'traitante'},
#  {'attireront', 'traiteront', 'trottinera'},
#  {'attirons', 'sirotant', 'traitons'},
#  {'attirée', 'traitée', 'téterai'},
#  {'attise', 'estait', 'testai'},
#  {'attractions', 'contrastait', 'tractations'},
#  {'attribues', 'butterais', 'tituberas'},
#  {'auges', 'sauge', 'usage'},
#  {'aurifient', 'enfuirait', 'fuiraient'},
#  {'auront', 'rouant', 'tourna'},
#  {'aussi', 'suais', 'usais'},
#  {'australie', 'saluerait', 'salutaire'},
#  {'australien', 'naturalise', 'neutralisa'},
#  {'australiens', 'naturalises', 'neutralisas'},
#  {'autorises', 'soustraie', 'tousserai'},
#  {'autos', 'touas', 'tousa'},
#  {'autriche', 'chuterai', 'rechutai'},
#  {'avaler', 'lavera', 'ravale'},
#  {'avals', 'lavas', 'valsa'},
#  {'avants', 'savant', 'vantas'},
#  {'avenus', 'naevus', 'neuvas'},
#  {'averties', 'estivera', 'savetier'},
#  {'avertir', 'verrait', 'vitrera'},
#  {'avides', 'devais', 'devisa'},
#  {'avidité', 'déviait', 'évidait'},
#  {'avirons', 'vairons', 'varions'},
#  {'avis', 'vais', 'visa'},
#  {'avons', 'novas', 'savon'},
#  {'avouer', 'oeuvra', 'vouera'},
#  {'avrils', 'livras', 'virals'},
#  {'aérolite', 'étiolera', 'étoilera'},
#  {'aérolites', 'étioleras', 'étoileras'},
#  {'badinerons', 'banderions', 'bidonneras'},
#  {'badinons', 'bandions', 'bidonnas'},
#  {'baierais', 'baiserai', 'biaisera'},
#  {'baieras', 'baisera', 'baserai'},
#  {'baierons', 'enrobais', 'snoberai'},
#  {'baignes', 'binages', 'esbigna'},
#  {'baisais', 'baissai', 'biaisas'},
#  {'baisas', 'baissa', 'basais'},
#  {'baiser', 'braies', 'braise'},
#  {'baiserais', 'baisserai', 'biaiseras'},
#  {'baiserions', 'bassinoire', 'biaiserons'},
#  {'baiserons', 'baserions', 'snoberais'},
#  {'baisons', 'basions', 'snobais'},
#  {'baisseras', 'braisasse', 'rabaisses'},
#  {'baisseront', 'brossaient', 'obstineras'},
#  {'balisas', 'blasais', 'sablais'},
#  {'baliseras', 'blaserais', 'sablerais'},
#  {'baliserez', 'blaseriez', 'sableriez'},
#  {'baliserons', 'blaserions', 'sablerions'},
#  {'balisez', 'blasiez', 'sabliez'},
#  {'balisons', 'blasions', 'sablions'},
#  {'balourde', 'doublera', 'redoubla'},
#  {'balourdes', 'doubleras', 'redoublas'},
#  {'balourdise', 'doublerais', 'redoublais'},
#  {'balsa', 'blasa', 'sabla'},
#  {'baltes', 'stable', 'tables'},
#  {'banaliserons', 'blasonnerais', 'raisonnables'},
#  {'banaliseront', 'blasonnerait', 'laborantines'},
#  {'banderait', 'bardaient', 'bradaient'},
#  {'baratines', 'brasaient', 'sabraient'},
#  {'barattent', 'rabattent', 'rebattant'},
#  {'baratter', 'rabattre', 'rebattra'},
#  {'barderions', 'braderions', 'rebondiras'},
#  {'bardions', 'bondiras', 'bradions'},
#  {'bardât', 'bradât', 'bâtard'},
#  {'bardâtes', 'bradâtes', 'bâtardes'},
#  {'barrisse', 'brasiers', 'briseras'},
#  {'baser', 'brase', 'sabre'},
#  {'baserons', 'bornasse', 'snoberas'},
#  {'basons', 'basson', 'snobas'},
#  {'batteur', 'buttera', 'rebattu'},
#  {'batteurs', 'butteras', 'rebattus'},
#  {'bisser', 'brises', 'sbires'},
#  {'blasaient', 'ensablait', 'sablaient'},
#  {'blasait', 'sablait', 'tablais'},
#  {'blaseraient', 'ensablerait', 'sableraient'},
#  {'blaserait', 'sablerait', 'tablerais'},
#  {'blaseront', 'sableront', 'tablerons'},
#  {'blases', 'blessa', 'sables'},
#  {'blasâmes', 'blâmasse', 'sablâmes'},
#  {'blasé', 'blésa', 'sablé'},
#  {'blasés', 'blésas', 'sablés'},
#  {'blousai', 'boulais', 'oublias'},
#  {'blousera', 'bouleras', 'laboures'},
#  {'blouserai', 'boulerais', 'oublieras'},
#  {'blousée', 'boulées', 'éboules'},
#  {'blutera', 'brutale', 'tableur'},
#  {'bluterais', 'brutalise', 'buraliste'},
#  {'bluteras', 'brutales', 'tableurs'},
#  {'boisent', 'obstine', 'obtiens'},
#  {'boisera', 'isobare', 'reboisa'},
#  {'boiserait', 'boiterais', 'reboisait'},
#  {'boitent', 'bottine', 'obtient'},
#  {'bordaient', 'brodaient', 'obtiendra'},
#  {'border', 'broder', 'rebord'},
#  {'bordée', 'brodée', 'dérobe'},
#  {'bore', 'orbe', 'robe'},
#  ...]
