# %% [markdown]
# # Lire des données d'un fichier texte

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
# iterating over an open file yields its lines, one by one

words = []
for line in open('francais.txt', 'r',  encoding='latin1'):
    words.append(line)

# %%
len(words)
# Out:
# 208916

# %%
words[:10]
# Out:
# ['\n',
#  'a\n',
#  'ab\n',
#  'abaissa\n',
#  'abaissai\n',
#  'abaissaient\n',
#  'abaissais\n',
#  'abaissait\n',
#  'abaissant\n',
#  'abaissas\n']

# %%
'abaissa\n'.strip()
# Out:
# 'abaissa'

# %%
'Abaissa\n'.strip().lower()
# Out:
# 'abaissa'

# %%
words = []
for line in open('francais.txt', 'r'):
    words.append(line.strip().lower())

# %%
words[:10]
# Out:
# ['',
#  'a',
#  'ab',
#  'abaissa',
#  'abaissai',
#  'abaissaient',
#  'abaissais',
#  'abaissait',
#  'abaissant',
#  'abaissas']

# %%
words = set()
for line in open('francais.txt', 'r'):
    words.add(line.strip().lower())

# %%
words
# Out:
# {'',
#  'touerai',
#  'ulcérèrent',
#  'tétraèdre',
#  'désenfleras',
#  'misanthrope',
#  'racolera',
#  'ressaisissais',
#  'outreras',
#  'déserteur',
#  'vaqueraient',
#  'magnétoscopes',
#  'comparussiez',
#  'culpabilité',
#  'replaçons',
#  'peignâmes',
#  'stabiliserions',
#  'rouvrir',
#  'poudreuses',
#  'badinage',
#  'consommâtes',
#  'dramatisassiez',
#  'chronométrassions',
#  'télégraphique',
#  'primauté',
#  'cheminerait',
#  'hérissât aspiré',
#  'bougeront',
#  'sevrerais',
#  'folioteraient',
#  'révérerai',
#  'cambriolera',
#  'classifiassent',
#  'pétassiez',
#  'trépanations',
#  'minimisé',
#  'cancaneriez',
#  'grattées',
#  'débordantes',
#  'patiemment',
#  'déjeuneriez',
#  'câblerons',
#  'tortue',
#  'dégazait',
#  'éduquasses',
#  'abdominales',
#  'détartré',
#  'abordait',
#  'empiétement',
#  'analyserais',
#  'cuivrerions',
#  'monacal',
#  'rouons',
#  'décrètent',
#  'insultais',
#  'proportion',
#  'prodiguassions',
#  'questionnent',
#  'brassons',
#  'garenne',
#  'entraînant',
#  'emménageas',
#  'réchampiriez',
#  'détromperont',
#  'avoisina',
#  'striâtes',
#  'supporta',
#  'fléchissions',
#  'cherchons',
#  'laissons',
#  'paressassent',
#  'titularisaient',
#  'scandalisais',
#  'dédoublai',
#  'déboulât',
#  'émersion',
#  'chattertons',
#  'festonnâmes',
#  'babilleriez',
#  'insolites',
#  'peinés',
#  'acheminassions',
#  'homologations',
#  'dévoyâtes',
#  'expertisions',
#  'invoquasses',
#  'parjurer',
#  'maintenir',
#  'brinquebalant',
#  'bobinés',
#  'diminuai',
#  'republieras',
#  'légitimerons',
#  'étiquetèrent',
#  'désintéressaient',
#  'ruons',
#  'furetaient',
#  'instrumentez',
#  'légitimées',
#  'téléphonâtes',
#  'infinitif',
#  'stupéfierons',
#  'zodiacales',
#  'méditeront',
#  'surplomberont',
#  'dînera',
#  'expurgeas',
#  'cirais',
#  'insurgeaient',
#  'petitement',
#  'réprimandèrent',
#  'bougonnai',
#  'distribuiez',
#  'dessillerai',
#  'intarissablement',
#  'fraîchis',
#  'interlude',
#  'renfrognaient',
#  'primevères',
#  'serpenterez',
#  'plébiscitée',
#  'calottent',
#  'pelletez',
#  'décennaux',
#  'empressassiez',
#  'grugions',
#  'trouilles',
#  'becquettes',
#  'vénalités',
#  'indemnisions',
#  'particulariserait',
#  'populeux',
#  'surexcitons',
#  'assoupies',
#  'imputassions',
#  'pronostiquerait',
#  'cabriolions',
#  'caressez',
#  'récolter',
#  'agréable',
#  'réabsorbera',
#  'regrettassent',
#  'connaîtrez',
#  'puritaines',
#  'métropolitaine',
#  'surélevât',
#  'verdirais',
#  'déshabitua',
#  'résolusses',
#  'convergents',
#  'manipulerais',
#  'bateleuses',
#  'gribouillèrent',
#  'interloqué',
#  'marrant',
#  'assermenté',
#  'exterminait',
#  'électrolysais',
#  'imprécision',
#  'ruât',
#  'bondes',
#  'radiographiera',
#  'tourbillonnas',
#  'picorerons',
#  'fauteront',
#  'entreposée',
#  'grené',
#  'déflorez',
#  'fricassés',
#  'officialiseront',
#  'ponçai',
#  'questionnait',
#  'béants',
#  'réaffirmions',
#  'feu',
#  'enfournerai',
#  'soupçonneront',
#  'assimilé',
#  'enserrées',
#  'fiançailles',
#  'cabanon',
#  'tramant',
#  'polka',
#  'soupirés',
#  'déposes',
#  'lilliputiennes',
#  'bachotaient',
#  'aptère',
#  'replâtrions',
#  'grimpais',
#  'défera',
#  'partitif',
#  'expérimentant',
#  'titille',
#  'sulfuraient',
#  'obligea',
#  'embouchions',
#  'corrigeaient',
#  'combinaient',
#  'purgez',
#  'expédiions',
#  'corrigeasse',
#  'léche',
#  'pactes',
#  'cerné',
#  'compilerez',
#  'prévenus',
#  'traduirai',
#  'fendais',
#  'limite',
#  'provigneras',
#  'restaurerait',
#  'subrogeassent',
#  'inhumes',
#  'étonnerai',
#  'maintînt',
#  'hissait aspiré',
#  'résorbassent',
#  'criaient',
#  'exciperaient',
#  'opérasses',
#  'symbole',
#  'complaisons',
#  'exaltions',
#  'vouvoieraient',
#  'désarçonnait',
#  'parfaisait',
#  'modèleriez',
#  'adultéreras',
#  'débandons',
#  'inspirera',
#  'émoussée',
#  'plantigrade',
#  'tiriez',
#  'bêtifiions',
#  'déculotteront',
#  'turbineriez',
#  'spécifia',
#  'improvisées',
#  'repli',
#  'simulesz',
#  'péagistes',
#  'tintinnabula',
#  'annonceraient',
#  'bisquerions',
#  'effriteraient',
#  'conclue',
#  'juxtaposition',
#  'retoucherais',
#  'vitellus',
#  'encocherai',
#  'moyenne',
#  'haïrons aspiré',
#  'nichassions',
#  'aggravée',
#  'capots',
#  'échancrée',
#  'éperdue',
#  'réarmassions',
#  'chipoterez',
#  'commodités',
#  'dénigrera',
#  'chétif',
#  'agences',
#  'absorba',
#  'cuisine',
#  'freina',
#  'incendiait',
#  'narvals',
#  'imbibasses',
#  'recommandaient',
#  'simili',
#  'éclusière',
#  'carapateriez',
#  'dénommasse',
#  'larigot',
#  'stationnas',
#  'encryptés',
#  'colportasse',
#  'zébras',
#  'béatifies',
#  'burinât',
#  'baratine',
#  'gelions',
#  'éjaculiez',
#  'éliderais',
#  'fomenterez',
#  'motus',
#  'polygamie',
#  'gloriettes',
#  'infiltrer',
#  'ambrées',
#  'écroulâtes',
#  'etc',
#  'occit',
#  'cambrée',
#  'affriola',
#  'musardassiez',
#  'défileraient',
#  'briquetât',
#  'maugréerions',
#  'javellisée',
#  'corderas',
#  'harnachai aspiré',
#  'palabrasses',
#  'affamerai',
#  'raccourcisses',
#  'spécialisera',
#  'parcellements',
#  'insurgeassiez',
#  'piétez',
#  'éprirent',
#  'évoluaient',
#  'déconnections',
#  'postulais',
#  'crouleront',
#  'inélégantes',
#  'songerions',
#  'dilatasses',
#  'louvoyèrent',
#  'piéride',
#  'aguichera',
#  'fourmillés',
#  'dissimuler',
#  'urémie',
#  'opossums',
#  'ratiociniez',
#  'concordataire',
#  'départagent',
#  'carguerai',
#  'charmassent',
#  'huppés aspiré',
#  'rembourrés',
#  'noirciraient',
#  'paillardises',
#  'repêchassent',
#  'colorant',
#  'cahotassent',
#  'affoleriez',
#  'grevas',
#  'empileraient',
#  'exhumasse',
#  'périclitât',
#  'dépeuplasses',
#  'foutront',
#  'métisserait',
#  'vautrassent',
#  'réticence',
#  'anesthésier',
#  'énucléâtes',
#  'hydrocution',
#  'rongent',
#  'répandrai',
#  'initierai',
#  'embobinait',
#  'darderai',
#  'pava',
#  'plâtrent',
#  'casait',
#  'regrettas',
#  'imputerais',
#  'paradis',
#  'déjeuneras',
#  'vivotions',
#  'sucrai',
#  'massera',
#  'hypertrophierions',
#  'endormît',
#  'neutraliserons',
#  'rentrasse',
#  'doucherait',
#  'manuel',
#  'montagneux',
#  'gaspilles',
#  'saumonés',
#  'étreinte',
#  'calcaire',
#  'dégivrez',
#  'équivoquons',
#  'nommas',
#  'échouasses',
#  'réorganisatrices',
#  'clamasses',
#  'irritâmes',
#  'attirerions',
#  'tapie',
#  'déployassiez',
#  'ingérence',
#  'cueilliez',
#  'perdues',
#  'affolantes',
#  'jargonnée',
#  'sommeillais',
#  'tituberions',
#  'arboretums',
#  'financerons',
#  'frôliez',
#  'découragez',
#  'héritèrent',
#  'audiovisuels',
#  'maîtrisera',
#  'fricassèrent',
#  'sériait',
#  'démilitarisée',
#  'décomposai',
#  'dessiniez',
#  'intolérant',
#  'tressaillirez',
#  'abrutirions',
#  'réfuterions',
#  'hétérodyne',
#  'épluchait',
#  'chapardèrent',
#  'raisonnablement',
#  'martial',
#  'coordonnait',
#  'cilice',
#  'expliqua',
#  'individuellement',
#  'rendissiez',
#  'rétrocède',
#  'abuserions',
#  'ostensibles',
#  'recroquevilleras',
#  'complimenteur',
#  'oxydons',
#  'pariétaires',
#  'irradiasses',
#  'tarons',
#  'multiples',
#  'cabochon',
#  'nimberons',
#  'patenta',
#  'démoralisateur',
#  'inamovibilité',
#  'lésinés',
#  'implantions',
#  'tavernières',
#  'baguenauderais',
#  'surintendants',
#  'rossai',
#  'teignisses',
#  'raccommoderas',
#  'râpiez',
#  'joindre',
#  'raccommodas',
#  'réverbérerons',
#  'sulfataient',
#  'music',
#  'intentionnées',
#  'effiliez',
#  'servirent',
#  'qualifiée',
#  'chahutais',
#  'décolorerait',
#  'lambineront',
#  'paralysé',
#  'goûtassions',
#  'daignez',
#  'enhardi',
#  'expédieriez',
#  'continuât',
#  'monothéistes',
#  'parlerait',
#  'tintinnabulerai',
#  'dédaigneriez',
#  'circoncisiez',
#  'captieuses',
#  'empoisonnante',
#  'saborderas',
#  'dénierai',
#  'traces',
#  'butions',
#  'tremblassiez',
#  'brocantés',
#  'conseillerai',
#  'insufflais',
#  'duperies',
#  'enrôles',
#  'cuisinées',
#  'illustrions',
#  'provoqueront',
#  'imposent',
#  'agrandis',
#  'originaire',
#  'péristaltiques',
#  'chômons',
#  'ratissas',
#  'revaudrais',
#  'inséminait',
#  'décanterai',
#  'calquèrent',
#  'dissipât',
#  'gourmandâtes',
#  'fabuler',
#  'trombine',
#  'hachât aspiré',
#  'sourcillera',
#  'suffoqua',
#  'rétribués',
#  'vulgarisasses',
#  'rompisse',
#  'clocherai',
#  'trinquerais',
#  'vidéos',
#  'enfantais',
#  'congestionniez',
#  'empesassent',
#  'piqueté',
#  'entrâinons',
#  'saoulât',
#  'expulsèrent',
#  'accusatrices',
#  'dessillai',
#  'fileta',
#  'pondéreriez',
#  'éclatiez',
#  'désabusés',
#  'éclipsiez',
#  'cligneras',
#  'débuta',
#  'noir',
#  'anthropométriques',
#  'chameaux',
#  'mesurer',
#  'parterre',
#  'organisatrices',
#  'bégaiera',
#  'retrancheraient',
#  'nourririons',
#  'persuadées',
#  'rétorquèrent',
#  'sautillée',
#  'étuvâtes',
#  'mobilisassent',
#  'croisses',
#  'sommeillâtes',
#  'empaquetait',
#  'endormiras',
#  'aboi',
#  'déblaiement',
#  'hanse aspiré',
#  'solfierai',
#  'exhaussa',
#  'terrorisaient',
#  'luxé',
#  'surnommasse',
#  'nasillées',
#  'désemparâmes',
#  'surchargeât',
#  'attroupent',
#  'normaliseraient',
#  'expérimentaux',
#  'forets instrument',
#  'finançait',
#  'plombasse',
#  'recollions',
#  'estourbissant',
#  'matinales',
#  'supplicias',
#  'taraudages',
#  'tuméfiait',
#  'poussières',
#  'totems',
#  'bouchonne',
#  'dévoile',
#  'grasseyions',
#  'pavanent',
#  'carences',
#  'bivouaquer',
#  'becquetai',
#  'envolassiez',
#  'hébergeait',
#  'rincerait',
#  'beuglerait',
#  'clôturèrent',
#  'vibreras',
#  'militassent',
#  'démunit',
#  'gigoteraient',
#  'prédictions',
#  'délibérant',
#  'empanacherez',
#  'torréfient',
#  'ésotérique',
#  'flairerais',
#  'illimitée',
#  'aduleriez',
#  'patiente',
#  'obséder',
#  'blottit',
#  'fusionnerions',
#  'frictionnerais',
#  'déteriorâmes',
#  'répandît',
#  'rôdeur',
#  'salopâmes',
#  'cassures',
#  'encollais',
#  'engendrée',
#  'languira',
#  'étalonnage',
#  'intervertirait',
#  'éponyme',
#  'engueule',
#  'oxydées',
#  'égoutiers',
#  'fauta',
#  'tonnerais',
#  'réorganisa',
#  'supplanteront',
#  'blettissait',
#  'amaigrît',
#  'amenuisons',
#  'émondaient',
#  'pilotera',
#  'limitâtes',
#  'infortunées',
#  'confédérant',
#  'hispanisantes',
#  'pourvoyeuse',
#  'lotirons',
#  'réarmements',
#  'dépaquetâtes',
#  'chialassent',
#  'alternons',
#  'calcium',
#  'déculottèrent',
#  'débandent',
#  'papillonnasse',
#  'fusèrent',
#  'ramasserais',
#  'alerterait',
#  'concernèrent',
#  'transmuables',
#  'fractionnerez',
#  'vendettas',
#  'incombassions',
#  'fêleras',
#  'verbiage',
#  'démasquez',
#  'délibérasse',
#  'invoqua',
#  'carabinés',
#  'légiféras',
#  'renégat',
#  'éjectons',
#  'jasasse',
#  'exhuma',
#  'extorquer',
#  'motiveront',
#  'rapatriions',
#  'décatîtes',
#  'guignerions',
#  'fracassent',
#  'mastiqués',
#  'bouffiriez',
#  'ragaillardis',
#  'rendit',
#  'assignions',
#  'distrais',
#  'partis',
#  'déterminatifs',
#  'piquetions',
#  'rattrapés',
#  'recrachiez',
#  'viendrait',
#  'illettré',
#  'gouttait',
#  'préfigurassiez',
#  'approprieront',
#  'tariront',
#  'bêcherions',
#  'astronomique',
#  'équivalut',
#  'assomment',
#  'embarquâtes',
#  'effondrai',
#  'répéteras',
#  'catapulteront',
#  'pleurnichassent',
#  'réaffirmerait',
#  'tutoieriez',
#  'légitimions',
#  'pondéra',
#  'haubaneraient aspiré',
#  'gobait',
#  'nazis',
#  'testerais',
#  'oeillère',
#  'dandinions',
#  'tintinnabulassions',
#  'dérouillait',
#  'indifférent',
#  'pourchassa',
#  'valorisasse',
#  'rectiligne',
#  'forerait',
#  'méritions',
#  'chaulé',
#  'lingerie',
#  'baba',
#  'reniflâmes',
#  'obérerions',
#  'rabibochassions',
#  'intriguèrent',
#  'casino',
#  'berçait',
#  'obéîmes',
#  'convive',
#  'tasserez',
#  'détecterons',
#  'prépareront',
#  'ombraient',
#  'coagules',
#  'collectait',
#  'irak',
#  'ravigotâmes',
#  'dépasseront',
#  'soupirer',
#  'fondeur',
#  'scolarisez',
#  'intermède',
#  'maillé',
#  'gémirait',
#  'déboussoliez',
#  'acceptai',
#  'hétéro',
#  'masque',
#  'caquettent',
#  'taira',
#  'grognait',
#  'ressasser',
#  'ambrâtes',
#  'provinssions',
#  'carapateront',
#  'bichonnât',
#  'détalassions',
#  'tonifiera',
#  'cime',
#  'ras',
#  'entichais',
#  'faste',
#  'tordions',
#  'gondolé',
#  'vociféreriez',
#  'récriminer',
#  'abêtisses',
#  'gaspillât',
#  'garantissent',
#  'relançais',
#  'usurpai',
#  'rosissons',
#  'attachions',
#  'commissionneriez',
#  'jalouserai',
#  'estompassent',
#  'éveille',
#  'nécrosâmes',
#  'pendillaient',
#  'tarifer',
#  'dactylo',
#  'colporté',
#  'enlisé',
#  'mentonnet',
#  'insubordinations',
#  'fléchiront',
#  'réglementèrent',
#  'honorant',
#  'avantagea',
#  'récitasses',
#  'juché',
#  'provoquasse',
#  'encaissasse',
#  'déférait',
#  'cémenterais',
#  'javelots',
#  'ressuscitâmes',
#  'aiguillera',
#  'parcourussent',
#  'expireriez',
#  'brutalisèrent',
#  'espionnera',
#  'sardoniques',
#  'déménageassiez',
#  'fréquenté',
#  'démunissais',
#  'forciriez',
#  'moudrai',
#  'prévoiriez',
#  'chétifs',
#  'enseigneraient',
#  'cruelles',
#  'prospectais',
#  'essartasses',
#  'légalisâtez',
#  'caillait',
#  'éclatai',
#  'marnant',
#  'colorierai',
#  'licenciements',
#  'métropolites',
#  'braillent',
#  'sautillantes',
#  'énervaient',
#  'immobiliseront',
#  'remémoraient',
#  'cognait',
#  'racoleur',
#  'profiteur',
#  'confronterons',
#  'peinturer',
#  'résonner',
#  'fabulasse',
#  'regonflas',
#  'coupoles',
#  'crochetteras',
#  'accélères',
#  'grincheuse',
#  'requîtes',
#  'grésilles',
#  'réveillonné',
#  'désenclaviez',
#  'rayaient',
#  'ajourai',
#  'étatisât',
#  'polluez',
#  'gagerai',
#  'mélangeait',
#  'occire',
#  'activations',
#  'révéré',
#  'nourricières',
#  'interloqueriez',
#  'exultasses',
#  'lubrifiassions',
#  'désarçonnez',
#  'redemandent',
#  'éprouvée',
#  'cravacherons',
#  'repentirez',
#  'blousant',
#  'associative',
#  'ressautant',
#  'jalousasses',
#  'brabonçonnes',
#  'dégainât',
#  'enrobiez',
#  'pochassent',
#  'censurée',
#  'mûrirons',
#  'parachuterions',
#  'fustigées',
#  'cassé',
#  'inquiéteras',
#  'fabriquer',
#  'gaulas',
#  'maraudeur',
#  'rechignés',
#  'snoberaient',
#  'maculais',
#  'abrégeas',
#  'effets',
#  'gagnées',
#  'obsédassiez',
#  'talonnées',
#  'taisais',
#  'menaçâtes',
#  'furetions',
#  'o',
#  'maraudeuse',
#  'regarderait',
#  'accidentés',
#  'ruâmes',
#  'terrait',
#  'existerait',
#  'arborés',
#  'oscultaient',
#  'surimposâmes',
#  'remportâtes',
#  'désapprouvaient',
#  'astreindrons',
#  'déclassaient',
#  'fermenterais',
#  'conteniez',
#  'bénissiez',
#  'régaliez',
#  'adhéra',
#  'splendidement',
#  'posséderions',
#  'abri',
#  'retombiez',
#  'ébrasais',
#  'juxtaposerais',
#  'soupçonnée',
#  'décime',
#  'sains',
#  'réchauffèrent',
#  'angoissassiez',
#  'blutant',
#  'cabriolant',
#  'engouent',
#  'mûris',
#  'appariâmes',
#  'préméditant',
#  'sauvegardiez',
#  'vocaliseront',
#  'alphabétisassent',
#  'poires',
#  'recrachassiez',
#  'topait',
#  'dévalise',
#  'entichâmes',
#  'abstenue',
#  'exciperai',
#  'calcinions',
#  'envisageons',
#  'dénommées',
#  'spirochètes',
#  'élidas',
#  'chantre',
#  'accouda',
#  'jalonneriez',
#  'enrhumeras',
#  'rubéfions',
#  'incarcérai',
#  'régentât',
#  'correspondrait',
#  'cède',
#  'échalassèrent',
#  'embardée',
#  'faussâtes',
#  'disqualifiâtes',
#  'filèterais',
#  'sérièrent',
#  'vénérienne',
#  'accablement',
#  'balancier',
#  'bosselassions',
#  'couronnais',
#  'patinait',
#  'sécrétait',
#  'dégazeriez',
#  'morcellerais',
#  'allouerait',
#  'voilèrent',
#  'assoiront',
#  'métissages',
#  'verbalisé',
#  'cécité',
#  'échoues',
#  'démembrée',
#  'nimberait',
#  'électrochocs',
#  'terrien',
#  'agencerait',
#  'atone',
#  'scolariseront',
#  'insensibles',
#  'claironnant',
#  'détordre',
#  'grandirent',
#  'hydrate',
#  'contrebalançassent',
#  'verrouillages',
#  'domptasse',
#  'ovalisassions',
#  'décapsulons',
#  'arbitrerai',
#  'enlacerons',
#  'bâcheraient',
#  'décapole',
#  'anticonceptionnelles',
#  'comportant',
#  'dégorgeas',
#  'honorassent',
#  'arrondissiez',
#  'maïs',
#  'claironnerons',
#  'cintrer',
#  'avivasses',
#  'déchiffrerions',
#  'démoralisasse',
#  'graviraient',
#  'rapparier',
#  'alevin',
#  'stipendiaient',
#  'démontât',
#  'authentifierai',
#  'automnaux',
#  'méfiai',
#  'balsamiques',
#  'poltronneries',
#  'putes',
#  'oppressiez',
#  'viriez',
#  'abrégée',
#  'distancerai',
#  'exportez',
#  'hésitât',
#  ...}

# %%
# a set comprehension that collects stripped and lowercased lines...
words = {line.strip().lower() for line in open('francais.txt', 'r')}

# %%
words
# Out:
# {'',
#  'touerai',
#  'ulcérèrent',
#  'tétraèdre',
#  'désenfleras',
#  'misanthrope',
#  'racolera',
#  'ressaisissais',
#  'outreras',
#  'déserteur',
#  'vaqueraient',
#  'magnétoscopes',
#  'comparussiez',
#  'culpabilité',
#  'replaçons',
#  'peignâmes',
#  'stabiliserions',
#  'rouvrir',
#  'poudreuses',
#  'badinage',
#  'consommâtes',
#  'dramatisassiez',
#  'chronométrassions',
#  'télégraphique',
#  'primauté',
#  'cheminerait',
#  'hérissât aspiré',
#  'bougeront',
#  'sevrerais',
#  'folioteraient',
#  'révérerai',
#  'cambriolera',
#  'classifiassent',
#  'pétassiez',
#  'trépanations',
#  'minimisé',
#  'cancaneriez',
#  'grattées',
#  'débordantes',
#  'patiemment',
#  'déjeuneriez',
#  'câblerons',
#  'tortue',
#  'dégazait',
#  'éduquasses',
#  'abdominales',
#  'détartré',
#  'abordait',
#  'empiétement',
#  'analyserais',
#  'cuivrerions',
#  'monacal',
#  'rouons',
#  'décrètent',
#  'insultais',
#  'proportion',
#  'prodiguassions',
#  'questionnent',
#  'brassons',
#  'garenne',
#  'entraînant',
#  'emménageas',
#  'réchampiriez',
#  'détromperont',
#  'avoisina',
#  'striâtes',
#  'supporta',
#  'fléchissions',
#  'cherchons',
#  'laissons',
#  'paressassent',
#  'titularisaient',
#  'scandalisais',
#  'dédoublai',
#  'déboulât',
#  'émersion',
#  'chattertons',
#  'festonnâmes',
#  'babilleriez',
#  'insolites',
#  'peinés',
#  'acheminassions',
#  'homologations',
#  'dévoyâtes',
#  'expertisions',
#  'invoquasses',
#  'parjurer',
#  'maintenir',
#  'brinquebalant',
#  'bobinés',
#  'diminuai',
#  'republieras',
#  'légitimerons',
#  'étiquetèrent',
#  'désintéressaient',
#  'ruons',
#  'furetaient',
#  'instrumentez',
#  'légitimées',
#  'téléphonâtes',
#  'infinitif',
#  'stupéfierons',
#  'zodiacales',
#  'méditeront',
#  'surplomberont',
#  'dînera',
#  'expurgeas',
#  'cirais',
#  'insurgeaient',
#  'petitement',
#  'réprimandèrent',
#  'bougonnai',
#  'distribuiez',
#  'dessillerai',
#  'intarissablement',
#  'fraîchis',
#  'interlude',
#  'renfrognaient',
#  'primevères',
#  'serpenterez',
#  'plébiscitée',
#  'calottent',
#  'pelletez',
#  'décennaux',
#  'empressassiez',
#  'grugions',
#  'trouilles',
#  'becquettes',
#  'vénalités',
#  'indemnisions',
#  'particulariserait',
#  'populeux',
#  'surexcitons',
#  'assoupies',
#  'imputassions',
#  'pronostiquerait',
#  'cabriolions',
#  'caressez',
#  'récolter',
#  'agréable',
#  'réabsorbera',
#  'regrettassent',
#  'connaîtrez',
#  'puritaines',
#  'métropolitaine',
#  'surélevât',
#  'verdirais',
#  'déshabitua',
#  'résolusses',
#  'convergents',
#  'manipulerais',
#  'bateleuses',
#  'gribouillèrent',
#  'interloqué',
#  'marrant',
#  'assermenté',
#  'exterminait',
#  'électrolysais',
#  'imprécision',
#  'ruât',
#  'bondes',
#  'radiographiera',
#  'tourbillonnas',
#  'picorerons',
#  'fauteront',
#  'entreposée',
#  'grené',
#  'déflorez',
#  'fricassés',
#  'officialiseront',
#  'ponçai',
#  'questionnait',
#  'béants',
#  'réaffirmions',
#  'feu',
#  'enfournerai',
#  'soupçonneront',
#  'assimilé',
#  'enserrées',
#  'fiançailles',
#  'cabanon',
#  'tramant',
#  'polka',
#  'soupirés',
#  'déposes',
#  'lilliputiennes',
#  'bachotaient',
#  'aptère',
#  'replâtrions',
#  'grimpais',
#  'défera',
#  'partitif',
#  'expérimentant',
#  'titille',
#  'sulfuraient',
#  'obligea',
#  'embouchions',
#  'corrigeaient',
#  'combinaient',
#  'purgez',
#  'expédiions',
#  'corrigeasse',
#  'léche',
#  'pactes',
#  'cerné',
#  'compilerez',
#  'prévenus',
#  'traduirai',
#  'fendais',
#  'limite',
#  'provigneras',
#  'restaurerait',
#  'subrogeassent',
#  'inhumes',
#  'étonnerai',
#  'maintînt',
#  'hissait aspiré',
#  'résorbassent',
#  'criaient',
#  'exciperaient',
#  'opérasses',
#  'symbole',
#  'complaisons',
#  'exaltions',
#  'vouvoieraient',
#  'désarçonnait',
#  'parfaisait',
#  'modèleriez',
#  'adultéreras',
#  'débandons',
#  'inspirera',
#  'émoussée',
#  'plantigrade',
#  'tiriez',
#  'bêtifiions',
#  'déculotteront',
#  'turbineriez',
#  'spécifia',
#  'improvisées',
#  'repli',
#  'simulesz',
#  'péagistes',
#  'tintinnabula',
#  'annonceraient',
#  'bisquerions',
#  'effriteraient',
#  'conclue',
#  'juxtaposition',
#  'retoucherais',
#  'vitellus',
#  'encocherai',
#  'moyenne',
#  'haïrons aspiré',
#  'nichassions',
#  'aggravée',
#  'capots',
#  'échancrée',
#  'éperdue',
#  'réarmassions',
#  'chipoterez',
#  'commodités',
#  'dénigrera',
#  'chétif',
#  'agences',
#  'absorba',
#  'cuisine',
#  'freina',
#  'incendiait',
#  'narvals',
#  'imbibasses',
#  'recommandaient',
#  'simili',
#  'éclusière',
#  'carapateriez',
#  'dénommasse',
#  'larigot',
#  'stationnas',
#  'encryptés',
#  'colportasse',
#  'zébras',
#  'béatifies',
#  'burinât',
#  'baratine',
#  'gelions',
#  'éjaculiez',
#  'éliderais',
#  'fomenterez',
#  'motus',
#  'polygamie',
#  'gloriettes',
#  'infiltrer',
#  'ambrées',
#  'écroulâtes',
#  'etc',
#  'occit',
#  'cambrée',
#  'affriola',
#  'musardassiez',
#  'défileraient',
#  'briquetât',
#  'maugréerions',
#  'javellisée',
#  'corderas',
#  'harnachai aspiré',
#  'palabrasses',
#  'affamerai',
#  'raccourcisses',
#  'spécialisera',
#  'parcellements',
#  'insurgeassiez',
#  'piétez',
#  'éprirent',
#  'évoluaient',
#  'déconnections',
#  'postulais',
#  'crouleront',
#  'inélégantes',
#  'songerions',
#  'dilatasses',
#  'louvoyèrent',
#  'piéride',
#  'aguichera',
#  'fourmillés',
#  'dissimuler',
#  'urémie',
#  'opossums',
#  'ratiociniez',
#  'concordataire',
#  'départagent',
#  'carguerai',
#  'charmassent',
#  'huppés aspiré',
#  'rembourrés',
#  'noirciraient',
#  'paillardises',
#  'repêchassent',
#  'colorant',
#  'cahotassent',
#  'affoleriez',
#  'grevas',
#  'empileraient',
#  'exhumasse',
#  'périclitât',
#  'dépeuplasses',
#  'foutront',
#  'métisserait',
#  'vautrassent',
#  'réticence',
#  'anesthésier',
#  'énucléâtes',
#  'hydrocution',
#  'rongent',
#  'répandrai',
#  'initierai',
#  'embobinait',
#  'darderai',
#  'pava',
#  'plâtrent',
#  'casait',
#  'regrettas',
#  'imputerais',
#  'paradis',
#  'déjeuneras',
#  'vivotions',
#  'sucrai',
#  'massera',
#  'hypertrophierions',
#  'endormît',
#  'neutraliserons',
#  'rentrasse',
#  'doucherait',
#  'manuel',
#  'montagneux',
#  'gaspilles',
#  'saumonés',
#  'étreinte',
#  'calcaire',
#  'dégivrez',
#  'équivoquons',
#  'nommas',
#  'échouasses',
#  'réorganisatrices',
#  'clamasses',
#  'irritâmes',
#  'attirerions',
#  'tapie',
#  'déployassiez',
#  'ingérence',
#  'cueilliez',
#  'perdues',
#  'affolantes',
#  'jargonnée',
#  'sommeillais',
#  'tituberions',
#  'arboretums',
#  'financerons',
#  'frôliez',
#  'découragez',
#  'héritèrent',
#  'audiovisuels',
#  'maîtrisera',
#  'fricassèrent',
#  'sériait',
#  'démilitarisée',
#  'décomposai',
#  'dessiniez',
#  'intolérant',
#  'tressaillirez',
#  'abrutirions',
#  'réfuterions',
#  'hétérodyne',
#  'épluchait',
#  'chapardèrent',
#  'raisonnablement',
#  'martial',
#  'coordonnait',
#  'cilice',
#  'expliqua',
#  'individuellement',
#  'rendissiez',
#  'rétrocède',
#  'abuserions',
#  'ostensibles',
#  'recroquevilleras',
#  'complimenteur',
#  'oxydons',
#  'pariétaires',
#  'irradiasses',
#  'tarons',
#  'multiples',
#  'cabochon',
#  'nimberons',
#  'patenta',
#  'démoralisateur',
#  'inamovibilité',
#  'lésinés',
#  'implantions',
#  'tavernières',
#  'baguenauderais',
#  'surintendants',
#  'rossai',
#  'teignisses',
#  'raccommoderas',
#  'râpiez',
#  'joindre',
#  'raccommodas',
#  'réverbérerons',
#  'sulfataient',
#  'music',
#  'intentionnées',
#  'effiliez',
#  'servirent',
#  'qualifiée',
#  'chahutais',
#  'décolorerait',
#  'lambineront',
#  'paralysé',
#  'goûtassions',
#  'daignez',
#  'enhardi',
#  'expédieriez',
#  'continuât',
#  'monothéistes',
#  'parlerait',
#  'tintinnabulerai',
#  'dédaigneriez',
#  'circoncisiez',
#  'captieuses',
#  'empoisonnante',
#  'saborderas',
#  'dénierai',
#  'traces',
#  'butions',
#  'tremblassiez',
#  'brocantés',
#  'conseillerai',
#  'insufflais',
#  'duperies',
#  'enrôles',
#  'cuisinées',
#  'illustrions',
#  'provoqueront',
#  'imposent',
#  'agrandis',
#  'originaire',
#  'péristaltiques',
#  'chômons',
#  'ratissas',
#  'revaudrais',
#  'inséminait',
#  'décanterai',
#  'calquèrent',
#  'dissipât',
#  'gourmandâtes',
#  'fabuler',
#  'trombine',
#  'hachât aspiré',
#  'sourcillera',
#  'suffoqua',
#  'rétribués',
#  'vulgarisasses',
#  'rompisse',
#  'clocherai',
#  'trinquerais',
#  'vidéos',
#  'enfantais',
#  'congestionniez',
#  'empesassent',
#  'piqueté',
#  'entrâinons',
#  'saoulât',
#  'expulsèrent',
#  'accusatrices',
#  'dessillai',
#  'fileta',
#  'pondéreriez',
#  'éclatiez',
#  'désabusés',
#  'éclipsiez',
#  'cligneras',
#  'débuta',
#  'noir',
#  'anthropométriques',
#  'chameaux',
#  'mesurer',
#  'parterre',
#  'organisatrices',
#  'bégaiera',
#  'retrancheraient',
#  'nourririons',
#  'persuadées',
#  'rétorquèrent',
#  'sautillée',
#  'étuvâtes',
#  'mobilisassent',
#  'croisses',
#  'sommeillâtes',
#  'empaquetait',
#  'endormiras',
#  'aboi',
#  'déblaiement',
#  'hanse aspiré',
#  'solfierai',
#  'exhaussa',
#  'terrorisaient',
#  'luxé',
#  'surnommasse',
#  'nasillées',
#  'désemparâmes',
#  'surchargeât',
#  'attroupent',
#  'normaliseraient',
#  'expérimentaux',
#  'forets instrument',
#  'finançait',
#  'plombasse',
#  'recollions',
#  'estourbissant',
#  'matinales',
#  'supplicias',
#  'taraudages',
#  'tuméfiait',
#  'poussières',
#  'totems',
#  'bouchonne',
#  'dévoile',
#  'grasseyions',
#  'pavanent',
#  'carences',
#  'bivouaquer',
#  'becquetai',
#  'envolassiez',
#  'hébergeait',
#  'rincerait',
#  'beuglerait',
#  'clôturèrent',
#  'vibreras',
#  'militassent',
#  'démunit',
#  'gigoteraient',
#  'prédictions',
#  'délibérant',
#  'empanacherez',
#  'torréfient',
#  'ésotérique',
#  'flairerais',
#  'illimitée',
#  'aduleriez',
#  'patiente',
#  'obséder',
#  'blottit',
#  'fusionnerions',
#  'frictionnerais',
#  'déteriorâmes',
#  'répandît',
#  'rôdeur',
#  'salopâmes',
#  'cassures',
#  'encollais',
#  'engendrée',
#  'languira',
#  'étalonnage',
#  'intervertirait',
#  'éponyme',
#  'engueule',
#  'oxydées',
#  'égoutiers',
#  'fauta',
#  'tonnerais',
#  'réorganisa',
#  'supplanteront',
#  'blettissait',
#  'amaigrît',
#  'amenuisons',
#  'émondaient',
#  'pilotera',
#  'limitâtes',
#  'infortunées',
#  'confédérant',
#  'hispanisantes',
#  'pourvoyeuse',
#  'lotirons',
#  'réarmements',
#  'dépaquetâtes',
#  'chialassent',
#  'alternons',
#  'calcium',
#  'déculottèrent',
#  'débandent',
#  'papillonnasse',
#  'fusèrent',
#  'ramasserais',
#  'alerterait',
#  'concernèrent',
#  'transmuables',
#  'fractionnerez',
#  'vendettas',
#  'incombassions',
#  'fêleras',
#  'verbiage',
#  'démasquez',
#  'délibérasse',
#  'invoqua',
#  'carabinés',
#  'légiféras',
#  'renégat',
#  'éjectons',
#  'jasasse',
#  'exhuma',
#  'extorquer',
#  'motiveront',
#  'rapatriions',
#  'décatîtes',
#  'guignerions',
#  'fracassent',
#  'mastiqués',
#  'bouffiriez',
#  'ragaillardis',
#  'rendit',
#  'assignions',
#  'distrais',
#  'partis',
#  'déterminatifs',
#  'piquetions',
#  'rattrapés',
#  'recrachiez',
#  'viendrait',
#  'illettré',
#  'gouttait',
#  'préfigurassiez',
#  'approprieront',
#  'tariront',
#  'bêcherions',
#  'astronomique',
#  'équivalut',
#  'assomment',
#  'embarquâtes',
#  'effondrai',
#  'répéteras',
#  'catapulteront',
#  'pleurnichassent',
#  'réaffirmerait',
#  'tutoieriez',
#  'légitimions',
#  'pondéra',
#  'haubaneraient aspiré',
#  'gobait',
#  'nazis',
#  'testerais',
#  'oeillère',
#  'dandinions',
#  'tintinnabulassions',
#  'dérouillait',
#  'indifférent',
#  'pourchassa',
#  'valorisasse',
#  'rectiligne',
#  'forerait',
#  'méritions',
#  'chaulé',
#  'lingerie',
#  'baba',
#  'reniflâmes',
#  'obérerions',
#  'rabibochassions',
#  'intriguèrent',
#  'casino',
#  'berçait',
#  'obéîmes',
#  'convive',
#  'tasserez',
#  'détecterons',
#  'prépareront',
#  'ombraient',
#  'coagules',
#  'collectait',
#  'irak',
#  'ravigotâmes',
#  'dépasseront',
#  'soupirer',
#  'fondeur',
#  'scolarisez',
#  'intermède',
#  'maillé',
#  'gémirait',
#  'déboussoliez',
#  'acceptai',
#  'hétéro',
#  'masque',
#  'caquettent',
#  'taira',
#  'grognait',
#  'ressasser',
#  'ambrâtes',
#  'provinssions',
#  'carapateront',
#  'bichonnât',
#  'détalassions',
#  'tonifiera',
#  'cime',
#  'ras',
#  'entichais',
#  'faste',
#  'tordions',
#  'gondolé',
#  'vociféreriez',
#  'récriminer',
#  'abêtisses',
#  'gaspillât',
#  'garantissent',
#  'relançais',
#  'usurpai',
#  'rosissons',
#  'attachions',
#  'commissionneriez',
#  'jalouserai',
#  'estompassent',
#  'éveille',
#  'nécrosâmes',
#  'pendillaient',
#  'tarifer',
#  'dactylo',
#  'colporté',
#  'enlisé',
#  'mentonnet',
#  'insubordinations',
#  'fléchiront',
#  'réglementèrent',
#  'honorant',
#  'avantagea',
#  'récitasses',
#  'juché',
#  'provoquasse',
#  'encaissasse',
#  'déférait',
#  'cémenterais',
#  'javelots',
#  'ressuscitâmes',
#  'aiguillera',
#  'parcourussent',
#  'expireriez',
#  'brutalisèrent',
#  'espionnera',
#  'sardoniques',
#  'déménageassiez',
#  'fréquenté',
#  'démunissais',
#  'forciriez',
#  'moudrai',
#  'prévoiriez',
#  'chétifs',
#  'enseigneraient',
#  'cruelles',
#  'prospectais',
#  'essartasses',
#  'légalisâtez',
#  'caillait',
#  'éclatai',
#  'marnant',
#  'colorierai',
#  'licenciements',
#  'métropolites',
#  'braillent',
#  'sautillantes',
#  'énervaient',
#  'immobiliseront',
#  'remémoraient',
#  'cognait',
#  'racoleur',
#  'profiteur',
#  'confronterons',
#  'peinturer',
#  'résonner',
#  'fabulasse',
#  'regonflas',
#  'coupoles',
#  'crochetteras',
#  'accélères',
#  'grincheuse',
#  'requîtes',
#  'grésilles',
#  'réveillonné',
#  'désenclaviez',
#  'rayaient',
#  'ajourai',
#  'étatisât',
#  'polluez',
#  'gagerai',
#  'mélangeait',
#  'occire',
#  'activations',
#  'révéré',
#  'nourricières',
#  'interloqueriez',
#  'exultasses',
#  'lubrifiassions',
#  'désarçonnez',
#  'redemandent',
#  'éprouvée',
#  'cravacherons',
#  'repentirez',
#  'blousant',
#  'associative',
#  'ressautant',
#  'jalousasses',
#  'brabonçonnes',
#  'dégainât',
#  'enrobiez',
#  'pochassent',
#  'censurée',
#  'mûrirons',
#  'parachuterions',
#  'fustigées',
#  'cassé',
#  'inquiéteras',
#  'fabriquer',
#  'gaulas',
#  'maraudeur',
#  'rechignés',
#  'snoberaient',
#  'maculais',
#  'abrégeas',
#  'effets',
#  'gagnées',
#  'obsédassiez',
#  'talonnées',
#  'taisais',
#  'menaçâtes',
#  'furetions',
#  'o',
#  'maraudeuse',
#  'regarderait',
#  'accidentés',
#  'ruâmes',
#  'terrait',
#  'existerait',
#  'arborés',
#  'oscultaient',
#  'surimposâmes',
#  'remportâtes',
#  'désapprouvaient',
#  'astreindrons',
#  'déclassaient',
#  'fermenterais',
#  'conteniez',
#  'bénissiez',
#  'régaliez',
#  'adhéra',
#  'splendidement',
#  'posséderions',
#  'abri',
#  'retombiez',
#  'ébrasais',
#  'juxtaposerais',
#  'soupçonnée',
#  'décime',
#  'sains',
#  'réchauffèrent',
#  'angoissassiez',
#  'blutant',
#  'cabriolant',
#  'engouent',
#  'mûris',
#  'appariâmes',
#  'préméditant',
#  'sauvegardiez',
#  'vocaliseront',
#  'alphabétisassent',
#  'poires',
#  'recrachassiez',
#  'topait',
#  'dévalise',
#  'entichâmes',
#  'abstenue',
#  'exciperai',
#  'calcinions',
#  'envisageons',
#  'dénommées',
#  'spirochètes',
#  'élidas',
#  'chantre',
#  'accouda',
#  'jalonneriez',
#  'enrhumeras',
#  'rubéfions',
#  'incarcérai',
#  'régentât',
#  'correspondrait',
#  'cède',
#  'échalassèrent',
#  'embardée',
#  'faussâtes',
#  'disqualifiâtes',
#  'filèterais',
#  'sérièrent',
#  'vénérienne',
#  'accablement',
#  'balancier',
#  'bosselassions',
#  'couronnais',
#  'patinait',
#  'sécrétait',
#  'dégazeriez',
#  'morcellerais',
#  'allouerait',
#  'voilèrent',
#  'assoiront',
#  'métissages',
#  'verbalisé',
#  'cécité',
#  'échoues',
#  'démembrée',
#  'nimberait',
#  'électrochocs',
#  'terrien',
#  'agencerait',
#  'atone',
#  'scolariseront',
#  'insensibles',
#  'claironnant',
#  'détordre',
#  'grandirent',
#  'hydrate',
#  'contrebalançassent',
#  'verrouillages',
#  'domptasse',
#  'ovalisassions',
#  'décapsulons',
#  'arbitrerai',
#  'enlacerons',
#  'bâcheraient',
#  'décapole',
#  'anticonceptionnelles',
#  'comportant',
#  'dégorgeas',
#  'honorassent',
#  'arrondissiez',
#  'maïs',
#  'claironnerons',
#  'cintrer',
#  'avivasses',
#  'déchiffrerions',
#  'démoralisasse',
#  'graviraient',
#  'rapparier',
#  'alevin',
#  'stipendiaient',
#  'démontât',
#  'authentifierai',
#  'automnaux',
#  'méfiai',
#  'balsamiques',
#  'poltronneries',
#  'putes',
#  'oppressiez',
#  'viriez',
#  'abrégée',
#  'distancerai',
#  'exportez',
#  'hésitât',
#  ...}
